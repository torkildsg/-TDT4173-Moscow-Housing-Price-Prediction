# %% [markdown]
# # Moscow Housing Prediction: Group 60

# %% [markdown]
# ### Team members
#
# * Emil Ekornrød (Student ID: 506828)
# * Torkild Sandnes Grøstad (Student ID: 506595)
# * Henrik Gundersen (Student ID: 488635)

# %% [markdown]
# # 0: Loading Data

# %%
# !pip install lightgbm
# !pip install xgboost
# !pip install catboost

import numpy as np 
import pandas as pd 
import seaborn as sns 
import geopy.distance
import xgboost as xgb
import catboost as cb
import lightgbm as lgb
import matplotlib.pyplot as plt 
from pointpats import centrography
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor

np.random.seed(123)
sns.set_style('darkgrid')
pd.set_option('display.max_colwidth', None)

# %%
# Load the data
apartments = pd.read_csv('data/apartments_train.csv')
buildings = pd.read_csv('data/buildings_train.csv')
data = pd.merge(apartments, buildings.set_index('id'), how='left', left_on='building_id', right_index=True)
apartments_test = pd.read_csv('data/apartments_test.csv')
buildings_test = pd.read_csv('data/buildings_test.csv')
data_test = pd.merge(apartments_test, buildings_test.set_index('id'), how='left', left_on='building_id', right_index=True)

# %% [markdown]
# # 1: Data Cleaning

# %%
# Dataframe with train and test for imputing NaN values
cleaning = pd.concat([data, data_test], axis=0)
cleaning.shape
# Out:
# (33222, 34)

# %%
# For LightGBM v3 with no preprocessing
raw_data = cleaning.copy()

# %%
cleaning.drop_duplicates();

# %% [markdown]
# ### Outliers, duplicates and inconsistent observations

# %% [markdown]
# #### area_total

# %%
# drop outliers
cleaning = cleaning[cleaning['area_total'] < 1500]

# %%
# Looks like collection error in district 8.0, strategy -> set kitchen and living to NaN to impute later
cleaning_df = cleaning[cleaning['area_total'] < cleaning['area_living']]
cleaning_df = cleaning_df[cleaning_df['district'] == 8.0]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'area_living'] = np.nan
    cleaning.loc[(cleaning['id'] == ide), 'area_kitchen'] = np.nan

# %%
# Want to check district 8 area_kitchen and area_living
cleaning_df = cleaning[cleaning['district'] == 8.0]
cleaning_df = cleaning_df[cleaning_df['area_living'] == 80]
cleaning_df = cleaning_df[cleaning_df['area_kitchen'] == 20]
ids = cleaning_df['id'].values

# Set all area_kitchen, area_living == 20, 80 in district 8.0 to NaN to impute later
for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'area_living'] = np.nan
    cleaning.loc[(cleaning['id'] == ide), 'area_kitchen'] = np.nan

# %%
# Set rest of inconsistent, -> area_living equal area_total
cleaning_df = cleaning[cleaning['area_total'] < cleaning['area_living']]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'area_living'] = cleaning.loc[(cleaning['id'] == ide), 'area_total']

# %%
cleaning.loc[1107, 'area_kitchen'] = np.nan

# %%
cleaning_df = cleaning[cleaning['area_kitchen'] > cleaning['area_living']]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'area_living'] = cleaning.loc[(cleaning['id'] == ide), 'area_total']

# %%
# Examine floor higher than stories
cleaning_df = cleaning[cleaning['floor'] > cleaning['stories']]
cleaning_df[['floor', 'stories', 'building_id']]
ids = cleaning_df['id'].values

# Set floor values that are above stories to be stories / 2
for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'floor'] = cleaning.loc[(cleaning['id'] == ide), 'stories'] / 2

# %%
# Correcting for high number of rooms on small area
cleaning.loc[10831, 'rooms'] = 2
cleaning.loc[10830, 'rooms'] = 2
cleaning.loc[(cleaning['id'] == 25049), 'rooms'] = 3
cleaning.loc[(cleaning['id'] == 25083), 'rooms'] = 3

# %%
# Check apartments in same building and change if out of the ordinary
cleaning.loc[2358, 'bathrooms_private'] = 1
cleaning.loc[8664, 'bathrooms_private'] = 1
cleaning.loc[17413, 'bathrooms_private'] = 1
cleaning.loc[(cleaning['id'] == 26821), 'bathrooms_private'] = 1

# %%
# Check ceiling feature
cleaning.loc[2853, 'ceiling'] = 3.5
cleaning_df = cleaning[cleaning['ceiling'] >= 100]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'ceiling'] = cleaning.loc[(cleaning['id'] == ide), 'ceiling'] / 100

cleaning_df = cleaning[cleaning['ceiling'] > 10]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'ceiling'] = cleaning.loc[(cleaning['id'] == ide), 'ceiling'] / 10

# %% [markdown]
# ### Missing Data

# %%
def fast_mode(df, key_cols, value_col):
    return (df.groupby(key_cols + [value_col]).size() 
              .to_frame('counts').reset_index() 
              .sort_values('counts', ascending=False) 
              .drop_duplicates(subset=key_cols)).drop(columns='counts')

# %% [markdown]
# ### Missing data: layout, ceiling

# %%
# Too many missing values, drop columns
cleaning = cleaning.drop(columns=['layout'])

# %% [markdown]
# ### Missing data: District

# %%
data_district = cleaning[['longitude', 'latitude', 'district', 'building_id']]
data_district = data_district[data_district['district'].isnull()]
coordinates_missing = []

for building in data_district.building_id.unique():
    df_building = cleaning[cleaning['building_id'] == building]    
    coordinates_missing.append((df_building['latitude'].unique()[0], df_building['longitude'].unique()[0], building))

# %% [markdown]
# Manually see where these coordinates are on the map to determine district:

# %%
building_to_district = {
    4162: 7.0,
    2265: 7.0,
    1647: 7.0,
    6403: 7.0,
    183: 7.0,
    926: 3.0,
    4636: "check further, VC bird international airport",
    4412: "check further, VC bird international airport",
    4202: "check further, outskirts of city in kirgistan",
    7317: 6.0,
    8811: "check further, all the way towards japan",
    5667: "check further, all the way towards japan",
    6879: 3.0
}

# %%
# Impute districts found
cleaning.loc[(cleaning['building_id'] == 4162), 'district'] = 7.0
cleaning.loc[(cleaning['building_id'] == 2265), 'district'] = 7.0
cleaning.loc[(cleaning['building_id'] == 1647), 'district'] = 7.0
cleaning.loc[(cleaning['building_id'] == 6403), 'district'] = 7.0
cleaning.loc[(cleaning['building_id'] == 183), 'district'] = 7.0
cleaning.loc[(cleaning['building_id'] == 926), 'district'] = 3.0
cleaning.loc[(cleaning['building_id'] == 7317), 'district'] = 6.0
cleaning.loc[(cleaning['building_id'] == 6879), 'district'] = 3.0

data_district = cleaning[['longitude', 'latitude', 'district', 'building_id']]
data_district = data_district[data_district['district'].isnull()]

# %%
# Check weird if weird coordinates is in train or test, if train drop
building_4636 = data[data['building_id'] == 4636]
building_4412 = data[data['building_id'] == 4412]
building_4202 = data[data['building_id'] == 4202]
building_8811 = data[data['building_id'] == 8811]
building_5667 = data[data['building_id'] == 5667]
building_3803 = data[data['building_id'] == 3803]

# %%
# Examine building with weird coordinates
weird_building = [4636, 4412, 4202, 8811, 5667, 3803]

addresses_missing = []

for building in weird_building:
    df_building = cleaning[cleaning['building_id'] == building]
    addresses_missing.append((df_building['street'].unique()[0], 
                              df_building['address'].unique()[0], 
                              building))

# %%
# Manually check address for district
weird_building_to_district = {
    3803: 11.0,
    4636: 11.0,
    4412: 11.0,
    4202: 11.0,
    8811: 11.0,
    5667: 11.0,
}

# %%
# Fixing values latitude, longitude
cleaning.loc[(cleaning['building_id'] == 3803), 'latitude'] = 55.56729707552548
cleaning.loc[(cleaning['building_id'] == 3803), 'longitude'] = 37.48142051265652

cleaning.loc[(cleaning['building_id'] == 4636), 'latitude'] = 55.554940129860185
cleaning.loc[(cleaning['building_id'] == 4636), 'longitude'] = 37.53089613751531
cleaning.loc[(cleaning['building_id'] == 4412), 'latitude'] = 55.554940129860185
cleaning.loc[(cleaning['building_id'] == 4412), 'longitude'] = 37.53089613751531

cleaning.loc[(cleaning['building_id'] == 4202), 'latitude'] = 55.48214820099864
cleaning.loc[(cleaning['building_id'] == 4202), 'longitude'] = 36.990398748020795

cleaning.loc[(cleaning['building_id'] == 8811), 'latitude'] = 55.48214820099864
cleaning.loc[(cleaning['building_id'] == 8811), 'longitude'] = 36.990398748020795
cleaning.loc[(cleaning['building_id'] == 5667), 'latitude'] = 55.48214820099864
cleaning.loc[(cleaning['building_id'] == 5667), 'longitude'] = 36.990398748020795

# %%
for building in weird_building:
    cleaning.loc[(cleaning['building_id'] == building), 'district'] = 11.0

# %% [markdown]
# ### Missing data: impute with mode by district

# %%
def impute_missing_by_mode_in_district(cleaning, column):
    mode_by_district = fast_mode(cleaning, ['district'], column)
    mode_by_district.set_index('district', inplace=True)

    districts = cleaning.district.unique()
    for district in districts:
        cleaning.loc[(cleaning['district'] == district) & (cleaning[column].isna()), column] = mode_by_district.loc[district,column]

    return cleaning

# %%
cleaning = impute_missing_by_mode_in_district(cleaning, 'seller')
cleaning = impute_missing_by_mode_in_district(cleaning, 'bathrooms_shared')
cleaning = impute_missing_by_mode_in_district(cleaning, 'bathrooms_private')
cleaning = impute_missing_by_mode_in_district(cleaning, 'balconies')
cleaning = impute_missing_by_mode_in_district(cleaning, 'constructed')
cleaning = impute_missing_by_mode_in_district(cleaning, 'loggias')
cleaning = impute_missing_by_mode_in_district(cleaning, 'phones')
cleaning = impute_missing_by_mode_in_district(cleaning, 'new')
cleaning = impute_missing_by_mode_in_district(cleaning, 'ceiling')
cleaning = impute_missing_by_mode_in_district(cleaning, 'condition')
cleaning = impute_missing_by_mode_in_district(cleaning, 'material')
cleaning = impute_missing_by_mode_in_district(cleaning, 'elevator_without')
cleaning = impute_missing_by_mode_in_district(cleaning, 'elevator_passenger')
cleaning = impute_missing_by_mode_in_district(cleaning, 'elevator_service')

# %% [markdown]
# ### Missing data: area_living

# %%
missing_living = cleaning[cleaning['area_living'].isnull()]

# Impute missing value by mean percent of total is living by district
cleaning['living_to_total'] = cleaning['area_living'] / cleaning['area_total']

mean_living_to_total_by_district = cleaning[['living_to_total', 'district']].groupby('district').mean()

cleaning['mean_living_to_total_by_district'] = 0

districts = cleaning.district.unique()

for district in districts:
    cleaning.loc[(cleaning['district'] == district), 'mean_living_to_total_by_district'] = mean_living_to_total_by_district.loc[district,'living_to_total']

cleaning['area_living'].fillna(cleaning['area_total']*cleaning['mean_living_to_total_by_district'], inplace=True)

for ide in ids:
    cleaning.loc[(cleaning['area_living'] == 0), 'area_living'] = cleaning.loc[(cleaning['id'] == ide),'area_total']*cleaning.loc[(cleaning['id'] == ide),'mean_living_to_total_by_district']

# %%
# area_living == area_total
cleaning_df = cleaning[cleaning['area_living'] == cleaning['area_total']]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'area_living'] = cleaning.loc[(cleaning['id'] == ide),'area_total']*cleaning.loc[(cleaning['id'] == ide),'mean_living_to_total_by_district']
    
cleaning = cleaning.drop(columns=['mean_living_to_total_by_district', 'living_to_total'])

# %% [markdown]
# ### Missing data: ceiling

# %%
cleaning_df = cleaning[cleaning['ceiling'] == 0]
ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'ceiling'] = np.nan
    
cleaning = impute_missing_by_mode_in_district(cleaning, 'ceiling')

# %% [markdown]
# ### Missing data: area_kitchen

# %%
missing_kitchen = cleaning[cleaning['area_kitchen'].isnull()]

# %%
# Impute missing value by mean percent of total is kitchen by district
cleaning['kitchen_to_total'] = cleaning['area_kitchen'] / cleaning['area_total']

mean_kitchen_to_total_by_district = cleaning[['kitchen_to_total', 'district']].groupby('district').mean()

cleaning['mean_kitchen_to_total_by_district'] = 0

for district in districts:
    cleaning.loc[(cleaning['district'] == district), 'mean_kitchen_to_total_by_district'] = mean_kitchen_to_total_by_district.loc[district,'kitchen_to_total']

cleaning['area_kitchen'].fillna(cleaning['area_total']*cleaning['mean_kitchen_to_total_by_district'], inplace=True)
cleaning = cleaning.drop(columns=['mean_kitchen_to_total_by_district', 'kitchen_to_total'])

# %% [markdown]
# ### Missing data: Impute with "missing" category

# %%
def impute_missing_by_new_category(df, column):
    df.loc[(df[column].isnull()), column] = 'Missing'
    return df

# %%
cleaning = impute_missing_by_new_category(cleaning, 'parking')
cleaning = impute_missing_by_new_category(cleaning, 'garbage_chute')
cleaning = impute_missing_by_new_category(cleaning, 'heating')
#cleaning = impute_missing_by_new_category(cleaning, 'condition')
cleaning = impute_missing_by_new_category(cleaning, 'new')
cleaning = impute_missing_by_new_category(cleaning, 'windows_street')
cleaning = impute_missing_by_new_category(cleaning, 'windows_court')

# %% [markdown]
# # 2. Feature Engineering

# %%
data_fe = cleaning

# %%
data_fe['price_log'] = np.log10(data_fe.price)

# %%
data_fe['area_total_log'] = np.log(data_fe['area_total'] + 1)

# %% [markdown]
# ### Feature Engineering: room_size = area_total / rooms

# %%
data_fe['room_size'] = data_fe['area_total'] / data_fe['rooms']

# %%
data_fe['room_size_log'] = np.log(data_fe['room_size'] + 1)

# %% [markdown]
# ### Feature Engineering: distance_to_mean (distance to "hottest place to be")

# %%
value = 5e7
data_price_fltr = cleaning[cleaning['price'] > value]

mean_center = centrography.mean_center(data_price_fltr[['longitude', 'latitude']])
median_center = centrography.euclidean_median(data_price_fltr[['longitude', 'latitude']])

# Create apartment point tuples
fixed_mean_center = (mean_center[1], mean_center[0])

def create_point_tuples_column(data):
    point_tuples_list = []
    for index, row in data.iterrows(): 
        if np.isnan(row['latitude']) or np.isnan(row['longitude']):
            point_tuples_list.append((0.0, 0.0))
        else:  
            this_point = (row['latitude'], row['longitude'])
            point_tuples_list.append(this_point) 
    data['point_tuples'] = point_tuples_list
    return data['point_tuples'], fixed_mean_center

#Calculate the distance from the mean center to all apartments
def calculate_distances(data):
    point_tuples_column, fixed_mean_center = create_point_tuples_column(data)
    data['distance_mean'] = point_tuples_column.apply(lambda x: geopy.distance.geodesic(fixed_mean_center, x).km)
    #if isinstance(x[0], np.nan)) | (isinstance(x[1], np.nan)) else geopy.distance.geodesic(fixed_mean_center, x).km)
    return data

data_fe = calculate_distances(data_fe)
data_fe['distance_mean_log'] = np.log(data_fe['distance_mean']+1) 
data_fe['distance_mean_log_standard'] = (data_fe['distance_mean_log'] - 2.336536) / 0.690107

# %% [markdown]
# ### Feature Engineering: age_of_building = 2023 - constructed

# %%
data_fe['age_of_building'] = 2023 - data_fe['constructed']

# %%
data_fe['age_of_building_log'] = np.log(data_fe['age_of_building']+1)

# %%
data_fe['age_of_building_log_standard'] = (data_fe['age_of_building_log'] - 2.570196) / 1.011501

# %% [markdown]
# ### Feature Engineering: cat_constructed

# %%
constructed_mean = pd.DataFrame(data_fe.groupby("constructed", as_index=False)["price_log"].mean())
constructed_median = pd.DataFrame(data_fe.groupby("constructed", as_index=False)["price_log"].median())

# %%
zero = constructed_mean[constructed_mean['price_log'] < 7.0]
zero = zero['constructed'].values
zero = list(zero)

# %%
one = constructed_mean[constructed_mean['price_log'] < 7.25]
one = one[one['price_log'] >= 7.0]
one = one['constructed'].values
one = list(one)

# %%
two = constructed_mean[constructed_mean['price_log'] < 7.50]
two = two[two['price_log'] >= 7.25]
two = two['constructed'].values
two = list(two)

# %%
three = constructed_mean[constructed_mean['price_log'] < 7.75]
three = three[three['price_log'] >= 7.50]
three = three['constructed'].values
three = list(three)

# %%
four = constructed_mean[constructed_mean['price_log'] < 9.0]
four = four[four['price_log'] >= 7.75]
four = four['constructed'].values
four = list(four)

# %%
cleaning['cat_constructed'] = 0

# %%
ids = cleaning['id'].values

for ide in ids:
    build_year = cleaning.loc[(cleaning['id'] == ide), 'constructed']
    build_year = float(build_year)
    
    if build_year in zero:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = 0
    elif build_year in one:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = 1
    elif build_year in two:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = 2
    elif build_year in three:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = 3
    elif build_year in four:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = 4
    else:
        cleaning.loc[(cleaning['id'] == ide), 'cat_constructed'] = "Missing"

# %%
# Manually assign missing
cleaning.loc[(cleaning['constructed'] == 1875), 'cat_constructed'] = 2
cleaning.loc[(cleaning['constructed'] == 1887), 'cat_constructed'] = 2
cleaning.loc[(cleaning['constructed'] == 1892), 'cat_constructed'] = 3
cleaning.loc[(cleaning['constructed'] == 1923), 'cat_constructed'] = 2
cleaning.loc[(cleaning['constructed'] == 1945), 'cat_constructed'] = 2
cleaning.loc[(cleaning['constructed'] == 1947), 'cat_constructed'] = 2

# %%
cleaning['build_year'] = cleaning['cat_constructed']

# %% [markdown]
# ### Feature Engineering: floor_perc = floor / stories

# %%
data_fe['floor_perc'] = data_fe['floor'] / data_fe['stories']

# %%
cleaning_df = data_fe[data_fe['floor_perc'] == 1]
#cleaning_df[cleaning_df['price'].isnull()]
#print(cleaning_df['building_id'].value_counts())
#cleaning_df[cleaning_df['building_id'] == 5663]

ids = cleaning_df['id'].values

for ide in ids:
    cleaning.loc[(cleaning['id'] == ide), 'floor_perc'] = 0.5

# %%
data_fe['floor_perc_log'] = np.log(data_fe['floor_perc'] + 1)

# %% [markdown]
# ### Feature Engineering: ceiling

# %%
data_fe.loc[2494, 'ceiling'] = 3.0
data_fe.loc[13256, 'ceiling'] = 3.0
data_fe.loc[6090, 'ceiling'] = 2.65

# %% [markdown]
# ### Feature Engineering: distance_to_metro

# %%
data_metros = pd.read_csv('data/moscow_metro_stations.csv', encoding='cp1252')

def create_metro_tuples_column(data_metros):
    metro_tuples_list = []
    for row in data_metros.itertuples(): 
        metro_tuples_list.append((row.latitude, row.longitude))
    data_metros['metro_tuple'] = metro_tuples_list
    return data_metros['metro_tuple'] 

create_metro_tuples_column(data_metros)
# Out:
# 0        (55.8148, 37.7342)
# 1        (55.8038, 37.7448)
# 2        (55.7963, 37.7151)
# 3        (55.7888, 37.6802)
# 4        (55.7801, 37.6673)
#                ...
# 237    (55.70497, 37.81901)
# 238      (55.7033, 37.8511)
# 239        (55.71, 37.8792)
# 240      (55.7085, 37.9004)
# 241      (55.7036, 37.9264)
# Name: metro_tuple, Length: 242, dtype: object

# %%
#data_metros = data_metros.drop(242)
#data_metros

# %%
def calculate_distance_metro(data_metros, data):
    metro_tuples = data_metros['metro_tuple']
    distance = 999
    distances_to_metro = []
    for point in data['point_tuples']:
        list_of_distances = metro_tuples.apply(lambda x: geopy.distance.geodesic(point, x).km)
        distances_to_metro.append(min(list_of_distances))
    data['distance_to_metro'] = distances_to_metro
    return data['distance_to_metro']

# %%
#calculate_distance_metro(data_metros, data_fe)

# %%
calculated_distances_metro = pd.read_csv('data/distance_to_metro.csv')
data_fe = pd.merge(data_fe, calculated_distances_metro.set_index('id'), how='left', left_on='id', right_index=True)

# %%
data_fe['distance_to_metro']
# Out:
# 0        1.923224
# 1        0.914736
# 2        1.644991
# 3        0.914736
# 4        1.221645
#           ...
# 9932     2.152614
# 9933     0.632797
# 9934     2.582979
# 9935     0.722539
# 9936    13.446798
# Name: distance_to_metro, Length: 33219, dtype: float64

# %%
data_fe['distance_to_metro'] = np.log(data_fe['distance_to_metro'])

# %% [markdown]
# ### Feature Cleaning

# %%
data_fe['new'] = pd.to_numeric(data_fe['new'])
data_fe['cat_constructed'] = pd.to_numeric(data_fe['cat_constructed'])

# %%
data_fe['material'] = data_fe['material'].astype(int)

# %%
data_fe['condition'] = data_fe['condition'].astype(int)

# %%
data_fe['latitude_squared'] = data_fe['latitude']**2
data_fe['longitude_squared'] = data_fe['longitude']**2

# %%
data_fe['room_size_log_squared'] = data_fe['room_size_log']**2

# %% [markdown]
# ### Feature Engineering: distances to universities

# %%
data_uni = pd.read_csv('data/universities_moscow.csv', encoding='cp1252')

def create_uni_tuples_column(data_uni):
    uni_tuples_list = []
    for row in data_uni.itertuples(): 
        uni_tuples_list.append((row.latitude, row.longitude))
    data_uni['lat_long_tuple'] = uni_tuples_list
    return data_uni['lat_long_tuple'] 

create_uni_tuples_column(data_uni)
# Out:
# 0    (55.703819, 37.528401)
# 1    (55.766022, 37.684533)
# 2    (55.929809, 37.520234)
# 3    (55.761435, 37.633197)
# 4     (55.64983, 37.664436)
# 5    (55.672896, 37.484679)
# 6    (55.741182, 37.619337)
# 7    (55.727818, 37.627432)
# Name: lat_long_tuple, dtype: object

# %%
def calculate_distance_uni(data_uni, data):
    uni_tuples = data_uni['lat_long_tuple']
    distances_to_uni = []
    for point in data['point_tuples']:
        list_of_distances = uni_tuples.apply(lambda x: geopy.distance.geodesic(point, x).km)
        distances_to_uni.append(min(list_of_distances))
    data['distance_to_uni'] = distances_to_uni
    return data['distance_to_uni']

# %%
calculate_distance_uni(data_uni, data_fe);

# %%
data_fe['distance_to_uni'] = np.log(data_fe['distance_to_uni'])

# %%
data_fe['distance_to_uni'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Feature Engineering: Bearing to center

# %%
from numpy import arctan2, random, sin, cos, degrees

def calc_bearing(data):
  center = (mean_center[1], mean_center[0]) # (55, 37) lat, long
  bearing_list = []
  for point in data.point_tuples:
    # delta_L is the difference between the Longitudal values of the two points
    dLong = center[1] - point[1]
    x = cos(center[0])*sin(dLong)
    y = cos(point[0])*sin(center[0]) - sin(point[0])*cos(center[0])*cos(dLong)
    bearing = degrees(arctan2(x, y))
    bearing_list.append(bearing)
  data['bearing_to_center'] = bearing_list
  return data['bearing_to_center']

calc_bearing(data_fe);

# %% [markdown]
# # 3. Prediction

# %% [markdown]
# ### Train/test split

# %%
# categorical lgbm: 'material', 'condition', 'cat_constructed' => must be floats
# categorical cb: 'floor', 'rooms', 'condition', 'district', 'stories', 'material', 'cat_constructed' => must be strings
data_fe.cat_constructed = data_fe.cat_constructed.astype(np.float64)
convert_types=['material', 'condition', 'cat_constructed', 'floor', 'rooms',  'district', 'stories']
for col in convert_types:
    data_fe[col + '_string'] = data_fe[col].astype(str)

# %%
train = data_fe[data_fe['price'].notnull()]
test = data_fe[data_fe['price'].isnull()]
train['price_log'] = np.log(train['price'])
group = train.building_id
# Out:
# <ipython-input-149-aed7cf7bb691>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['price_log'] = np.log(train['price'])

# %% [markdown]
# ### Features

# %%
categorical_features = [0, 1, 2]

cb_cat_features = ['floor', 'rooms', 'condition', 'district', 'stories', 'material']

xgb_features = ['longitude', 'latitude', 'floor_perc', 'condition', 'material', 
                 'ceiling',  'distance_to_uni', 'area_total', 'distance_mean', 'room_size', 'cat_constructed']


catb_features = [ 'age_of_building', 'area_total', 'longitude', 'latitude',
                 'ceiling', 'room_size', 'distance_to_uni', 'distance_mean', 'distance_to_metro',
                    'floor', 'rooms', 'condition', 'district', 'stories', 'material', 'cat_constructed']

lgbm_features = ['material', 'condition', 'constructed', 'floor_perc',
            'area_total',  'ceiling', 'room_size', 'distance_to_uni',
            'distance_mean', 'longitude', 'latitude']

rf_features = ['material', 'condition', 'cat_constructed', 'floor_perc',  'age_of_building_log',
            'area_total_log',  'ceiling', 'room_size_log', 'distance_to_uni',
            'distance_mean_log', 'longitude', 'latitude']

# %% [markdown]
# ### XGBoost

# %%
convert_types = ['seller', 'floor', 'rooms', 'bathrooms', 'balc_loggias', 'condition', 
                 'phones', 'new', 'district', 'stories', 'elevator_without', 'material', 'cat_constructed']
for col in convert_types:
    train[col] = train[col].astype(float) 
    test[col] = test[col].astype(float)
# Out:
# <ipython-input-97-40d8c0e0c665>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[col] = train[col].astype(float)
# <ipython-input-97-40d8c0e0c665>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = test[col].astype(float)

# %%
xgb = xgb.XGBRegressor(    
    metric= 'rmsle',
    #tree_method= 'gpu_hist',
    n_estimators= 6000,
    reg_lambda= 3.3970862089233713,
    reg_alpha= 0.05,
    colsample_bytree= 0.9,
    subsample= 0.7,
    learning_rate= 0.0086,
    max_depth= 11,
    random_state= 48,
    min_child_weight= 1,
    seed= 42
)

xgb.fit(train[xgb_features], train['price_log'])
# Out:
# [10:35:32] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.9, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.0086, max_delta_step=0,
#              max_depth=11, metric='rmsle', min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=6000, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=48,
#              reg_alpha=0.05, reg_lambda=3.3970862089233713, scale_pos_weight=1,
#              seed=42, subsample=0.7, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
xgb_pred = xgb.predict(test[xgb_features])

# %% [markdown]
# ### CatBoost

# %%
convert_types = ['seller', 'floor', 'rooms', 'bathrooms', 'balc_loggias', 'condition', 'constructed', 
                 'phones', 'new', 'district', 'stories', 'elevator_without', 'material', 'cat_constructed']
for col in convert_types:
    train[col] = train[col].astype(str) 
    test[col] = test[col].astype(str)
# Out:
# <ipython-input-102-6011426471e9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[col] = train[col].astype(str)
# <ipython-input-102-6011426471e9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = test[col].astype(str)

# %%
best_trial_cb={
    'l2_leaf_reg': 0.0029675173022904867,
    'max_bin': 389,
    'bagging_temperature': 0.7448407730182606,
    'learning_rate': 0.05226579708274029,
    'depth': 11,
    'min_data_in_leaf': 88,
    #'rsm': 1
}

model_cb = cb.CatBoostRegressor(**best_trial_cb)

model_cb.fit(train[catb_features], train['price_log'], cat_features=cb_cat_features )
# Out:
# 0:	learn: 0.8235188	total: 292ms	remaining: 4m 51s
# 1:	learn: 0.7876871	total: 430ms	remaining: 3m 34s
# 2:	learn: 0.7530108	total: 562ms	remaining: 3m 6s
# 3:	learn: 0.7207778	total: 660ms	remaining: 2m 44s
# 4:	learn: 0.6901308	total: 797ms	remaining: 2m 38s
# 5:	learn: 0.6608522	total: 930ms	remaining: 2m 34s
# 6:	learn: 0.6332870	total: 1.06s	remaining: 2m 30s
# 7:	learn: 0.6070752	total: 1.19s	remaining: 2m 27s
# 8:	learn: 0.5821676	total: 1.32s	remaining: 2m 25s
# 9:	learn: 0.5588884	total: 1.45s	remaining: 2m 23s
# 10:	learn: 0.5368302	total: 1.58s	remaining: 2m 22s
# 11:	learn: 0.5162398	total: 1.72s	remaining: 2m 21s
# 12:	learn: 0.4967104	total: 1.85s	remaining: 2m 20s
# 13:	learn: 0.4782592	total: 1.98s	remaining: 2m 19s
# 14:	learn: 0.4603992	total: 2.12s	remaining: 2m 19s
# 15:	learn: 0.4440629	total: 2.24s	remaining: 2m 17s
# 16:	learn: 0.4284932	total: 2.37s	remaining: 2m 17s
# 17:	learn: 0.4136223	total: 2.5s	remaining: 2m 16s
# 18:	learn: 0.3996060	total: 2.64s	remaining: 2m 16s
# 19:	learn: 0.3860516	total: 2.78s	remaining: 2m 16s
# 20:	learn: 0.3733312	total: 2.91s	remaining: 2m 15s
# 21:	learn: 0.3619740	total: 3.05s	remaining: 2m 15s
# 22:	learn: 0.3511795	total: 3.18s	remaining: 2m 15s
# 23:	learn: 0.3409298	total: 3.31s	remaining: 2m 14s
# 24:	learn: 0.3311831	total: 3.44s	remaining: 2m 14s
# 25:	learn: 0.3220549	total: 3.57s	remaining: 2m 13s
# 26:	learn: 0.3127788	total: 3.71s	remaining: 2m 13s
# 27:	learn: 0.3045511	total: 3.85s	remaining: 2m 13s
# 28:	learn: 0.2968801	total: 3.98s	remaining: 2m 13s
# 29:	learn: 0.2898117	total: 4.11s	remaining: 2m 12s
# 30:	learn: 0.2835305	total: 4.24s	remaining: 2m 12s
# 31:	learn: 0.2771975	total: 4.37s	remaining: 2m 12s
# 32:	learn: 0.2710151	total: 4.5s	remaining: 2m 11s
# 33:	learn: 0.2653132	total: 4.64s	remaining: 2m 11s
# 34:	learn: 0.2596757	total: 4.78s	remaining: 2m 11s
# 35:	learn: 0.2550939	total: 4.9s	remaining: 2m 11s
# 36:	learn: 0.2503228	total: 5.04s	remaining: 2m 11s
# 37:	learn: 0.2463249	total: 5.17s	remaining: 2m 10s
# 38:	learn: 0.2424886	total: 5.3s	remaining: 2m 10s
# 39:	learn: 0.2383914	total: 5.43s	remaining: 2m 10s
# 40:	learn: 0.2345017	total: 5.57s	remaining: 2m 10s
# 41:	learn: 0.2312191	total: 5.71s	remaining: 2m 10s
# 42:	learn: 0.2274723	total: 5.84s	remaining: 2m 10s
# 43:	learn: 0.2242066	total: 5.97s	remaining: 2m 9s
# 44:	learn: 0.2203757	total: 6.1s	remaining: 2m 9s
# 45:	learn: 0.2168453	total: 6.23s	remaining: 2m 9s
# 46:	learn: 0.2143434	total: 6.36s	remaining: 2m 9s
# 47:	learn: 0.2119172	total: 6.49s	remaining: 2m 8s
# 48:	learn: 0.2088691	total: 6.64s	remaining: 2m 8s
# 49:	learn: 0.2064843	total: 6.78s	remaining: 2m 8s
# 50:	learn: 0.2035698	total: 6.91s	remaining: 2m 8s
# 51:	learn: 0.2011815	total: 7.03s	remaining: 2m 8s
# 52:	learn: 0.1989447	total: 7.16s	remaining: 2m 7s
# 53:	learn: 0.1966517	total: 7.3s	remaining: 2m 7s
# 54:	learn: 0.1948665	total: 7.43s	remaining: 2m 7s
# 55:	learn: 0.1932696	total: 7.56s	remaining: 2m 7s
# 56:	learn: 0.1915201	total: 7.71s	remaining: 2m 7s
# 57:	learn: 0.1898957	total: 7.83s	remaining: 2m 7s
# 58:	learn: 0.1882673	total: 7.96s	remaining: 2m 6s
# 59:	learn: 0.1861894	total: 8.09s	remaining: 2m 6s
# 60:	learn: 0.1849204	total: 8.22s	remaining: 2m 6s
# 61:	learn: 0.1829189	total: 8.34s	remaining: 2m 6s
# 62:	learn: 0.1816060	total: 8.48s	remaining: 2m 6s
# 63:	learn: 0.1804176	total: 8.61s	remaining: 2m 5s
# 64:	learn: 0.1782844	total: 8.75s	remaining: 2m 5s
# 65:	learn: 0.1764623	total: 8.88s	remaining: 2m 5s
# 66:	learn: 0.1753996	total: 9.01s	remaining: 2m 5s
# 67:	learn: 0.1743306	total: 9.14s	remaining: 2m 5s
# 68:	learn: 0.1738728	total: 9.19s	remaining: 2m 4s
# 69:	learn: 0.1728136	total: 9.33s	remaining: 2m 3s
# 70:	learn: 0.1718556	total: 9.46s	remaining: 2m 3s
# 71:	learn: 0.1706580	total: 9.61s	remaining: 2m 3s
# 72:	learn: 0.1694587	total: 9.75s	remaining: 2m 3s
# 73:	learn: 0.1689082	total: 9.9s	remaining: 2m 3s
# 74:	learn: 0.1677362	total: 10s	remaining: 2m 3s
# 75:	learn: 0.1668268	total: 10.2s	remaining: 2m 3s
# 76:	learn: 0.1660873	total: 10.3s	remaining: 2m 3s
# 77:	learn: 0.1655511	total: 10.4s	remaining: 2m 3s
# 78:	learn: 0.1644546	total: 10.6s	remaining: 2m 3s
# 79:	learn: 0.1635634	total: 10.7s	remaining: 2m 3s
# 80:	learn: 0.1628193	total: 10.9s	remaining: 2m 3s
# 81:	learn: 0.1619738	total: 11s	remaining: 2m 3s
# 82:	learn: 0.1607203	total: 11.1s	remaining: 2m 2s
# 83:	learn: 0.1599839	total: 11.3s	remaining: 2m 2s
# 84:	learn: 0.1590445	total: 11.4s	remaining: 2m 2s
# 85:	learn: 0.1585592	total: 11.5s	remaining: 2m 2s
# 86:	learn: 0.1578680	total: 11.7s	remaining: 2m 2s
# 87:	learn: 0.1571253	total: 11.8s	remaining: 2m 2s
# 88:	learn: 0.1566651	total: 11.9s	remaining: 2m 2s
# 89:	learn: 0.1562528	total: 12.1s	remaining: 2m 2s
# 90:	learn: 0.1554723	total: 12.2s	remaining: 2m 2s
# 91:	learn: 0.1549094	total: 12.3s	remaining: 2m 1s
# 92:	learn: 0.1543418	total: 12.5s	remaining: 2m 1s
# 93:	learn: 0.1537421	total: 12.6s	remaining: 2m 1s
# 94:	learn: 0.1533554	total: 12.8s	remaining: 2m 1s
# 95:	learn: 0.1525097	total: 12.9s	remaining: 2m 1s
# 96:	learn: 0.1522114	total: 13.1s	remaining: 2m 1s
# 97:	learn: 0.1513726	total: 13.2s	remaining: 2m 1s
# 98:	learn: 0.1507260	total: 13.3s	remaining: 2m 1s
# 99:	learn: 0.1504304	total: 13.5s	remaining: 2m 1s
# 100:	learn: 0.1497218	total: 13.6s	remaining: 2m 1s
# 101:	learn: 0.1491534	total: 13.7s	remaining: 2m 1s
# 102:	learn: 0.1486264	total: 13.9s	remaining: 2m
# 103:	learn: 0.1483169	total: 14s	remaining: 2m
# 104:	learn: 0.1476327	total: 14.1s	remaining: 2m
# 105:	learn: 0.1472054	total: 14.3s	remaining: 2m
# 106:	learn: 0.1466244	total: 14.4s	remaining: 2m
# 107:	learn: 0.1463395	total: 14.6s	remaining: 2m
# 108:	learn: 0.1459374	total: 14.7s	remaining: 2m
# 109:	learn: 0.1453536	total: 14.9s	remaining: 2m
# 110:	learn: 0.1447502	total: 15s	remaining: 2m
# 111:	learn: 0.1440425	total: 15.1s	remaining: 2m
# 112:	learn: 0.1436395	total: 15.3s	remaining: 1m 59s
# 113:	learn: 0.1432242	total: 15.4s	remaining: 1m 59s
# 114:	learn: 0.1427089	total: 15.6s	remaining: 1m 59s
# 115:	learn: 0.1421680	total: 15.7s	remaining: 1m 59s
# 116:	learn: 0.1417166	total: 15.8s	remaining: 1m 59s
# 117:	learn: 0.1413777	total: 16s	remaining: 1m 59s
# 118:	learn: 0.1407013	total: 16.1s	remaining: 1m 59s
# 119:	learn: 0.1402247	total: 16.2s	remaining: 1m 59s
# 120:	learn: 0.1401935	total: 16.3s	remaining: 1m 58s
# 121:	learn: 0.1397161	total: 16.4s	remaining: 1m 58s
# 122:	learn: 0.1391857	total: 16.6s	remaining: 1m 58s
# 123:	learn: 0.1383336	total: 16.7s	remaining: 1m 58s
# 124:	learn: 0.1379376	total: 16.8s	remaining: 1m 57s
# 125:	learn: 0.1373765	total: 17s	remaining: 1m 57s
# 126:	learn: 0.1369266	total: 17.1s	remaining: 1m 57s
# 127:	learn: 0.1365155	total: 17.2s	remaining: 1m 57s
# 128:	learn: 0.1363298	total: 17.4s	remaining: 1m 57s
# 129:	learn: 0.1360959	total: 17.5s	remaining: 1m 57s
# 130:	learn: 0.1357174	total: 17.7s	remaining: 1m 57s
# 131:	learn: 0.1353085	total: 17.8s	remaining: 1m 56s
# 132:	learn: 0.1346501	total: 17.9s	remaining: 1m 56s
# 133:	learn: 0.1342097	total: 18s	remaining: 1m 56s
# 134:	learn: 0.1338726	total: 18.2s	remaining: 1m 56s
# 135:	learn: 0.1335444	total: 18.3s	remaining: 1m 56s
# 136:	learn: 0.1331908	total: 18.4s	remaining: 1m 56s
# 137:	learn: 0.1326335	total: 18.6s	remaining: 1m 56s
# 138:	learn: 0.1322094	total: 18.7s	remaining: 1m 56s
# 139:	learn: 0.1318692	total: 18.9s	remaining: 1m 55s
# 140:	learn: 0.1313314	total: 19s	remaining: 1m 55s
# 141:	learn: 0.1307317	total: 19.1s	remaining: 1m 55s
# 142:	learn: 0.1305200	total: 19.3s	remaining: 1m 55s
# 143:	learn: 0.1303063	total: 19.4s	remaining: 1m 55s
# 144:	learn: 0.1298011	total: 19.5s	remaining: 1m 55s
# 145:	learn: 0.1293490	total: 19.7s	remaining: 1m 55s
# 146:	learn: 0.1289342	total: 19.8s	remaining: 1m 55s
# 147:	learn: 0.1284703	total: 19.9s	remaining: 1m 54s
# 148:	learn: 0.1282731	total: 20.1s	remaining: 1m 54s
# 149:	learn: 0.1280258	total: 20.2s	remaining: 1m 54s
# 150:	learn: 0.1277829	total: 20.3s	remaining: 1m 54s
# 151:	learn: 0.1275105	total: 20.5s	remaining: 1m 54s
# 152:	learn: 0.1270528	total: 20.6s	remaining: 1m 54s
# 153:	learn: 0.1264833	total: 20.8s	remaining: 1m 54s
# 154:	learn: 0.1260677	total: 20.9s	remaining: 1m 53s
# 155:	learn: 0.1257332	total: 21s	remaining: 1m 53s
# 156:	learn: 0.1256337	total: 21.2s	remaining: 1m 53s
# 157:	learn: 0.1253116	total: 21.3s	remaining: 1m 53s
# 158:	learn: 0.1249718	total: 21.4s	remaining: 1m 53s
# 159:	learn: 0.1244890	total: 21.6s	remaining: 1m 53s
# 160:	learn: 0.1241966	total: 21.7s	remaining: 1m 53s
# 161:	learn: 0.1240786	total: 21.9s	remaining: 1m 53s
# 162:	learn: 0.1237117	total: 22s	remaining: 1m 52s
# 163:	learn: 0.1233900	total: 22.1s	remaining: 1m 52s
# 164:	learn: 0.1231409	total: 22.3s	remaining: 1m 52s
# 165:	learn: 0.1229556	total: 22.4s	remaining: 1m 52s
# 166:	learn: 0.1226280	total: 22.6s	remaining: 1m 52s
# 167:	learn: 0.1221549	total: 22.7s	remaining: 1m 52s
# 168:	learn: 0.1217896	total: 22.8s	remaining: 1m 52s
# 169:	learn: 0.1215793	total: 23s	remaining: 1m 52s
# 170:	learn: 0.1211519	total: 23.1s	remaining: 1m 52s
# 171:	learn: 0.1209911	total: 23.2s	remaining: 1m 51s
# 172:	learn: 0.1205887	total: 23.4s	remaining: 1m 51s
# 173:	learn: 0.1203809	total: 23.5s	remaining: 1m 51s
# 174:	learn: 0.1201290	total: 23.7s	remaining: 1m 51s
# 175:	learn: 0.1199092	total: 23.8s	remaining: 1m 51s
# 176:	learn: 0.1195579	total: 23.9s	remaining: 1m 51s
# 177:	learn: 0.1193367	total: 24s	remaining: 1m 51s
# 178:	learn: 0.1188283	total: 24.2s	remaining: 1m 50s
# 179:	learn: 0.1186166	total: 24.3s	remaining: 1m 50s
# 180:	learn: 0.1184799	total: 24.5s	remaining: 1m 50s
# 181:	learn: 0.1181929	total: 24.6s	remaining: 1m 50s
# 182:	learn: 0.1178996	total: 24.8s	remaining: 1m 50s
# 183:	learn: 0.1175158	total: 24.9s	remaining: 1m 50s
# 184:	learn: 0.1172770	total: 25.1s	remaining: 1m 50s
# 185:	learn: 0.1169933	total: 25.2s	remaining: 1m 50s
# 186:	learn: 0.1168206	total: 25.3s	remaining: 1m 50s
# 187:	learn: 0.1163829	total: 25.5s	remaining: 1m 49s
# 188:	learn: 0.1159932	total: 25.6s	remaining: 1m 49s
# 189:	learn: 0.1157665	total: 25.7s	remaining: 1m 49s
# 190:	learn: 0.1155394	total: 25.9s	remaining: 1m 49s
# 191:	learn: 0.1153471	total: 26s	remaining: 1m 49s
# 192:	learn: 0.1151923	total: 26.1s	remaining: 1m 49s
# 193:	learn: 0.1147718	total: 26.3s	remaining: 1m 49s
# 194:	learn: 0.1144477	total: 26.4s	remaining: 1m 49s
# 195:	learn: 0.1141074	total: 26.6s	remaining: 1m 48s
# 196:	learn: 0.1138775	total: 26.7s	remaining: 1m 48s
# 197:	learn: 0.1137482	total: 26.9s	remaining: 1m 48s
# 198:	learn: 0.1136404	total: 27s	remaining: 1m 48s
# 199:	learn: 0.1134520	total: 27.2s	remaining: 1m 48s
# 200:	learn: 0.1131317	total: 27.3s	remaining: 1m 48s
# 201:	learn: 0.1126361	total: 27.5s	remaining: 1m 48s
# 202:	learn: 0.1122223	total: 27.6s	remaining: 1m 48s
# 203:	learn: 0.1120644	total: 27.8s	remaining: 1m 48s
# 204:	learn: 0.1118691	total: 27.9s	remaining: 1m 48s
# 205:	learn: 0.1117510	total: 28.1s	remaining: 1m 48s
# 206:	learn: 0.1116035	total: 28.2s	remaining: 1m 48s
# 207:	learn: 0.1113435	total: 28.4s	remaining: 1m 48s
# 208:	learn: 0.1111420	total: 28.5s	remaining: 1m 47s
# 209:	learn: 0.1110515	total: 28.7s	remaining: 1m 47s
# 210:	learn: 0.1107996	total: 28.8s	remaining: 1m 47s
# 211:	learn: 0.1105474	total: 29s	remaining: 1m 47s
# 212:	learn: 0.1103408	total: 29.1s	remaining: 1m 47s
# 213:	learn: 0.1100213	total: 29.3s	remaining: 1m 47s
# 214:	learn: 0.1096169	total: 29.5s	remaining: 1m 47s
# 215:	learn: 0.1094071	total: 29.6s	remaining: 1m 47s
# 216:	learn: 0.1091245	total: 29.7s	remaining: 1m 47s
# 217:	learn: 0.1089800	total: 29.9s	remaining: 1m 47s
# 218:	learn: 0.1087565	total: 30s	remaining: 1m 47s
# 219:	learn: 0.1085004	total: 30.2s	remaining: 1m 46s
# 220:	learn: 0.1082094	total: 30.3s	remaining: 1m 46s
# 221:	learn: 0.1079786	total: 30.5s	remaining: 1m 46s
# 222:	learn: 0.1078137	total: 30.6s	remaining: 1m 46s
# 223:	learn: 0.1074902	total: 30.8s	remaining: 1m 46s
# 224:	learn: 0.1072884	total: 30.9s	remaining: 1m 46s
# 225:	learn: 0.1071256	total: 31.1s	remaining: 1m 46s
# 226:	learn: 0.1070222	total: 31.2s	remaining: 1m 46s
# 227:	learn: 0.1065746	total: 31.4s	remaining: 1m 46s
# 228:	learn: 0.1064600	total: 31.5s	remaining: 1m 46s
# 229:	learn: 0.1062771	total: 31.7s	remaining: 1m 46s
# 230:	learn: 0.1060522	total: 31.8s	remaining: 1m 45s
# 231:	learn: 0.1058539	total: 32s	remaining: 1m 45s
# 232:	learn: 0.1056387	total: 32.1s	remaining: 1m 45s
# 233:	learn: 0.1053375	total: 32.3s	remaining: 1m 45s
# 234:	learn: 0.1050826	total: 32.4s	remaining: 1m 45s
# 235:	learn: 0.1048670	total: 32.6s	remaining: 1m 45s
# 236:	learn: 0.1046673	total: 32.7s	remaining: 1m 45s
# 237:	learn: 0.1044477	total: 32.9s	remaining: 1m 45s
# 238:	learn: 0.1040985	total: 33s	remaining: 1m 45s
# 239:	learn: 0.1039866	total: 33.2s	remaining: 1m 44s
# 240:	learn: 0.1037783	total: 33.3s	remaining: 1m 44s
# 241:	learn: 0.1036485	total: 33.4s	remaining: 1m 44s
# 242:	learn: 0.1032833	total: 33.6s	remaining: 1m 44s
# 243:	learn: 0.1030642	total: 33.7s	remaining: 1m 44s
# 244:	learn: 0.1029024	total: 33.9s	remaining: 1m 44s
# 245:	learn: 0.1025190	total: 34s	remaining: 1m 44s
# 246:	learn: 0.1022632	total: 34.2s	remaining: 1m 44s
# 247:	learn: 0.1021570	total: 34.3s	remaining: 1m 44s
# 248:	learn: 0.1020376	total: 34.5s	remaining: 1m 43s
# 249:	learn: 0.1018854	total: 34.6s	remaining: 1m 43s
# 250:	learn: 0.1016670	total: 34.8s	remaining: 1m 43s
# 251:	learn: 0.1014413	total: 34.9s	remaining: 1m 43s
# 252:	learn: 0.1012391	total: 35s	remaining: 1m 43s
# 253:	learn: 0.1011119	total: 35.2s	remaining: 1m 43s
# 254:	learn: 0.1009969	total: 35.3s	remaining: 1m 43s
# 255:	learn: 0.1008074	total: 35.5s	remaining: 1m 43s
# 256:	learn: 0.1005794	total: 35.6s	remaining: 1m 43s
# 257:	learn: 0.1003937	total: 35.8s	remaining: 1m 42s
# 258:	learn: 0.1002617	total: 35.9s	remaining: 1m 42s
# 259:	learn: 0.0999745	total: 36.1s	remaining: 1m 42s
# 260:	learn: 0.0997969	total: 36.2s	remaining: 1m 42s
# 261:	learn: 0.0995106	total: 36.4s	remaining: 1m 42s
# 262:	learn: 0.0994163	total: 36.5s	remaining: 1m 42s
# 263:	learn: 0.0992049	total: 36.7s	remaining: 1m 42s
# 264:	learn: 0.0989109	total: 36.8s	remaining: 1m 42s
# 265:	learn: 0.0986852	total: 37s	remaining: 1m 42s
# 266:	learn: 0.0985132	total: 37.1s	remaining: 1m 41s
# 267:	learn: 0.0981689	total: 37.2s	remaining: 1m 41s
# 268:	learn: 0.0980780	total: 37.4s	remaining: 1m 41s
# 269:	learn: 0.0979180	total: 37.5s	remaining: 1m 41s
# 270:	learn: 0.0976890	total: 37.7s	remaining: 1m 41s
# 271:	learn: 0.0975670	total: 37.8s	remaining: 1m 41s
# 272:	learn: 0.0972556	total: 38s	remaining: 1m 41s
# 273:	learn: 0.0970674	total: 38.1s	remaining: 1m 40s
# 274:	learn: 0.0969487	total: 38.3s	remaining: 1m 40s
# 275:	learn: 0.0967264	total: 38.4s	remaining: 1m 40s
# 276:	learn: 0.0966690	total: 38.6s	remaining: 1m 40s
# 277:	learn: 0.0965989	total: 38.7s	remaining: 1m 40s
# 278:	learn: 0.0964748	total: 38.9s	remaining: 1m 40s
# 279:	learn: 0.0962989	total: 39s	remaining: 1m 40s
# 280:	learn: 0.0961677	total: 39.2s	remaining: 1m 40s
# 281:	learn: 0.0959766	total: 39.3s	remaining: 1m 40s
# 282:	learn: 0.0958471	total: 39.4s	remaining: 1m 39s
# 283:	learn: 0.0956686	total: 39.6s	remaining: 1m 39s
# 284:	learn: 0.0954980	total: 39.7s	remaining: 1m 39s
# 285:	learn: 0.0954204	total: 39.8s	remaining: 1m 39s
# 286:	learn: 0.0953375	total: 40s	remaining: 1m 39s
# 287:	learn: 0.0951269	total: 40.1s	remaining: 1m 39s
# 288:	learn: 0.0950423	total: 40.2s	remaining: 1m 38s
# 289:	learn: 0.0948356	total: 40.4s	remaining: 1m 38s
# 290:	learn: 0.0946246	total: 40.5s	remaining: 1m 38s
# 291:	learn: 0.0943609	total: 40.6s	remaining: 1m 38s
# 292:	learn: 0.0942289	total: 40.8s	remaining: 1m 38s
# 293:	learn: 0.0940481	total: 40.9s	remaining: 1m 38s
# 294:	learn: 0.0938795	total: 41.1s	remaining: 1m 38s
# 295:	learn: 0.0935952	total: 41.2s	remaining: 1m 37s
# 296:	learn: 0.0933054	total: 41.3s	remaining: 1m 37s
# 297:	learn: 0.0931583	total: 41.5s	remaining: 1m 37s
# 298:	learn: 0.0930320	total: 41.6s	remaining: 1m 37s
# 299:	learn: 0.0928560	total: 41.7s	remaining: 1m 37s
# 300:	learn: 0.0926614	total: 41.9s	remaining: 1m 37s
# 301:	learn: 0.0925062	total: 42s	remaining: 1m 37s
# 302:	learn: 0.0923368	total: 42.1s	remaining: 1m 36s
# 303:	learn: 0.0921515	total: 42.3s	remaining: 1m 36s
# 304:	learn: 0.0919970	total: 42.4s	remaining: 1m 36s
# 305:	learn: 0.0918846	total: 42.5s	remaining: 1m 36s
# 306:	learn: 0.0917695	total: 42.7s	remaining: 1m 36s
# 307:	learn: 0.0916362	total: 42.8s	remaining: 1m 36s
# 308:	learn: 0.0913819	total: 42.9s	remaining: 1m 36s
# 309:	learn: 0.0911813	total: 43.1s	remaining: 1m 35s
# 310:	learn: 0.0910713	total: 43.2s	remaining: 1m 35s
# 311:	learn: 0.0908767	total: 43.3s	remaining: 1m 35s
# 312:	learn: 0.0907522	total: 43.5s	remaining: 1m 35s
# 313:	learn: 0.0905846	total: 43.6s	remaining: 1m 35s
# 314:	learn: 0.0903134	total: 43.8s	remaining: 1m 35s
# 315:	learn: 0.0902770	total: 43.9s	remaining: 1m 34s
# 316:	learn: 0.0901705	total: 44s	remaining: 1m 34s
# 317:	learn: 0.0900265	total: 44.2s	remaining: 1m 34s
# 318:	learn: 0.0898798	total: 44.3s	remaining: 1m 34s
# 319:	learn: 0.0897735	total: 44.5s	remaining: 1m 34s
# 320:	learn: 0.0895650	total: 44.6s	remaining: 1m 34s
# 321:	learn: 0.0893419	total: 44.7s	remaining: 1m 34s
# 322:	learn: 0.0891220	total: 44.8s	remaining: 1m 34s
# 323:	learn: 0.0889967	total: 45s	remaining: 1m 33s
# 324:	learn: 0.0888863	total: 45.1s	remaining: 1m 33s
# 325:	learn: 0.0888225	total: 45.2s	remaining: 1m 33s
# 326:	learn: 0.0886282	total: 45.4s	remaining: 1m 33s
# 327:	learn: 0.0885118	total: 45.5s	remaining: 1m 33s
# 328:	learn: 0.0883408	total: 45.6s	remaining: 1m 33s
# 329:	learn: 0.0881478	total: 45.8s	remaining: 1m 32s
# 330:	learn: 0.0880690	total: 45.9s	remaining: 1m 32s
# 331:	learn: 0.0878695	total: 46.1s	remaining: 1m 32s
# 332:	learn: 0.0876472	total: 46.2s	remaining: 1m 32s
# 333:	learn: 0.0875499	total: 46.3s	remaining: 1m 32s
# 334:	learn: 0.0873634	total: 46.5s	remaining: 1m 32s
# 335:	learn: 0.0872641	total: 46.6s	remaining: 1m 32s
# 336:	learn: 0.0870984	total: 46.7s	remaining: 1m 31s
# 337:	learn: 0.0869898	total: 46.9s	remaining: 1m 31s
# 338:	learn: 0.0868347	total: 47s	remaining: 1m 31s
# 339:	learn: 0.0867303	total: 47.1s	remaining: 1m 31s
# 340:	learn: 0.0865635	total: 47.3s	remaining: 1m 31s
# 341:	learn: 0.0863351	total: 47.4s	remaining: 1m 31s
# 342:	learn: 0.0861001	total: 47.6s	remaining: 1m 31s
# 343:	learn: 0.0858945	total: 47.7s	remaining: 1m 30s
# 344:	learn: 0.0857668	total: 47.8s	remaining: 1m 30s
# 345:	learn: 0.0856190	total: 48s	remaining: 1m 30s
# 346:	learn: 0.0854738	total: 48.1s	remaining: 1m 30s
# 347:	learn: 0.0854010	total: 48.2s	remaining: 1m 30s
# 348:	learn: 0.0853824	total: 48.3s	remaining: 1m 30s
# 349:	learn: 0.0853110	total: 48.4s	remaining: 1m 29s
# 350:	learn: 0.0851861	total: 48.6s	remaining: 1m 29s
# 351:	learn: 0.0850301	total: 48.7s	remaining: 1m 29s
# 352:	learn: 0.0848374	total: 48.9s	remaining: 1m 29s
# 353:	learn: 0.0847458	total: 49s	remaining: 1m 29s
# 354:	learn: 0.0847391	total: 49s	remaining: 1m 29s
# 355:	learn: 0.0846323	total: 49.2s	remaining: 1m 28s
# 356:	learn: 0.0845607	total: 49.3s	remaining: 1m 28s
# 357:	learn: 0.0843801	total: 49.4s	remaining: 1m 28s
# 358:	learn: 0.0842720	total: 49.6s	remaining: 1m 28s
# 359:	learn: 0.0841854	total: 49.7s	remaining: 1m 28s
# 360:	learn: 0.0840690	total: 49.8s	remaining: 1m 28s
# 361:	learn: 0.0839225	total: 50s	remaining: 1m 28s
# 362:	learn: 0.0837472	total: 50.1s	remaining: 1m 27s
# 363:	learn: 0.0836495	total: 50.2s	remaining: 1m 27s
# 364:	learn: 0.0834191	total: 50.4s	remaining: 1m 27s
# 365:	learn: 0.0832524	total: 50.5s	remaining: 1m 27s
# 366:	learn: 0.0831034	total: 50.6s	remaining: 1m 27s
# 367:	learn: 0.0830298	total: 50.8s	remaining: 1m 27s
# 368:	learn: 0.0829316	total: 50.9s	remaining: 1m 27s
# 369:	learn: 0.0828308	total: 51s	remaining: 1m 26s
# 370:	learn: 0.0827427	total: 51.2s	remaining: 1m 26s
# 371:	learn: 0.0826706	total: 51.3s	remaining: 1m 26s
# 372:	learn: 0.0825621	total: 51.4s	remaining: 1m 26s
# 373:	learn: 0.0824892	total: 51.6s	remaining: 1m 26s
# 374:	learn: 0.0824338	total: 51.7s	remaining: 1m 26s
# 375:	learn: 0.0824161	total: 51.8s	remaining: 1m 25s
# 376:	learn: 0.0822584	total: 51.9s	remaining: 1m 25s
# 377:	learn: 0.0821521	total: 52s	remaining: 1m 25s
# 378:	learn: 0.0820061	total: 52.2s	remaining: 1m 25s
# 379:	learn: 0.0818941	total: 52.3s	remaining: 1m 25s
# 380:	learn: 0.0817492	total: 52.5s	remaining: 1m 25s
# 381:	learn: 0.0816884	total: 52.6s	remaining: 1m 25s
# 382:	learn: 0.0815857	total: 52.7s	remaining: 1m 24s
# 383:	learn: 0.0814333	total: 52.9s	remaining: 1m 24s
# 384:	learn: 0.0813035	total: 53s	remaining: 1m 24s
# 385:	learn: 0.0812160	total: 53.1s	remaining: 1m 24s
# 386:	learn: 0.0811302	total: 53.2s	remaining: 1m 24s
# 387:	learn: 0.0810328	total: 53.4s	remaining: 1m 24s
# 388:	learn: 0.0809252	total: 53.5s	remaining: 1m 24s
# 389:	learn: 0.0808758	total: 53.7s	remaining: 1m 23s
# 390:	learn: 0.0807434	total: 53.8s	remaining: 1m 23s
# 391:	learn: 0.0806718	total: 53.9s	remaining: 1m 23s
# 392:	learn: 0.0805134	total: 54.1s	remaining: 1m 23s
# 393:	learn: 0.0804115	total: 54.2s	remaining: 1m 23s
# 394:	learn: 0.0802115	total: 54.3s	remaining: 1m 23s
# 395:	learn: 0.0801450	total: 54.5s	remaining: 1m 23s
# 396:	learn: 0.0800274	total: 54.6s	remaining: 1m 22s
# 397:	learn: 0.0799613	total: 54.7s	remaining: 1m 22s
# 398:	learn: 0.0797638	total: 54.9s	remaining: 1m 22s
# 399:	learn: 0.0797160	total: 55s	remaining: 1m 22s
# 400:	learn: 0.0796026	total: 55.1s	remaining: 1m 22s
# 401:	learn: 0.0795114	total: 55.3s	remaining: 1m 22s
# 402:	learn: 0.0794236	total: 55.4s	remaining: 1m 22s
# 403:	learn: 0.0794024	total: 55.5s	remaining: 1m 21s
# 404:	learn: 0.0792093	total: 55.7s	remaining: 1m 21s
# 405:	learn: 0.0790735	total: 55.8s	remaining: 1m 21s
# 406:	learn: 0.0789776	total: 55.9s	remaining: 1m 21s
# 407:	learn: 0.0788849	total: 56.1s	remaining: 1m 21s
# 408:	learn: 0.0788232	total: 56.2s	remaining: 1m 21s
# 409:	learn: 0.0787402	total: 56.3s	remaining: 1m 21s
# 410:	learn: 0.0785624	total: 56.5s	remaining: 1m 20s
# 411:	learn: 0.0784614	total: 56.6s	remaining: 1m 20s
# 412:	learn: 0.0784321	total: 56.7s	remaining: 1m 20s
# 413:	learn: 0.0782703	total: 56.9s	remaining: 1m 20s
# 414:	learn: 0.0781757	total: 57s	remaining: 1m 20s
# 415:	learn: 0.0780854	total: 57.1s	remaining: 1m 20s
# 416:	learn: 0.0780133	total: 57.3s	remaining: 1m 20s
# 417:	learn: 0.0778468	total: 57.4s	remaining: 1m 19s
# 418:	learn: 0.0777418	total: 57.5s	remaining: 1m 19s
# 419:	learn: 0.0776065	total: 57.7s	remaining: 1m 19s
# 420:	learn: 0.0775004	total: 57.8s	remaining: 1m 19s
# 421:	learn: 0.0773326	total: 57.9s	remaining: 1m 19s
# 422:	learn: 0.0771865	total: 58.1s	remaining: 1m 19s
# 423:	learn: 0.0770546	total: 58.2s	remaining: 1m 19s
# 424:	learn: 0.0769447	total: 58.3s	remaining: 1m 18s
# 425:	learn: 0.0768521	total: 58.5s	remaining: 1m 18s
# 426:	learn: 0.0767009	total: 58.6s	remaining: 1m 18s
# 427:	learn: 0.0766302	total: 58.8s	remaining: 1m 18s
# 428:	learn: 0.0764858	total: 58.9s	remaining: 1m 18s
# 429:	learn: 0.0763791	total: 59s	remaining: 1m 18s
# 430:	learn: 0.0762598	total: 59.1s	remaining: 1m 18s
# 431:	learn: 0.0762007	total: 59.3s	remaining: 1m 17s
# 432:	learn: 0.0761409	total: 59.4s	remaining: 1m 17s
# 433:	learn: 0.0760852	total: 59.6s	remaining: 1m 17s
# 434:	learn: 0.0759853	total: 59.7s	remaining: 1m 17s
# 435:	learn: 0.0758799	total: 59.8s	remaining: 1m 17s
# 436:	learn: 0.0756753	total: 60s	remaining: 1m 17s
# 437:	learn: 0.0755561	total: 1m	remaining: 1m 17s
# 438:	learn: 0.0754369	total: 1m	remaining: 1m 16s
# 439:	learn: 0.0752599	total: 1m	remaining: 1m 16s
# 440:	learn: 0.0751873	total: 1m	remaining: 1m 16s
# 441:	learn: 0.0750840	total: 1m	remaining: 1m 16s
# 442:	learn: 0.0750292	total: 1m	remaining: 1m 16s
# 443:	learn: 0.0748718	total: 1m	remaining: 1m 16s
# 444:	learn: 0.0747509	total: 1m 1s	remaining: 1m 16s
# 445:	learn: 0.0747267	total: 1m 1s	remaining: 1m 15s
# 446:	learn: 0.0746663	total: 1m 1s	remaining: 1m 15s
# 447:	learn: 0.0745668	total: 1m 1s	remaining: 1m 15s
# 448:	learn: 0.0744212	total: 1m 1s	remaining: 1m 15s
# 449:	learn: 0.0742749	total: 1m 1s	remaining: 1m 15s
# 450:	learn: 0.0741397	total: 1m 1s	remaining: 1m 15s
# 451:	learn: 0.0740880	total: 1m 2s	remaining: 1m 15s
# 452:	learn: 0.0740144	total: 1m 2s	remaining: 1m 15s
# 453:	learn: 0.0738349	total: 1m 2s	remaining: 1m 14s
# 454:	learn: 0.0737617	total: 1m 2s	remaining: 1m 14s
# 455:	learn: 0.0736737	total: 1m 2s	remaining: 1m 14s
# 456:	learn: 0.0736012	total: 1m 2s	remaining: 1m 14s
# 457:	learn: 0.0735112	total: 1m 2s	remaining: 1m 14s
# 458:	learn: 0.0734229	total: 1m 2s	remaining: 1m 14s
# 459:	learn: 0.0732774	total: 1m 3s	remaining: 1m 14s
# 460:	learn: 0.0732047	total: 1m 3s	remaining: 1m 13s
# 461:	learn: 0.0731496	total: 1m 3s	remaining: 1m 13s
# 462:	learn: 0.0730670	total: 1m 3s	remaining: 1m 13s
# 463:	learn: 0.0729686	total: 1m 3s	remaining: 1m 13s
# 464:	learn: 0.0728965	total: 1m 3s	remaining: 1m 13s
# 465:	learn: 0.0727302	total: 1m 3s	remaining: 1m 13s
# 466:	learn: 0.0725997	total: 1m 4s	remaining: 1m 13s
# 467:	learn: 0.0725543	total: 1m 4s	remaining: 1m 12s
# 468:	learn: 0.0724689	total: 1m 4s	remaining: 1m 12s
# 469:	learn: 0.0724573	total: 1m 4s	remaining: 1m 12s
# 470:	learn: 0.0723927	total: 1m 4s	remaining: 1m 12s
# 471:	learn: 0.0723297	total: 1m 4s	remaining: 1m 12s
# 472:	learn: 0.0722518	total: 1m 4s	remaining: 1m 12s
# 473:	learn: 0.0720907	total: 1m 4s	remaining: 1m 12s
# 474:	learn: 0.0720299	total: 1m 5s	remaining: 1m 11s
# 475:	learn: 0.0720256	total: 1m 5s	remaining: 1m 11s
# 476:	learn: 0.0719703	total: 1m 5s	remaining: 1m 11s
# 477:	learn: 0.0719165	total: 1m 5s	remaining: 1m 11s
# 478:	learn: 0.0718394	total: 1m 5s	remaining: 1m 11s
# 479:	learn: 0.0718143	total: 1m 5s	remaining: 1m 11s
# 480:	learn: 0.0716567	total: 1m 5s	remaining: 1m 10s
# 481:	learn: 0.0715912	total: 1m 5s	remaining: 1m 10s
# 482:	learn: 0.0715277	total: 1m 6s	remaining: 1m 10s
# 483:	learn: 0.0714689	total: 1m 6s	remaining: 1m 10s
# 484:	learn: 0.0714218	total: 1m 6s	remaining: 1m 10s
# 485:	learn: 0.0713659	total: 1m 6s	remaining: 1m 10s
# 486:	learn: 0.0712458	total: 1m 6s	remaining: 1m 10s
# 487:	learn: 0.0711710	total: 1m 6s	remaining: 1m 9s
# 488:	learn: 0.0711167	total: 1m 6s	remaining: 1m 9s
# 489:	learn: 0.0710137	total: 1m 6s	remaining: 1m 9s
# 490:	learn: 0.0708659	total: 1m 7s	remaining: 1m 9s
# 491:	learn: 0.0707507	total: 1m 7s	remaining: 1m 9s
# 492:	learn: 0.0707031	total: 1m 7s	remaining: 1m 9s
# 493:	learn: 0.0706377	total: 1m 7s	remaining: 1m 9s
# 494:	learn: 0.0705569	total: 1m 7s	remaining: 1m 9s
# 495:	learn: 0.0705074	total: 1m 7s	remaining: 1m 8s
# 496:	learn: 0.0703881	total: 1m 7s	remaining: 1m 8s
# 497:	learn: 0.0702879	total: 1m 8s	remaining: 1m 8s
# 498:	learn: 0.0701820	total: 1m 8s	remaining: 1m 8s
# 499:	learn: 0.0700726	total: 1m 8s	remaining: 1m 8s
# 500:	learn: 0.0699880	total: 1m 8s	remaining: 1m 8s
# 501:	learn: 0.0699146	total: 1m 8s	remaining: 1m 8s
# 502:	learn: 0.0697710	total: 1m 8s	remaining: 1m 7s
# 503:	learn: 0.0697264	total: 1m 8s	remaining: 1m 7s
# 504:	learn: 0.0697087	total: 1m 9s	remaining: 1m 7s
# 505:	learn: 0.0696000	total: 1m 9s	remaining: 1m 7s
# 506:	learn: 0.0694944	total: 1m 9s	remaining: 1m 7s
# 507:	learn: 0.0693569	total: 1m 9s	remaining: 1m 7s
# 508:	learn: 0.0692171	total: 1m 9s	remaining: 1m 7s
# 509:	learn: 0.0691340	total: 1m 9s	remaining: 1m 6s
# 510:	learn: 0.0690306	total: 1m 9s	remaining: 1m 6s
# 511:	learn: 0.0689037	total: 1m 9s	remaining: 1m 6s
# 512:	learn: 0.0688567	total: 1m 10s	remaining: 1m 6s
# 513:	learn: 0.0687407	total: 1m 10s	remaining: 1m 6s
# 514:	learn: 0.0686719	total: 1m 10s	remaining: 1m 6s
# 515:	learn: 0.0685847	total: 1m 10s	remaining: 1m 6s
# 516:	learn: 0.0685147	total: 1m 10s	remaining: 1m 6s
# 517:	learn: 0.0684237	total: 1m 10s	remaining: 1m 5s
# 518:	learn: 0.0683200	total: 1m 10s	remaining: 1m 5s
# 519:	learn: 0.0681707	total: 1m 11s	remaining: 1m 5s
# 520:	learn: 0.0681026	total: 1m 11s	remaining: 1m 5s
# 521:	learn: 0.0680248	total: 1m 11s	remaining: 1m 5s
# 522:	learn: 0.0679850	total: 1m 11s	remaining: 1m 5s
# 523:	learn: 0.0679295	total: 1m 11s	remaining: 1m 5s
# 524:	learn: 0.0678206	total: 1m 11s	remaining: 1m 4s
# 525:	learn: 0.0677045	total: 1m 11s	remaining: 1m 4s
# 526:	learn: 0.0676371	total: 1m 12s	remaining: 1m 4s
# 527:	learn: 0.0675797	total: 1m 12s	remaining: 1m 4s
# 528:	learn: 0.0674364	total: 1m 12s	remaining: 1m 4s
# 529:	learn: 0.0673942	total: 1m 12s	remaining: 1m 4s
# 530:	learn: 0.0673119	total: 1m 12s	remaining: 1m 4s
# 531:	learn: 0.0672626	total: 1m 12s	remaining: 1m 3s
# 532:	learn: 0.0671468	total: 1m 12s	remaining: 1m 3s
# 533:	learn: 0.0671125	total: 1m 12s	remaining: 1m 3s
# 534:	learn: 0.0670509	total: 1m 13s	remaining: 1m 3s
# 535:	learn: 0.0669915	total: 1m 13s	remaining: 1m 3s
# 536:	learn: 0.0669157	total: 1m 13s	remaining: 1m 3s
# 537:	learn: 0.0667950	total: 1m 13s	remaining: 1m 3s
# 538:	learn: 0.0667404	total: 1m 13s	remaining: 1m 2s
# 539:	learn: 0.0667065	total: 1m 13s	remaining: 1m 2s
# 540:	learn: 0.0666238	total: 1m 13s	remaining: 1m 2s
# 541:	learn: 0.0665530	total: 1m 14s	remaining: 1m 2s
# 542:	learn: 0.0664735	total: 1m 14s	remaining: 1m 2s
# 543:	learn: 0.0664093	total: 1m 14s	remaining: 1m 2s
# 544:	learn: 0.0663678	total: 1m 14s	remaining: 1m 2s
# 545:	learn: 0.0662967	total: 1m 14s	remaining: 1m 2s
# 546:	learn: 0.0662525	total: 1m 14s	remaining: 1m 1s
# 547:	learn: 0.0661546	total: 1m 14s	remaining: 1m 1s
# 548:	learn: 0.0661166	total: 1m 15s	remaining: 1m 1s
# 549:	learn: 0.0660527	total: 1m 15s	remaining: 1m 1s
# 550:	learn: 0.0659837	total: 1m 15s	remaining: 1m 1s
# 551:	learn: 0.0659019	total: 1m 15s	remaining: 1m 1s
# 552:	learn: 0.0658232	total: 1m 15s	remaining: 1m 1s
# 553:	learn: 0.0657416	total: 1m 15s	remaining: 1m
# 554:	learn: 0.0656739	total: 1m 15s	remaining: 1m
# 555:	learn: 0.0655693	total: 1m 15s	remaining: 1m
# 556:	learn: 0.0655208	total: 1m 16s	remaining: 1m
# 557:	learn: 0.0654359	total: 1m 16s	remaining: 1m
# 558:	learn: 0.0653236	total: 1m 16s	remaining: 1m
# 559:	learn: 0.0652590	total: 1m 16s	remaining: 1m
# 560:	learn: 0.0652151	total: 1m 16s	remaining: 1m
# 561:	learn: 0.0651440	total: 1m 16s	remaining: 59.9s
# 562:	learn: 0.0650337	total: 1m 16s	remaining: 59.7s
# 563:	learn: 0.0650032	total: 1m 17s	remaining: 59.6s
# 564:	learn: 0.0649453	total: 1m 17s	remaining: 59.5s
# 565:	learn: 0.0648754	total: 1m 17s	remaining: 59.3s
# 566:	learn: 0.0648338	total: 1m 17s	remaining: 59.2s
# 567:	learn: 0.0647436	total: 1m 17s	remaining: 59.1s
# 568:	learn: 0.0646818	total: 1m 17s	remaining: 58.9s
# 569:	learn: 0.0646443	total: 1m 17s	remaining: 58.8s
# 570:	learn: 0.0645898	total: 1m 18s	remaining: 58.6s
# 571:	learn: 0.0644893	total: 1m 18s	remaining: 58.5s
# 572:	learn: 0.0644139	total: 1m 18s	remaining: 58.4s
# 573:	learn: 0.0643261	total: 1m 18s	remaining: 58.2s
# 574:	learn: 0.0642099	total: 1m 18s	remaining: 58.1s
# 575:	learn: 0.0640942	total: 1m 18s	remaining: 58s
# 576:	learn: 0.0640026	total: 1m 18s	remaining: 57.8s
# 577:	learn: 0.0639572	total: 1m 19s	remaining: 57.7s
# 578:	learn: 0.0637902	total: 1m 19s	remaining: 57.6s
# 579:	learn: 0.0637206	total: 1m 19s	remaining: 57.4s
# 580:	learn: 0.0636105	total: 1m 19s	remaining: 57.3s
# 581:	learn: 0.0635378	total: 1m 19s	remaining: 57.1s
# 582:	learn: 0.0633774	total: 1m 19s	remaining: 57s
# 583:	learn: 0.0632543	total: 1m 19s	remaining: 56.9s
# 584:	learn: 0.0631709	total: 1m 19s	remaining: 56.7s
# 585:	learn: 0.0630862	total: 1m 20s	remaining: 56.6s
# 586:	learn: 0.0629716	total: 1m 20s	remaining: 56.5s
# 587:	learn: 0.0629019	total: 1m 20s	remaining: 56.3s
# 588:	learn: 0.0628507	total: 1m 20s	remaining: 56.2s
# 589:	learn: 0.0628121	total: 1m 20s	remaining: 56s
# 590:	learn: 0.0627223	total: 1m 20s	remaining: 55.9s
# 591:	learn: 0.0626635	total: 1m 20s	remaining: 55.8s
# 592:	learn: 0.0625815	total: 1m 21s	remaining: 55.6s
# 593:	learn: 0.0625047	total: 1m 21s	remaining: 55.5s
# 594:	learn: 0.0624528	total: 1m 21s	remaining: 55.4s
# 595:	learn: 0.0623719	total: 1m 21s	remaining: 55.2s
# 596:	learn: 0.0622591	total: 1m 21s	remaining: 55.1s
# 597:	learn: 0.0622184	total: 1m 21s	remaining: 54.9s
# 598:	learn: 0.0621536	total: 1m 21s	remaining: 54.8s
# 599:	learn: 0.0621120	total: 1m 21s	remaining: 54.7s
# 600:	learn: 0.0620299	total: 1m 22s	remaining: 54.5s
# 601:	learn: 0.0619418	total: 1m 22s	remaining: 54.4s
# 602:	learn: 0.0618982	total: 1m 22s	remaining: 54.3s
# 603:	learn: 0.0618506	total: 1m 22s	remaining: 54.1s
# 604:	learn: 0.0617971	total: 1m 22s	remaining: 54s
# 605:	learn: 0.0617470	total: 1m 22s	remaining: 53.8s
# 606:	learn: 0.0617233	total: 1m 22s	remaining: 53.7s
# 607:	learn: 0.0616712	total: 1m 23s	remaining: 53.6s
# 608:	learn: 0.0616381	total: 1m 23s	remaining: 53.4s
# 609:	learn: 0.0615791	total: 1m 23s	remaining: 53.3s
# 610:	learn: 0.0615042	total: 1m 23s	remaining: 53.2s
# 611:	learn: 0.0614187	total: 1m 23s	remaining: 53s
# 612:	learn: 0.0613900	total: 1m 23s	remaining: 52.9s
# 613:	learn: 0.0613360	total: 1m 23s	remaining: 52.7s
# 614:	learn: 0.0612574	total: 1m 24s	remaining: 52.6s
# 615:	learn: 0.0611484	total: 1m 24s	remaining: 52.5s
# 616:	learn: 0.0610879	total: 1m 24s	remaining: 52.3s
# 617:	learn: 0.0610319	total: 1m 24s	remaining: 52.2s
# 618:	learn: 0.0609829	total: 1m 24s	remaining: 52.1s
# 619:	learn: 0.0609448	total: 1m 24s	remaining: 51.9s
# 620:	learn: 0.0609189	total: 1m 24s	remaining: 51.8s
# 621:	learn: 0.0608390	total: 1m 25s	remaining: 51.7s
# 622:	learn: 0.0607457	total: 1m 25s	remaining: 51.5s
# 623:	learn: 0.0606989	total: 1m 25s	remaining: 51.4s
# 624:	learn: 0.0606668	total: 1m 25s	remaining: 51.3s
# 625:	learn: 0.0605817	total: 1m 25s	remaining: 51.1s
# 626:	learn: 0.0605443	total: 1m 25s	remaining: 51s
# 627:	learn: 0.0604996	total: 1m 25s	remaining: 50.9s
# 628:	learn: 0.0604391	total: 1m 25s	remaining: 50.7s
# 629:	learn: 0.0603643	total: 1m 26s	remaining: 50.6s
# 630:	learn: 0.0603308	total: 1m 26s	remaining: 50.4s
# 631:	learn: 0.0602435	total: 1m 26s	remaining: 50.3s
# 632:	learn: 0.0602069	total: 1m 26s	remaining: 50.2s
# 633:	learn: 0.0601534	total: 1m 26s	remaining: 50s
# 634:	learn: 0.0601142	total: 1m 26s	remaining: 49.9s
# 635:	learn: 0.0600309	total: 1m 26s	remaining: 49.8s
# 636:	learn: 0.0599573	total: 1m 27s	remaining: 49.6s
# 637:	learn: 0.0599174	total: 1m 27s	remaining: 49.5s
# 638:	learn: 0.0598314	total: 1m 27s	remaining: 49.4s
# 639:	learn: 0.0597708	total: 1m 27s	remaining: 49.2s
# 640:	learn: 0.0596633	total: 1m 27s	remaining: 49.1s
# 641:	learn: 0.0596017	total: 1m 27s	remaining: 48.9s
# 642:	learn: 0.0595513	total: 1m 27s	remaining: 48.8s
# 643:	learn: 0.0594113	total: 1m 28s	remaining: 48.7s
# 644:	learn: 0.0593672	total: 1m 28s	remaining: 48.5s
# 645:	learn: 0.0593220	total: 1m 28s	remaining: 48.4s
# 646:	learn: 0.0592473	total: 1m 28s	remaining: 48.3s
# 647:	learn: 0.0591841	total: 1m 28s	remaining: 48.1s
# 648:	learn: 0.0591089	total: 1m 28s	remaining: 48s
# 649:	learn: 0.0590633	total: 1m 28s	remaining: 47.8s
# 650:	learn: 0.0590196	total: 1m 28s	remaining: 47.7s
# 651:	learn: 0.0589852	total: 1m 29s	remaining: 47.6s
# 652:	learn: 0.0589517	total: 1m 29s	remaining: 47.4s
# 653:	learn: 0.0589016	total: 1m 29s	remaining: 47.3s
# 654:	learn: 0.0588230	total: 1m 29s	remaining: 47.2s
# 655:	learn: 0.0587756	total: 1m 29s	remaining: 47s
# 656:	learn: 0.0587182	total: 1m 29s	remaining: 46.9s
# 657:	learn: 0.0586422	total: 1m 29s	remaining: 46.7s
# 658:	learn: 0.0586199	total: 1m 30s	remaining: 46.6s
# 659:	learn: 0.0585572	total: 1m 30s	remaining: 46.5s
# 660:	learn: 0.0584493	total: 1m 30s	remaining: 46.3s
# 661:	learn: 0.0583545	total: 1m 30s	remaining: 46.2s
# 662:	learn: 0.0583033	total: 1m 30s	remaining: 46.1s
# 663:	learn: 0.0582697	total: 1m 30s	remaining: 45.9s
# 664:	learn: 0.0582317	total: 1m 30s	remaining: 45.8s
# 665:	learn: 0.0581786	total: 1m 30s	remaining: 45.6s
# 666:	learn: 0.0581294	total: 1m 31s	remaining: 45.5s
# 667:	learn: 0.0580896	total: 1m 31s	remaining: 45.4s
# 668:	learn: 0.0579853	total: 1m 31s	remaining: 45.3s
# 669:	learn: 0.0579104	total: 1m 31s	remaining: 45.1s
# 670:	learn: 0.0578544	total: 1m 31s	remaining: 45s
# 671:	learn: 0.0577920	total: 1m 31s	remaining: 44.8s
# 672:	learn: 0.0577239	total: 1m 32s	remaining: 44.7s
# 673:	learn: 0.0576879	total: 1m 32s	remaining: 44.6s
# 674:	learn: 0.0576281	total: 1m 32s	remaining: 44.5s
# 675:	learn: 0.0576203	total: 1m 32s	remaining: 44.3s
# 676:	learn: 0.0576005	total: 1m 32s	remaining: 44.1s
# 677:	learn: 0.0575223	total: 1m 32s	remaining: 44s
# 678:	learn: 0.0574435	total: 1m 32s	remaining: 43.9s
# 679:	learn: 0.0573542	total: 1m 32s	remaining: 43.7s
# 680:	learn: 0.0572780	total: 1m 33s	remaining: 43.6s
# 681:	learn: 0.0571668	total: 1m 33s	remaining: 43.5s
# 682:	learn: 0.0570687	total: 1m 33s	remaining: 43.3s
# 683:	learn: 0.0570303	total: 1m 33s	remaining: 43.2s
# 684:	learn: 0.0569923	total: 1m 33s	remaining: 43.1s
# 685:	learn: 0.0569274	total: 1m 33s	remaining: 42.9s
# 686:	learn: 0.0568803	total: 1m 33s	remaining: 42.8s
# 687:	learn: 0.0567351	total: 1m 34s	remaining: 42.6s
# 688:	learn: 0.0566564	total: 1m 34s	remaining: 42.5s
# 689:	learn: 0.0565962	total: 1m 34s	remaining: 42.4s
# 690:	learn: 0.0565595	total: 1m 34s	remaining: 42.2s
# 691:	learn: 0.0565092	total: 1m 34s	remaining: 42.1s
# 692:	learn: 0.0564562	total: 1m 34s	remaining: 42s
# 693:	learn: 0.0564068	total: 1m 34s	remaining: 41.8s
# 694:	learn: 0.0563504	total: 1m 34s	remaining: 41.7s
# 695:	learn: 0.0563177	total: 1m 35s	remaining: 41.5s
# 696:	learn: 0.0562817	total: 1m 35s	remaining: 41.4s
# 697:	learn: 0.0562276	total: 1m 35s	remaining: 41.3s
# 698:	learn: 0.0561397	total: 1m 35s	remaining: 41.1s
# 699:	learn: 0.0561015	total: 1m 35s	remaining: 41s
# 700:	learn: 0.0560525	total: 1m 35s	remaining: 40.9s
# 701:	learn: 0.0559748	total: 1m 35s	remaining: 40.7s
# 702:	learn: 0.0558694	total: 1m 36s	remaining: 40.6s
# 703:	learn: 0.0558264	total: 1m 36s	remaining: 40.5s
# 704:	learn: 0.0557722	total: 1m 36s	remaining: 40.3s
# 705:	learn: 0.0557085	total: 1m 36s	remaining: 40.2s
# 706:	learn: 0.0556726	total: 1m 36s	remaining: 40.1s
# 707:	learn: 0.0556018	total: 1m 36s	remaining: 39.9s
# 708:	learn: 0.0555501	total: 1m 36s	remaining: 39.8s
# 709:	learn: 0.0555146	total: 1m 37s	remaining: 39.6s
# 710:	learn: 0.0554546	total: 1m 37s	remaining: 39.5s
# 711:	learn: 0.0553775	total: 1m 37s	remaining: 39.4s
# 712:	learn: 0.0553483	total: 1m 37s	remaining: 39.2s
# 713:	learn: 0.0552906	total: 1m 37s	remaining: 39.1s
# 714:	learn: 0.0552627	total: 1m 37s	remaining: 39s
# 715:	learn: 0.0552008	total: 1m 37s	remaining: 38.8s
# 716:	learn: 0.0551623	total: 1m 38s	remaining: 38.7s
# 717:	learn: 0.0550662	total: 1m 38s	remaining: 38.5s
# 718:	learn: 0.0550264	total: 1m 38s	remaining: 38.4s
# 719:	learn: 0.0550080	total: 1m 38s	remaining: 38.3s
# 720:	learn: 0.0549391	total: 1m 38s	remaining: 38.1s
# 721:	learn: 0.0548822	total: 1m 38s	remaining: 38s
# 722:	learn: 0.0548064	total: 1m 38s	remaining: 37.9s
# 723:	learn: 0.0547558	total: 1m 38s	remaining: 37.7s
# 724:	learn: 0.0547037	total: 1m 39s	remaining: 37.6s
# 725:	learn: 0.0546751	total: 1m 39s	remaining: 37.5s
# 726:	learn: 0.0546029	total: 1m 39s	remaining: 37.3s
# 727:	learn: 0.0545497	total: 1m 39s	remaining: 37.2s
# 728:	learn: 0.0544981	total: 1m 39s	remaining: 37s
# 729:	learn: 0.0544473	total: 1m 39s	remaining: 36.9s
# 730:	learn: 0.0543960	total: 1m 39s	remaining: 36.8s
# 731:	learn: 0.0543107	total: 1m 40s	remaining: 36.6s
# 732:	learn: 0.0542686	total: 1m 40s	remaining: 36.5s
# 733:	learn: 0.0542195	total: 1m 40s	remaining: 36.4s
# 734:	learn: 0.0541849	total: 1m 40s	remaining: 36.2s
# 735:	learn: 0.0541556	total: 1m 40s	remaining: 36.1s
# 736:	learn: 0.0541172	total: 1m 40s	remaining: 35.9s
# 737:	learn: 0.0540440	total: 1m 40s	remaining: 35.8s
# 738:	learn: 0.0539472	total: 1m 41s	remaining: 35.7s
# 739:	learn: 0.0538861	total: 1m 41s	remaining: 35.5s
# 740:	learn: 0.0538464	total: 1m 41s	remaining: 35.4s
# 741:	learn: 0.0538043	total: 1m 41s	remaining: 35.3s
# 742:	learn: 0.0537626	total: 1m 41s	remaining: 35.1s
# 743:	learn: 0.0537285	total: 1m 41s	remaining: 35s
# 744:	learn: 0.0536864	total: 1m 41s	remaining: 34.8s
# 745:	learn: 0.0536320	total: 1m 41s	remaining: 34.7s
# 746:	learn: 0.0535549	total: 1m 42s	remaining: 34.6s
# 747:	learn: 0.0534845	total: 1m 42s	remaining: 34.4s
# 748:	learn: 0.0534381	total: 1m 42s	remaining: 34.3s
# 749:	learn: 0.0533759	total: 1m 42s	remaining: 34.2s
# 750:	learn: 0.0533426	total: 1m 42s	remaining: 34s
# 751:	learn: 0.0532726	total: 1m 42s	remaining: 33.9s
# 752:	learn: 0.0531961	total: 1m 42s	remaining: 33.8s
# 753:	learn: 0.0531760	total: 1m 43s	remaining: 33.6s
# 754:	learn: 0.0531406	total: 1m 43s	remaining: 33.5s
# 755:	learn: 0.0530896	total: 1m 43s	remaining: 33.3s
# 756:	learn: 0.0530434	total: 1m 43s	remaining: 33.2s
# 757:	learn: 0.0529805	total: 1m 43s	remaining: 33.1s
# 758:	learn: 0.0529564	total: 1m 43s	remaining: 32.9s
# 759:	learn: 0.0529073	total: 1m 43s	remaining: 32.8s
# 760:	learn: 0.0528510	total: 1m 43s	remaining: 32.7s
# 761:	learn: 0.0527845	total: 1m 44s	remaining: 32.5s
# 762:	learn: 0.0527517	total: 1m 44s	remaining: 32.4s
# 763:	learn: 0.0527013	total: 1m 44s	remaining: 32.2s
# 764:	learn: 0.0526615	total: 1m 44s	remaining: 32.1s
# 765:	learn: 0.0526209	total: 1m 44s	remaining: 32s
# 766:	learn: 0.0525675	total: 1m 44s	remaining: 31.8s
# 767:	learn: 0.0525075	total: 1m 44s	remaining: 31.7s
# 768:	learn: 0.0524599	total: 1m 45s	remaining: 31.6s
# 769:	learn: 0.0524081	total: 1m 45s	remaining: 31.4s
# 770:	learn: 0.0523635	total: 1m 45s	remaining: 31.3s
# 771:	learn: 0.0522781	total: 1m 45s	remaining: 31.2s
# 772:	learn: 0.0522531	total: 1m 45s	remaining: 31s
# 773:	learn: 0.0521934	total: 1m 45s	remaining: 30.9s
# 774:	learn: 0.0520968	total: 1m 45s	remaining: 30.7s
# 775:	learn: 0.0520350	total: 1m 46s	remaining: 30.6s
# 776:	learn: 0.0519873	total: 1m 46s	remaining: 30.5s
# 777:	learn: 0.0519520	total: 1m 46s	remaining: 30.3s
# 778:	learn: 0.0518479	total: 1m 46s	remaining: 30.2s
# 779:	learn: 0.0518177	total: 1m 46s	remaining: 30.1s
# 780:	learn: 0.0517733	total: 1m 46s	remaining: 29.9s
# 781:	learn: 0.0517270	total: 1m 46s	remaining: 29.8s
# 782:	learn: 0.0516716	total: 1m 47s	remaining: 29.7s
# 783:	learn: 0.0516120	total: 1m 47s	remaining: 29.5s
# 784:	learn: 0.0515495	total: 1m 47s	remaining: 29.4s
# 785:	learn: 0.0515178	total: 1m 47s	remaining: 29.2s
# 786:	learn: 0.0514927	total: 1m 47s	remaining: 29.1s
# 787:	learn: 0.0514545	total: 1m 47s	remaining: 29s
# 788:	learn: 0.0514067	total: 1m 47s	remaining: 28.8s
# 789:	learn: 0.0513347	total: 1m 47s	remaining: 28.7s
# 790:	learn: 0.0512598	total: 1m 48s	remaining: 28.6s
# 791:	learn: 0.0511789	total: 1m 48s	remaining: 28.4s
# 792:	learn: 0.0511547	total: 1m 48s	remaining: 28.3s
# 793:	learn: 0.0511071	total: 1m 48s	remaining: 28.2s
# 794:	learn: 0.0510404	total: 1m 48s	remaining: 28s
# 795:	learn: 0.0509599	total: 1m 48s	remaining: 27.9s
# 796:	learn: 0.0508643	total: 1m 48s	remaining: 27.7s
# 797:	learn: 0.0508421	total: 1m 49s	remaining: 27.6s
# 798:	learn: 0.0507708	total: 1m 49s	remaining: 27.5s
# 799:	learn: 0.0507492	total: 1m 49s	remaining: 27.3s
# 800:	learn: 0.0506918	total: 1m 49s	remaining: 27.2s
# 801:	learn: 0.0506640	total: 1m 49s	remaining: 27.1s
# 802:	learn: 0.0506112	total: 1m 49s	remaining: 26.9s
# 803:	learn: 0.0505676	total: 1m 49s	remaining: 26.8s
# 804:	learn: 0.0505419	total: 1m 50s	remaining: 26.6s
# 805:	learn: 0.0505054	total: 1m 50s	remaining: 26.5s
# 806:	learn: 0.0504705	total: 1m 50s	remaining: 26.4s
# 807:	learn: 0.0503961	total: 1m 50s	remaining: 26.2s
# 808:	learn: 0.0503660	total: 1m 50s	remaining: 26.1s
# 809:	learn: 0.0503195	total: 1m 50s	remaining: 26s
# 810:	learn: 0.0502836	total: 1m 50s	remaining: 25.8s
# 811:	learn: 0.0502037	total: 1m 50s	remaining: 25.7s
# 812:	learn: 0.0501588	total: 1m 51s	remaining: 25.6s
# 813:	learn: 0.0501116	total: 1m 51s	remaining: 25.4s
# 814:	learn: 0.0500482	total: 1m 51s	remaining: 25.3s
# 815:	learn: 0.0500094	total: 1m 51s	remaining: 25.2s
# 816:	learn: 0.0499618	total: 1m 51s	remaining: 25s
# 817:	learn: 0.0499389	total: 1m 51s	remaining: 24.9s
# 818:	learn: 0.0499009	total: 1m 51s	remaining: 24.7s
# 819:	learn: 0.0498664	total: 1m 52s	remaining: 24.6s
# 820:	learn: 0.0498014	total: 1m 52s	remaining: 24.5s
# 821:	learn: 0.0497575	total: 1m 52s	remaining: 24.3s
# 822:	learn: 0.0497006	total: 1m 52s	remaining: 24.2s
# 823:	learn: 0.0496595	total: 1m 52s	remaining: 24.1s
# 824:	learn: 0.0496334	total: 1m 52s	remaining: 23.9s
# 825:	learn: 0.0495757	total: 1m 52s	remaining: 23.8s
# 826:	learn: 0.0495293	total: 1m 53s	remaining: 23.6s
# 827:	learn: 0.0494860	total: 1m 53s	remaining: 23.5s
# 828:	learn: 0.0494622	total: 1m 53s	remaining: 23.4s
# 829:	learn: 0.0494362	total: 1m 53s	remaining: 23.2s
# 830:	learn: 0.0493989	total: 1m 53s	remaining: 23.1s
# 831:	learn: 0.0493370	total: 1m 53s	remaining: 23s
# 832:	learn: 0.0492791	total: 1m 53s	remaining: 22.8s
# 833:	learn: 0.0492362	total: 1m 54s	remaining: 22.7s
# 834:	learn: 0.0491975	total: 1m 54s	remaining: 22.6s
# 835:	learn: 0.0491667	total: 1m 54s	remaining: 22.4s
# 836:	learn: 0.0491390	total: 1m 54s	remaining: 22.3s
# 837:	learn: 0.0491037	total: 1m 54s	remaining: 22.2s
# 838:	learn: 0.0490536	total: 1m 54s	remaining: 22s
# 839:	learn: 0.0490231	total: 1m 54s	remaining: 21.9s
# 840:	learn: 0.0489997	total: 1m 55s	remaining: 21.7s
# 841:	learn: 0.0489444	total: 1m 55s	remaining: 21.6s
# 842:	learn: 0.0489018	total: 1m 55s	remaining: 21.5s
# 843:	learn: 0.0488781	total: 1m 55s	remaining: 21.3s
# 844:	learn: 0.0488160	total: 1m 55s	remaining: 21.2s
# 845:	learn: 0.0487833	total: 1m 55s	remaining: 21.1s
# 846:	learn: 0.0487702	total: 1m 55s	remaining: 20.9s
# 847:	learn: 0.0487144	total: 1m 55s	remaining: 20.8s
# 848:	learn: 0.0486621	total: 1m 56s	remaining: 20.7s
# 849:	learn: 0.0486035	total: 1m 56s	remaining: 20.5s
# 850:	learn: 0.0485566	total: 1m 56s	remaining: 20.4s
# 851:	learn: 0.0485404	total: 1m 56s	remaining: 20.2s
# 852:	learn: 0.0485100	total: 1m 56s	remaining: 20.1s
# 853:	learn: 0.0484404	total: 1m 56s	remaining: 20s
# 854:	learn: 0.0483706	total: 1m 56s	remaining: 19.8s
# 855:	learn: 0.0483230	total: 1m 57s	remaining: 19.7s
# 856:	learn: 0.0482825	total: 1m 57s	remaining: 19.6s
# 857:	learn: 0.0482423	total: 1m 57s	remaining: 19.4s
# 858:	learn: 0.0481735	total: 1m 57s	remaining: 19.3s
# 859:	learn: 0.0481244	total: 1m 57s	remaining: 19.2s
# 860:	learn: 0.0480825	total: 1m 57s	remaining: 19s
# 861:	learn: 0.0480581	total: 1m 57s	remaining: 18.9s
# 862:	learn: 0.0480063	total: 1m 58s	remaining: 18.7s
# 863:	learn: 0.0479766	total: 1m 58s	remaining: 18.6s
# 864:	learn: 0.0479520	total: 1m 58s	remaining: 18.5s
# 865:	learn: 0.0479181	total: 1m 58s	remaining: 18.3s
# 866:	learn: 0.0478890	total: 1m 58s	remaining: 18.2s
# 867:	learn: 0.0478362	total: 1m 58s	remaining: 18.1s
# 868:	learn: 0.0477922	total: 1m 58s	remaining: 17.9s
# 869:	learn: 0.0477292	total: 1m 59s	remaining: 17.8s
# 870:	learn: 0.0476744	total: 1m 59s	remaining: 17.6s
# 871:	learn: 0.0476437	total: 1m 59s	remaining: 17.5s
# 872:	learn: 0.0475822	total: 1m 59s	remaining: 17.4s
# 873:	learn: 0.0474861	total: 1m 59s	remaining: 17.2s
# 874:	learn: 0.0474546	total: 1m 59s	remaining: 17.1s
# 875:	learn: 0.0474013	total: 1m 59s	remaining: 17s
# 876:	learn: 0.0473517	total: 2m	remaining: 16.8s
# 877:	learn: 0.0473047	total: 2m	remaining: 16.7s
# 878:	learn: 0.0472753	total: 2m	remaining: 16.6s
# 879:	learn: 0.0472338	total: 2m	remaining: 16.4s
# 880:	learn: 0.0471841	total: 2m	remaining: 16.3s
# 881:	learn: 0.0471551	total: 2m	remaining: 16.1s
# 882:	learn: 0.0471332	total: 2m	remaining: 16s
# 883:	learn: 0.0470947	total: 2m	remaining: 15.9s
# 884:	learn: 0.0470709	total: 2m 1s	remaining: 15.7s
# 885:	learn: 0.0470585	total: 2m 1s	remaining: 15.6s
# 886:	learn: 0.0469850	total: 2m 1s	remaining: 15.5s
# 887:	learn: 0.0469245	total: 2m 1s	remaining: 15.3s
# 888:	learn: 0.0468504	total: 2m 1s	remaining: 15.2s
# 889:	learn: 0.0467946	total: 2m 1s	remaining: 15.1s
# 890:	learn: 0.0467762	total: 2m 1s	remaining: 14.9s
# 891:	learn: 0.0467583	total: 2m 2s	remaining: 14.8s
# 892:	learn: 0.0466995	total: 2m 2s	remaining: 14.6s
# 893:	learn: 0.0466429	total: 2m 2s	remaining: 14.5s
# 894:	learn: 0.0466101	total: 2m 2s	remaining: 14.4s
# 895:	learn: 0.0465539	total: 2m 2s	remaining: 14.2s
# 896:	learn: 0.0465244	total: 2m 2s	remaining: 14.1s
# 897:	learn: 0.0464656	total: 2m 2s	remaining: 14s
# 898:	learn: 0.0464370	total: 2m 3s	remaining: 13.8s
# 899:	learn: 0.0463802	total: 2m 3s	remaining: 13.7s
# 900:	learn: 0.0463511	total: 2m 3s	remaining: 13.5s
# 901:	learn: 0.0462385	total: 2m 3s	remaining: 13.4s
# 902:	learn: 0.0462086	total: 2m 3s	remaining: 13.3s
# 903:	learn: 0.0461479	total: 2m 3s	remaining: 13.1s
# 904:	learn: 0.0461111	total: 2m 3s	remaining: 13s
# 905:	learn: 0.0460778	total: 2m 3s	remaining: 12.9s
# 906:	learn: 0.0460560	total: 2m 4s	remaining: 12.7s
# 907:	learn: 0.0460293	total: 2m 4s	remaining: 12.6s
# 908:	learn: 0.0459883	total: 2m 4s	remaining: 12.5s
# 909:	learn: 0.0459499	total: 2m 4s	remaining: 12.3s
# 910:	learn: 0.0458900	total: 2m 4s	remaining: 12.2s
# 911:	learn: 0.0458526	total: 2m 4s	remaining: 12s
# 912:	learn: 0.0457982	total: 2m 4s	remaining: 11.9s
# 913:	learn: 0.0457299	total: 2m 5s	remaining: 11.8s
# 914:	learn: 0.0456728	total: 2m 5s	remaining: 11.6s
# 915:	learn: 0.0456375	total: 2m 5s	remaining: 11.5s
# 916:	learn: 0.0455811	total: 2m 5s	remaining: 11.4s
# 917:	learn: 0.0455625	total: 2m 5s	remaining: 11.2s
# 918:	learn: 0.0455344	total: 2m 5s	remaining: 11.1s
# 919:	learn: 0.0455117	total: 2m 5s	remaining: 10.9s
# 920:	learn: 0.0454715	total: 2m 6s	remaining: 10.8s
# 921:	learn: 0.0454453	total: 2m 6s	remaining: 10.7s
# 922:	learn: 0.0454004	total: 2m 6s	remaining: 10.5s
# 923:	learn: 0.0453874	total: 2m 6s	remaining: 10.4s
# 924:	learn: 0.0453336	total: 2m 6s	remaining: 10.3s
# 925:	learn: 0.0452871	total: 2m 6s	remaining: 10.1s
# 926:	learn: 0.0452372	total: 2m 6s	remaining: 9.99s
# 927:	learn: 0.0452074	total: 2m 7s	remaining: 9.86s
# 928:	learn: 0.0451728	total: 2m 7s	remaining: 9.72s
# 929:	learn: 0.0451398	total: 2m 7s	remaining: 9.58s
# 930:	learn: 0.0450614	total: 2m 7s	remaining: 9.45s
# 931:	learn: 0.0450191	total: 2m 7s	remaining: 9.31s
# 932:	learn: 0.0449643	total: 2m 7s	remaining: 9.17s
# 933:	learn: 0.0449355	total: 2m 7s	remaining: 9.04s
# 934:	learn: 0.0448621	total: 2m 8s	remaining: 8.9s
# 935:	learn: 0.0448332	total: 2m 8s	remaining: 8.76s
# 936:	learn: 0.0448043	total: 2m 8s	remaining: 8.63s
# 937:	learn: 0.0447683	total: 2m 8s	remaining: 8.49s
# 938:	learn: 0.0447455	total: 2m 8s	remaining: 8.35s
# 939:	learn: 0.0446871	total: 2m 8s	remaining: 8.21s
# 940:	learn: 0.0446465	total: 2m 8s	remaining: 8.08s
# 941:	learn: 0.0446157	total: 2m 8s	remaining: 7.94s
# 942:	learn: 0.0445733	total: 2m 9s	remaining: 7.8s
# 943:	learn: 0.0445404	total: 2m 9s	remaining: 7.67s
# 944:	learn: 0.0445228	total: 2m 9s	remaining: 7.53s
# 945:	learn: 0.0444909	total: 2m 9s	remaining: 7.39s
# 946:	learn: 0.0444544	total: 2m 9s	remaining: 7.25s
# 947:	learn: 0.0444222	total: 2m 9s	remaining: 7.12s
# 948:	learn: 0.0443756	total: 2m 9s	remaining: 6.98s
# 949:	learn: 0.0443408	total: 2m 10s	remaining: 6.84s
# 950:	learn: 0.0442928	total: 2m 10s	remaining: 6.71s
# 951:	learn: 0.0442452	total: 2m 10s	remaining: 6.57s
# 952:	learn: 0.0442149	total: 2m 10s	remaining: 6.43s
# 953:	learn: 0.0441841	total: 2m 10s	remaining: 6.3s
# 954:	learn: 0.0441618	total: 2m 10s	remaining: 6.16s
# 955:	learn: 0.0441130	total: 2m 10s	remaining: 6.02s
# 956:	learn: 0.0440594	total: 2m 11s	remaining: 5.89s
# 957:	learn: 0.0440082	total: 2m 11s	remaining: 5.75s
# 958:	learn: 0.0439937	total: 2m 11s	remaining: 5.61s
# 959:	learn: 0.0439745	total: 2m 11s	remaining: 5.48s
# 960:	learn: 0.0439389	total: 2m 11s	remaining: 5.34s
# 961:	learn: 0.0439139	total: 2m 11s	remaining: 5.2s
# 962:	learn: 0.0438814	total: 2m 11s	remaining: 5.07s
# 963:	learn: 0.0438609	total: 2m 11s	remaining: 4.93s
# 964:	learn: 0.0438154	total: 2m 12s	remaining: 4.79s
# 965:	learn: 0.0437833	total: 2m 12s	remaining: 4.66s
# 966:	learn: 0.0437265	total: 2m 12s	remaining: 4.52s
# 967:	learn: 0.0436422	total: 2m 12s	remaining: 4.38s
# 968:	learn: 0.0435903	total: 2m 12s	remaining: 4.24s
# 969:	learn: 0.0435637	total: 2m 12s	remaining: 4.11s
# 970:	learn: 0.0435337	total: 2m 12s	remaining: 3.97s
# 971:	learn: 0.0435002	total: 2m 13s	remaining: 3.83s
# 972:	learn: 0.0434251	total: 2m 13s	remaining: 3.7s
# 973:	learn: 0.0433851	total: 2m 13s	remaining: 3.56s
# 974:	learn: 0.0433451	total: 2m 13s	remaining: 3.42s
# 975:	learn: 0.0433206	total: 2m 13s	remaining: 3.29s
# 976:	learn: 0.0432747	total: 2m 13s	remaining: 3.15s
# 977:	learn: 0.0432343	total: 2m 13s	remaining: 3.01s
# 978:	learn: 0.0431894	total: 2m 14s	remaining: 2.87s
# 979:	learn: 0.0431489	total: 2m 14s	remaining: 2.74s
# 980:	learn: 0.0431113	total: 2m 14s	remaining: 2.6s
# 981:	learn: 0.0431018	total: 2m 14s	remaining: 2.46s
# 982:	learn: 0.0430309	total: 2m 14s	remaining: 2.33s
# 983:	learn: 0.0429839	total: 2m 14s	remaining: 2.19s
# 984:	learn: 0.0429404	total: 2m 14s	remaining: 2.05s
# 985:	learn: 0.0428938	total: 2m 14s	remaining: 1.92s
# 986:	learn: 0.0428365	total: 2m 15s	remaining: 1.78s
# 987:	learn: 0.0428061	total: 2m 15s	remaining: 1.64s
# 988:	learn: 0.0427871	total: 2m 15s	remaining: 1.5s
# 989:	learn: 0.0427362	total: 2m 15s	remaining: 1.37s
# 990:	learn: 0.0427167	total: 2m 15s	remaining: 1.23s
# 991:	learn: 0.0426906	total: 2m 15s	remaining: 1.09s
# 992:	learn: 0.0426487	total: 2m 15s	remaining: 958ms
# 993:	learn: 0.0426117	total: 2m 16s	remaining: 821ms
# 994:	learn: 0.0425966	total: 2m 16s	remaining: 684ms
# 995:	learn: 0.0425490	total: 2m 16s	remaining: 548ms
# 996:	learn: 0.0425175	total: 2m 16s	remaining: 411ms
# 997:	learn: 0.0424637	total: 2m 16s	remaining: 274ms
# 998:	learn: 0.0424258	total: 2m 16s	remaining: 137ms
# 999:	learn: 0.0423645	total: 2m 16s	remaining: 0us

# %%
cb_pred = model_cb.predict(test[catb_features])

# %% [markdown]
# ### LightGBM V1

# %%
convert_types = ['seller', 'floor', 'rooms', 'bathrooms', 'balc_loggias', 'condition', 'constructed',
                 'phones', 'new', 'district', 'stories', 'elevator_without', 'material', 'cat_constructed']
for col in convert_types:
    train[col] = train[col].astype(float) 
    test[col] = test[col].astype(float)
# Out:
# <ipython-input-106-bde874b7a30b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[col] = train[col].astype(float)
# <ipython-input-106-bde874b7a30b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[col] = test[col].astype(float)

# %%
RS = 20170501
np.random.seed(RS)
ROUNDS = 450

model = lgb.LGBMRegressor(
    objective ='regression',
    metric = 'rmsle',
    boosting = 'gbdt',
    num_leaves = 60, 
    max_depth = 12, 
    min_child_samples = 4, 
    max_bin = 1000,
    learning_rate = 0.032543242172229245, 
    verbose = -1,
    bagging_fraction = 0.7559447209589375, 
    bagging_freq = 3, 
    bagging_seed = 42,
    feature_fraction = 0.6697712968829559, 
    feature_fraction_seed = 42,
    num_iterations = 2400, 
    n_estimators = 10000,
    lambda_l1 = 1.5680852745891572e-06, 
    lambda_l2 = 5.5199200274889796e-05,
    categorical_features = categorical_features
)

model.fit(train[lgbm_features], train['price_log'])
# Out:
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# LGBMRegressor(bagging_fraction=0.7559447209589375, bagging_freq=3,
#               bagging_seed=42, boosting='gbdt', categorical_features=[0, 1, 2],
#               feature_fraction=0.6697712968829559, feature_fraction_seed=42,
#               lambda_l1=1.5680852745891572e-06,
#               lambda_l2=5.5199200274889796e-05,
#               learning_rate=0.032543242172229245, max_bin=1000, max_depth=12,
#               metric='rmsle', min_child_samples=4, n_estimators=10000,
#               num_iterations=2400, num_leaves=60, objective='regression',
#               verbose=-1)

# %%
lgbm_preds = model.predict(test[lgbm_features])

# %% [markdown]
# ### META model (RF, XGB, LGBM, LGBM_V2 & CB)

# %%
# LightGBM 
lgb_features = ['material', 'condition', 'constructed', 'longitude', 'latitude', 'floor_perc',
            'area_total', 'ceiling', 'room_size', 'distance_to_uni', 'distance_mean']

lgb_cat_features = [0, 1, 2]

# LightGBM V2 
lgb_v2_features = ['material', 'condition',  'constructed', 'stories', 'floor', 'rooms',
             'ceiling',  'distance_to_uni', 
            'distance_mean_log', 'area_total_log', 'bearing_to_center']

lgb_v2_cat_features = [0, 1, 2, 4, 5]

# XGBoost 
xgb_features = ['longitude', 'latitude', 'floor_perc', 'condition',  'material', 'ceiling', 'distance_to_uni',
                  'area_total', 'distance_mean', 'room_size', 'cat_constructed']

# CatBoost 
cb_features = ['longitude', 'latitude', 'age_of_building', 'area_total', 'ceiling', 'room_size',
                'distance_to_uni', 'distance_mean', 'distance_to_metro', 'floor_string', 'rooms_string',
                   'condition_string', 'district_string', 'stories_string', 'material_string', 'cat_constructed_string']

cb_cat_features = [9, 10, 11, 12, 13, 14, 15]

# Random Forest
rf_features = ['material', 'condition', 'cat_constructed', 'floor_perc', 'age_of_building_log',
            'area_total_log',  'ceiling', 'room_size_log', 'distance_to_uni', 'distance_mean_log', 'longitude', 'latitude']

# %%
model_lgb = lgb.LGBMRegressor(
    objective ='regression',
    metric = 'rmsle',
    boosting = 'gbdt',
    num_leaves = 60, 
    max_depth = 12, 
    min_child_samples = 4, 
    max_bin = 1000,
    learning_rate = 0.032543242172229245, 
    verbose = -1,
    bagging_fraction = 0.7559447209589375, 
    bagging_freq = 3, 
    bagging_seed = 42,
    feature_fraction = 0.6697712968829559, 
    feature_fraction_seed = 42,
    num_iterations = 2400, 
    n_estimators = 10000,
    lambda_l1 = 1.5680852745891572e-06, 
    lambda_l2 = 5.5199200274889796e-05,
    categorical_features = lgb_cat_features
)

model_xgb = xgb.XGBRegressor(    
    metric = 'rmsle',
    n_estimators = 6000,
    reg_lambda = 3.3970862089233713,
    reg_alpha = 0.05,
    colsample_bytree = 0.9,
    subsample = 0.7,
    learning_rate = 0.0086,
    max_depth = 11,
    random_state = 48,
    min_child_weight = 1,
    seed = 42
)

model_cb = cb.CatBoostRegressor(
    l2_leaf_reg = 0.0029675173022904867,
    max_bin = 389,
    bagging_temperature = 0.7448407730182606,
    learning_rate = 0.05226579708274029,
    depth = 11,
    min_data_in_leaf = 88,
    #'rsm': 1
    cat_features = cb_cat_features
)

model_rf = RandomForestRegressor(
    n_estimators=2000,
    random_state=42,
    bootstrap=False,
    max_features='sqrt'
)

model_lgb_v2 = lgb.LGBMRegressor(
    objective='regression',
    metric= 'rmsle',
    boosting= 'gbdt',
    num_leaves= 60, 
    max_depth= 10, 
    min_child_samples= 9, 
    max_bin= 1000,
    learning_rate= 0.032543242172229245, 
    verbose= -1,
    bagging_fraction= 0.6244885179807813, 
    bagging_freq= 6, 
    bagging_seed= 42,
    feature_fraction= 0.6293142647827907, 
    feature_fraction_seed= 42,
    num_iterations= 2000, 
    n_estimators= 10000,
    lambda_l1= 2.4308837323197616e-05, 
    lambda_l2= 0.0005, 
    categorical_features = lgb_v2_cat_features
)

# %%
n_train = train.shape[0]
n_test = test.shape[0]

n_folds = 10
kf = KFold(n_splits=n_folds, shuffle=True, random_state=42) 

def get_oof(reg_model, x_train, y_train, x_test):
    
    oof_train = np.zeros((n_train,))
    oof_test = np.zeros((n_test,))
    oof_test_skf = np.empty((n_folds, n_test))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):  
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        x_te = x_train[test_index]

        reg_model.fit(x_tr, y_tr)

        oof_train[test_index] = reg_model.predict(x_te)
        oof_test_skf[i, :] = reg_model.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
y_train = train.price_log.ravel()

cb_oof_train, cb_oof_test = get_oof(model_cb, train[cb_features].values, y_train, test[cb_features].values)
# Out:
# 0:	learn: 0.8247155	total: 488ms	remaining: 8m 7s
# 1:	learn: 0.7879733	total: 916ms	remaining: 7m 37s
# 2:	learn: 0.7544579	total: 1.05s	remaining: 5m 50s
# 3:	learn: 0.7218925	total: 1.57s	remaining: 6m 30s
# 4:	learn: 0.6903126	total: 2.04s	remaining: 6m 45s
# 5:	learn: 0.6610090	total: 2.59s	remaining: 7m 9s
# 6:	learn: 0.6334319	total: 3.16s	remaining: 7m 28s
# 7:	learn: 0.6068222	total: 3.58s	remaining: 7m 24s
# 8:	learn: 0.5821205	total: 4.17s	remaining: 7m 38s
# 9:	learn: 0.5589043	total: 4.67s	remaining: 7m 42s
# 10:	learn: 0.5369820	total: 5.16s	remaining: 7m 43s
# 11:	learn: 0.5160401	total: 5.76s	remaining: 7m 54s
# 12:	learn: 0.4965700	total: 6.45s	remaining: 8m 9s
# 13:	learn: 0.4778517	total: 7.08s	remaining: 8m 18s
# 14:	learn: 0.4602245	total: 7.72s	remaining: 8m 26s
# 15:	learn: 0.4430312	total: 8.24s	remaining: 8m 26s
# 16:	learn: 0.4274248	total: 8.78s	remaining: 8m 27s
# 17:	learn: 0.4127542	total: 9.47s	remaining: 8m 36s
# 18:	learn: 0.3993058	total: 10s	remaining: 8m 36s
# 19:	learn: 0.3862022	total: 10.7s	remaining: 8m 42s
# 20:	learn: 0.3740603	total: 11.3s	remaining: 8m 45s
# 21:	learn: 0.3623976	total: 11.9s	remaining: 8m 50s
# 22:	learn: 0.3513440	total: 12.5s	remaining: 8m 49s
# 23:	learn: 0.3411120	total: 13.1s	remaining: 8m 52s
# 24:	learn: 0.3323572	total: 13.3s	remaining: 8m 38s
# 25:	learn: 0.3229713	total: 13.8s	remaining: 8m 36s
# 26:	learn: 0.3139313	total: 14.2s	remaining: 8m 33s
# 27:	learn: 0.3060070	total: 14.8s	remaining: 8m 33s
# 28:	learn: 0.2983997	total: 15.4s	remaining: 8m 34s
# 29:	learn: 0.2910523	total: 15.9s	remaining: 8m 33s
# 30:	learn: 0.2844353	total: 16.3s	remaining: 8m 31s
# 31:	learn: 0.2784099	total: 16.9s	remaining: 8m 31s
# 32:	learn: 0.2727626	total: 17.5s	remaining: 8m 32s
# 33:	learn: 0.2678009	total: 18.2s	remaining: 8m 37s
# 34:	learn: 0.2626392	total: 18.8s	remaining: 8m 37s
# 35:	learn: 0.2567194	total: 19.3s	remaining: 8m 37s
# 36:	learn: 0.2519565	total: 20s	remaining: 8m 40s
# 37:	learn: 0.2472831	total: 20.5s	remaining: 8m 38s
# 38:	learn: 0.2429735	total: 21.1s	remaining: 8m 40s
# 39:	learn: 0.2379719	total: 21.6s	remaining: 8m 38s
# 40:	learn: 0.2344558	total: 22.2s	remaining: 8m 38s
# 41:	learn: 0.2311897	total: 22.7s	remaining: 8m 37s
# 42:	learn: 0.2264933	total: 23.3s	remaining: 8m 37s
# 43:	learn: 0.2228695	total: 23.8s	remaining: 8m 38s
# 44:	learn: 0.2189631	total: 24.3s	remaining: 8m 35s
# 45:	learn: 0.2161713	total: 24.8s	remaining: 8m 34s
# 46:	learn: 0.2134873	total: 25.4s	remaining: 8m 34s
# 47:	learn: 0.2104205	total: 26s	remaining: 8m 35s
# 48:	learn: 0.2082415	total: 26.5s	remaining: 8m 35s
# 49:	learn: 0.2058162	total: 27.1s	remaining: 8m 34s
# 50:	learn: 0.2034198	total: 27.7s	remaining: 8m 34s
# 51:	learn: 0.2010031	total: 28.3s	remaining: 8m 35s
# 52:	learn: 0.1981427	total: 29.1s	remaining: 8m 39s
# 53:	learn: 0.1965712	total: 29.6s	remaining: 8m 37s
# 54:	learn: 0.1950391	total: 30s	remaining: 8m 36s
# 55:	learn: 0.1928830	total: 30.6s	remaining: 8m 35s
# 56:	learn: 0.1912085	total: 31.1s	remaining: 8m 34s
# 57:	learn: 0.1893561	total: 31.7s	remaining: 8m 34s
# 58:	learn: 0.1880036	total: 32.2s	remaining: 8m 34s
# 59:	learn: 0.1867847	total: 32.8s	remaining: 8m 33s
# 60:	learn: 0.1856385	total: 33.4s	remaining: 8m 33s
# 61:	learn: 0.1839330	total: 33.8s	remaining: 8m 31s
# 62:	learn: 0.1817560	total: 34.4s	remaining: 8m 31s
# 63:	learn: 0.1805531	total: 34.9s	remaining: 8m 30s
# 64:	learn: 0.1789535	total: 35.4s	remaining: 8m 29s
# 65:	learn: 0.1777622	total: 35.9s	remaining: 8m 28s
# 66:	learn: 0.1761372	total: 36.5s	remaining: 8m 27s
# 67:	learn: 0.1748381	total: 37s	remaining: 8m 26s
# 68:	learn: 0.1738279	total: 37.5s	remaining: 8m 26s
# 69:	learn: 0.1729591	total: 38s	remaining: 8m 24s
# 70:	learn: 0.1720144	total: 38.5s	remaining: 8m 24s
# 71:	learn: 0.1706482	total: 39.1s	remaining: 8m 23s
# 72:	learn: 0.1696626	total: 39.6s	remaining: 8m 23s
# 73:	learn: 0.1689429	total: 40.3s	remaining: 8m 23s
# 74:	learn: 0.1675943	total: 40.8s	remaining: 8m 23s
# 75:	learn: 0.1665804	total: 41.4s	remaining: 8m 23s
# 76:	learn: 0.1655060	total: 42s	remaining: 8m 23s
# 77:	learn: 0.1648440	total: 42.7s	remaining: 8m 24s
# 78:	learn: 0.1633427	total: 43.3s	remaining: 8m 24s
# 79:	learn: 0.1624713	total: 44.1s	remaining: 8m 27s
# 80:	learn: 0.1613321	total: 44.9s	remaining: 8m 29s
# 81:	learn: 0.1606832	total: 45.5s	remaining: 8m 29s
# 82:	learn: 0.1601317	total: 46.2s	remaining: 8m 30s
# 83:	learn: 0.1592827	total: 46.7s	remaining: 8m 29s
# 84:	learn: 0.1583835	total: 47.2s	remaining: 8m 28s
# 85:	learn: 0.1578783	total: 47.7s	remaining: 8m 27s
# 86:	learn: 0.1573219	total: 48.3s	remaining: 8m 26s
# 87:	learn: 0.1564542	total: 48.9s	remaining: 8m 26s
# 88:	learn: 0.1556801	total: 49.4s	remaining: 8m 25s
# 89:	learn: 0.1549945	total: 50s	remaining: 8m 25s
# 90:	learn: 0.1542978	total: 50.6s	remaining: 8m 25s
# 91:	learn: 0.1537721	total: 51.2s	remaining: 8m 24s
# 92:	learn: 0.1529496	total: 51.6s	remaining: 8m 23s
# 93:	learn: 0.1523871	total: 52.2s	remaining: 8m 23s
# 94:	learn: 0.1515850	total: 52.6s	remaining: 8m 21s
# 95:	learn: 0.1508424	total: 53.3s	remaining: 8m 21s
# 96:	learn: 0.1503707	total: 53.8s	remaining: 8m 20s
# 97:	learn: 0.1499169	total: 54.2s	remaining: 8m 19s
# 98:	learn: 0.1496189	total: 54.7s	remaining: 8m 17s
# 99:	learn: 0.1491065	total: 55.2s	remaining: 8m 17s
# 100:	learn: 0.1486360	total: 55.8s	remaining: 8m 16s
# 101:	learn: 0.1479253	total: 56.4s	remaining: 8m 16s
# 102:	learn: 0.1474200	total: 57s	remaining: 8m 16s
# 103:	learn: 0.1465064	total: 57.4s	remaining: 8m 14s
# 104:	learn: 0.1461393	total: 57.9s	remaining: 8m 13s
# 105:	learn: 0.1458037	total: 58.5s	remaining: 8m 13s
# 106:	learn: 0.1452103	total: 59s	remaining: 8m 12s
# 107:	learn: 0.1446677	total: 59.7s	remaining: 8m 12s
# 108:	learn: 0.1442487	total: 1m	remaining: 8m 12s
# 109:	learn: 0.1440279	total: 1m	remaining: 8m 11s
# 110:	learn: 0.1436209	total: 1m 1s	remaining: 8m 10s
# 111:	learn: 0.1428838	total: 1m 1s	remaining: 8m 9s
# 112:	learn: 0.1425173	total: 1m 2s	remaining: 8m 7s
# 113:	learn: 0.1422668	total: 1m 2s	remaining: 8m 6s
# 114:	learn: 0.1412947	total: 1m 3s	remaining: 8m 6s
# 115:	learn: 0.1403461	total: 1m 3s	remaining: 8m 6s
# 116:	learn: 0.1397102	total: 1m 4s	remaining: 8m 7s
# 117:	learn: 0.1392969	total: 1m 5s	remaining: 8m 6s
# 118:	learn: 0.1389293	total: 1m 5s	remaining: 8m 7s
# 119:	learn: 0.1384455	total: 1m 6s	remaining: 8m 7s
# 120:	learn: 0.1381488	total: 1m 7s	remaining: 8m 9s
# 121:	learn: 0.1376700	total: 1m 7s	remaining: 8m 8s
# 122:	learn: 0.1372400	total: 1m 8s	remaining: 8m 9s
# 123:	learn: 0.1367880	total: 1m 9s	remaining: 8m 9s
# 124:	learn: 0.1365355	total: 1m 9s	remaining: 8m 8s
# 125:	learn: 0.1360170	total: 1m 10s	remaining: 8m 6s
# 126:	learn: 0.1356735	total: 1m 10s	remaining: 8m 6s
# 127:	learn: 0.1354550	total: 1m 11s	remaining: 8m 6s
# 128:	learn: 0.1348875	total: 1m 12s	remaining: 8m 6s
# 129:	learn: 0.1344948	total: 1m 12s	remaining: 8m 6s
# 130:	learn: 0.1341530	total: 1m 13s	remaining: 8m 5s
# 131:	learn: 0.1338481	total: 1m 13s	remaining: 8m 5s
# 132:	learn: 0.1336044	total: 1m 14s	remaining: 8m 5s
# 133:	learn: 0.1332362	total: 1m 15s	remaining: 8m 4s
# 134:	learn: 0.1328379	total: 1m 15s	remaining: 8m 4s
# 135:	learn: 0.1322706	total: 1m 16s	remaining: 8m 4s
# 136:	learn: 0.1319002	total: 1m 16s	remaining: 8m 4s
# 137:	learn: 0.1315455	total: 1m 17s	remaining: 8m 4s
# 138:	learn: 0.1311410	total: 1m 18s	remaining: 8m 3s
# 139:	learn: 0.1309063	total: 1m 18s	remaining: 8m 2s
# 140:	learn: 0.1304973	total: 1m 19s	remaining: 8m 2s
# 141:	learn: 0.1302575	total: 1m 19s	remaining: 8m 2s
# 142:	learn: 0.1299300	total: 1m 20s	remaining: 8m 2s
# 143:	learn: 0.1296028	total: 1m 21s	remaining: 8m 2s
# 144:	learn: 0.1291087	total: 1m 21s	remaining: 8m 2s
# 145:	learn: 0.1285974	total: 1m 22s	remaining: 8m 1s
# 146:	learn: 0.1281996	total: 1m 22s	remaining: 8m 1s
# 147:	learn: 0.1279765	total: 1m 23s	remaining: 8m 1s
# 148:	learn: 0.1277116	total: 1m 24s	remaining: 8m
# 149:	learn: 0.1275114	total: 1m 24s	remaining: 8m
# 150:	learn: 0.1271159	total: 1m 25s	remaining: 7m 58s
# 151:	learn: 0.1267788	total: 1m 25s	remaining: 7m 58s
# 152:	learn: 0.1266305	total: 1m 26s	remaining: 7m 58s
# 153:	learn: 0.1263369	total: 1m 27s	remaining: 7m 59s
# 154:	learn: 0.1259566	total: 1m 27s	remaining: 7m 59s
# 155:	learn: 0.1257377	total: 1m 28s	remaining: 7m 58s
# 156:	learn: 0.1251592	total: 1m 29s	remaining: 7m 58s
# 157:	learn: 0.1246347	total: 1m 29s	remaining: 7m 58s
# 158:	learn: 0.1243474	total: 1m 30s	remaining: 7m 58s
# 159:	learn: 0.1238400	total: 1m 31s	remaining: 7m 58s
# 160:	learn: 0.1235165	total: 1m 31s	remaining: 7m 58s
# 161:	learn: 0.1230201	total: 1m 32s	remaining: 7m 57s
# 162:	learn: 0.1226252	total: 1m 32s	remaining: 7m 57s
# 163:	learn: 0.1223461	total: 1m 33s	remaining: 7m 56s
# 164:	learn: 0.1221621	total: 1m 34s	remaining: 7m 56s
# 165:	learn: 0.1219127	total: 1m 34s	remaining: 7m 56s
# 166:	learn: 0.1216439	total: 1m 35s	remaining: 7m 55s
# 167:	learn: 0.1214623	total: 1m 36s	remaining: 7m 55s
# 168:	learn: 0.1211150	total: 1m 36s	remaining: 7m 55s
# 169:	learn: 0.1205538	total: 1m 37s	remaining: 7m 54s
# 170:	learn: 0.1200551	total: 1m 37s	remaining: 7m 53s
# 171:	learn: 0.1197859	total: 1m 38s	remaining: 7m 52s
# 172:	learn: 0.1195208	total: 1m 38s	remaining: 7m 51s
# 173:	learn: 0.1190773	total: 1m 38s	remaining: 7m 49s
# 174:	learn: 0.1186475	total: 1m 39s	remaining: 7m 49s
# 175:	learn: 0.1184241	total: 1m 40s	remaining: 7m 48s
# 176:	learn: 0.1181843	total: 1m 40s	remaining: 7m 47s
# 177:	learn: 0.1178846	total: 1m 41s	remaining: 7m 47s
# 178:	learn: 0.1174486	total: 1m 41s	remaining: 7m 45s
# 179:	learn: 0.1169891	total: 1m 42s	remaining: 7m 45s
# 180:	learn: 0.1167014	total: 1m 42s	remaining: 7m 43s
# 181:	learn: 0.1163101	total: 1m 43s	remaining: 7m 43s
# 182:	learn: 0.1160838	total: 1m 43s	remaining: 7m 42s
# 183:	learn: 0.1158207	total: 1m 44s	remaining: 7m 41s
# 184:	learn: 0.1155691	total: 1m 44s	remaining: 7m 41s
# 185:	learn: 0.1151038	total: 1m 45s	remaining: 7m 40s
# 186:	learn: 0.1148466	total: 1m 45s	remaining: 7m 39s
# 187:	learn: 0.1144780	total: 1m 46s	remaining: 7m 38s
# 188:	learn: 0.1142333	total: 1m 46s	remaining: 7m 37s
# 189:	learn: 0.1138502	total: 1m 47s	remaining: 7m 36s
# 190:	learn: 0.1136167	total: 1m 47s	remaining: 7m 35s
# 191:	learn: 0.1132990	total: 1m 47s	remaining: 7m 34s
# 192:	learn: 0.1130258	total: 1m 48s	remaining: 7m 33s
# 193:	learn: 0.1128720	total: 1m 49s	remaining: 7m 33s
# 194:	learn: 0.1126287	total: 1m 49s	remaining: 7m 32s
# 195:	learn: 0.1122058	total: 1m 50s	remaining: 7m 31s
# 196:	learn: 0.1119911	total: 1m 50s	remaining: 7m 31s
# 197:	learn: 0.1118369	total: 1m 51s	remaining: 7m 30s
# 198:	learn: 0.1114474	total: 1m 51s	remaining: 7m 29s
# 199:	learn: 0.1112017	total: 1m 52s	remaining: 7m 28s
# 200:	learn: 0.1108295	total: 1m 52s	remaining: 7m 27s
# 201:	learn: 0.1104799	total: 1m 52s	remaining: 7m 26s
# 202:	learn: 0.1100368	total: 1m 53s	remaining: 7m 25s
# 203:	learn: 0.1098166	total: 1m 53s	remaining: 7m 24s
# 204:	learn: 0.1095801	total: 1m 54s	remaining: 7m 23s
# 205:	learn: 0.1092115	total: 1m 54s	remaining: 7m 23s
# 206:	learn: 0.1090157	total: 1m 55s	remaining: 7m 22s
# 207:	learn: 0.1087826	total: 1m 55s	remaining: 7m 21s
# 208:	learn: 0.1085085	total: 1m 56s	remaining: 7m 20s
# 209:	learn: 0.1083393	total: 1m 56s	remaining: 7m 19s
# 210:	learn: 0.1081302	total: 1m 57s	remaining: 7m 18s
# 211:	learn: 0.1079614	total: 1m 57s	remaining: 7m 17s
# 212:	learn: 0.1077705	total: 1m 58s	remaining: 7m 17s
# 213:	learn: 0.1074338	total: 1m 58s	remaining: 7m 15s
# 214:	learn: 0.1072094	total: 1m 59s	remaining: 7m 14s
# 215:	learn: 0.1070498	total: 1m 59s	remaining: 7m 14s
# 216:	learn: 0.1069227	total: 2m	remaining: 7m 13s
# 217:	learn: 0.1065348	total: 2m	remaining: 7m 12s
# 218:	learn: 0.1061495	total: 2m	remaining: 7m 11s
# 219:	learn: 0.1060191	total: 2m 1s	remaining: 7m 10s
# 220:	learn: 0.1058522	total: 2m 2s	remaining: 7m 10s
# 221:	learn: 0.1056980	total: 2m 2s	remaining: 7m 9s
# 222:	learn: 0.1054781	total: 2m 3s	remaining: 7m 8s
# 223:	learn: 0.1052728	total: 2m 3s	remaining: 7m 7s
# 224:	learn: 0.1051314	total: 2m 3s	remaining: 7m 6s
# 225:	learn: 0.1049317	total: 2m 4s	remaining: 7m 5s
# 226:	learn: 0.1046574	total: 2m 4s	remaining: 7m 4s
# 227:	learn: 0.1043802	total: 2m 5s	remaining: 7m 3s
# 228:	learn: 0.1041328	total: 2m 5s	remaining: 7m 2s
# 229:	learn: 0.1039636	total: 2m 6s	remaining: 7m 1s
# 230:	learn: 0.1037484	total: 2m 6s	remaining: 7m
# 231:	learn: 0.1034472	total: 2m 6s	remaining: 6m 59s
# 232:	learn: 0.1030984	total: 2m 7s	remaining: 6m 58s
# 233:	learn: 0.1027724	total: 2m 7s	remaining: 6m 57s
# 234:	learn: 0.1022621	total: 2m 8s	remaining: 6m 56s
# 235:	learn: 0.1020231	total: 2m 8s	remaining: 6m 55s
# 236:	learn: 0.1018554	total: 2m 8s	remaining: 6m 54s
# 237:	learn: 0.1015773	total: 2m 9s	remaining: 6m 54s
# 238:	learn: 0.1014303	total: 2m 9s	remaining: 6m 53s
# 239:	learn: 0.1012793	total: 2m 10s	remaining: 6m 52s
# 240:	learn: 0.1010489	total: 2m 10s	remaining: 6m 51s
# 241:	learn: 0.1007909	total: 2m 11s	remaining: 6m 50s
# 242:	learn: 0.1006366	total: 2m 11s	remaining: 6m 49s
# 243:	learn: 0.1003394	total: 2m 11s	remaining: 6m 48s
# 244:	learn: 0.1001792	total: 2m 12s	remaining: 6m 47s
# 245:	learn: 0.0999857	total: 2m 12s	remaining: 6m 46s
# 246:	learn: 0.0999038	total: 2m 13s	remaining: 6m 46s
# 247:	learn: 0.0996673	total: 2m 13s	remaining: 6m 45s
# 248:	learn: 0.0994081	total: 2m 14s	remaining: 6m 44s
# 249:	learn: 0.0992745	total: 2m 14s	remaining: 6m 44s
# 250:	learn: 0.0991141	total: 2m 15s	remaining: 6m 43s
# 251:	learn: 0.0989694	total: 2m 15s	remaining: 6m 42s
# 252:	learn: 0.0987550	total: 2m 16s	remaining: 6m 41s
# 253:	learn: 0.0985966	total: 2m 16s	remaining: 6m 40s
# 254:	learn: 0.0983567	total: 2m 16s	remaining: 6m 40s
# 255:	learn: 0.0982322	total: 2m 17s	remaining: 6m 39s
# 256:	learn: 0.0981170	total: 2m 17s	remaining: 6m 38s
# 257:	learn: 0.0979207	total: 2m 18s	remaining: 6m 37s
# 258:	learn: 0.0977592	total: 2m 18s	remaining: 6m 36s
# 259:	learn: 0.0975844	total: 2m 19s	remaining: 6m 35s
# 260:	learn: 0.0973291	total: 2m 19s	remaining: 6m 34s
# 261:	learn: 0.0972506	total: 2m 19s	remaining: 6m 33s
# 262:	learn: 0.0969463	total: 2m 20s	remaining: 6m 33s
# 263:	learn: 0.0966857	total: 2m 20s	remaining: 6m 32s
# 264:	learn: 0.0963652	total: 2m 21s	remaining: 6m 31s
# 265:	learn: 0.0961560	total: 2m 21s	remaining: 6m 31s
# 266:	learn: 0.0959353	total: 2m 22s	remaining: 6m 30s
# 267:	learn: 0.0957395	total: 2m 22s	remaining: 6m 29s
# 268:	learn: 0.0955891	total: 2m 23s	remaining: 6m 29s
# 269:	learn: 0.0953477	total: 2m 23s	remaining: 6m 28s
# 270:	learn: 0.0951314	total: 2m 24s	remaining: 6m 27s
# 271:	learn: 0.0948135	total: 2m 24s	remaining: 6m 27s
# 272:	learn: 0.0946407	total: 2m 24s	remaining: 6m 25s
# 273:	learn: 0.0943468	total: 2m 25s	remaining: 6m 25s
# 274:	learn: 0.0940581	total: 2m 25s	remaining: 6m 24s
# 275:	learn: 0.0937970	total: 2m 26s	remaining: 6m 23s
# 276:	learn: 0.0936515	total: 2m 26s	remaining: 6m 22s
# 277:	learn: 0.0934795	total: 2m 26s	remaining: 6m 21s
# 278:	learn: 0.0932757	total: 2m 27s	remaining: 6m 20s
# 279:	learn: 0.0930908	total: 2m 27s	remaining: 6m 20s
# 280:	learn: 0.0928067	total: 2m 28s	remaining: 6m 19s
# 281:	learn: 0.0926206	total: 2m 28s	remaining: 6m 18s
# 282:	learn: 0.0924012	total: 2m 29s	remaining: 6m 17s
# 283:	learn: 0.0922504	total: 2m 29s	remaining: 6m 16s
# 284:	learn: 0.0920480	total: 2m 30s	remaining: 6m 16s
# 285:	learn: 0.0919094	total: 2m 30s	remaining: 6m 15s
# 286:	learn: 0.0917015	total: 2m 30s	remaining: 6m 14s
# 287:	learn: 0.0915205	total: 2m 31s	remaining: 6m 14s
# 288:	learn: 0.0913807	total: 2m 31s	remaining: 6m 13s
# 289:	learn: 0.0913184	total: 2m 32s	remaining: 6m 13s
# 290:	learn: 0.0911273	total: 2m 32s	remaining: 6m 12s
# 291:	learn: 0.0909019	total: 2m 33s	remaining: 6m 11s
# 292:	learn: 0.0907656	total: 2m 34s	remaining: 6m 11s
# 293:	learn: 0.0905763	total: 2m 34s	remaining: 6m 11s
# 294:	learn: 0.0904774	total: 2m 35s	remaining: 6m 10s
# 295:	learn: 0.0903030	total: 2m 35s	remaining: 6m 10s
# 296:	learn: 0.0901002	total: 2m 36s	remaining: 6m 9s
# 297:	learn: 0.0899201	total: 2m 36s	remaining: 6m 8s
# 298:	learn: 0.0896879	total: 2m 37s	remaining: 6m 8s
# 299:	learn: 0.0895172	total: 2m 37s	remaining: 6m 7s
# 300:	learn: 0.0893761	total: 2m 38s	remaining: 6m 7s
# 301:	learn: 0.0891615	total: 2m 38s	remaining: 6m 7s
# 302:	learn: 0.0889863	total: 2m 39s	remaining: 6m 6s
# 303:	learn: 0.0887990	total: 2m 39s	remaining: 6m 6s
# 304:	learn: 0.0886068	total: 2m 40s	remaining: 6m 5s
# 305:	learn: 0.0885276	total: 2m 40s	remaining: 6m 5s
# 306:	learn: 0.0884338	total: 2m 41s	remaining: 6m 4s
# 307:	learn: 0.0882624	total: 2m 42s	remaining: 6m 4s
# 308:	learn: 0.0881084	total: 2m 42s	remaining: 6m 3s
# 309:	learn: 0.0879064	total: 2m 43s	remaining: 6m 3s
# 310:	learn: 0.0877545	total: 2m 43s	remaining: 6m 2s
# 311:	learn: 0.0875979	total: 2m 44s	remaining: 6m 1s
# 312:	learn: 0.0874598	total: 2m 44s	remaining: 6m 1s
# 313:	learn: 0.0873750	total: 2m 45s	remaining: 6m
# 314:	learn: 0.0872042	total: 2m 45s	remaining: 5m 59s
# 315:	learn: 0.0870531	total: 2m 45s	remaining: 5m 59s
# 316:	learn: 0.0868561	total: 2m 46s	remaining: 5m 58s
# 317:	learn: 0.0866458	total: 2m 46s	remaining: 5m 58s
# 318:	learn: 0.0864413	total: 2m 47s	remaining: 5m 57s
# 319:	learn: 0.0863164	total: 2m 47s	remaining: 5m 56s
# 320:	learn: 0.0862490	total: 2m 48s	remaining: 5m 56s
# 321:	learn: 0.0861763	total: 2m 48s	remaining: 5m 55s
# 322:	learn: 0.0859448	total: 2m 49s	remaining: 5m 55s
# 323:	learn: 0.0858103	total: 2m 49s	remaining: 5m 54s
# 324:	learn: 0.0856591	total: 2m 50s	remaining: 5m 53s
# 325:	learn: 0.0855520	total: 2m 50s	remaining: 5m 53s
# 326:	learn: 0.0854857	total: 2m 51s	remaining: 5m 52s
# 327:	learn: 0.0853332	total: 2m 51s	remaining: 5m 51s
# 328:	learn: 0.0851887	total: 2m 52s	remaining: 5m 51s
# 329:	learn: 0.0850495	total: 2m 52s	remaining: 5m 50s
# 330:	learn: 0.0847504	total: 2m 53s	remaining: 5m 50s
# 331:	learn: 0.0845654	total: 2m 53s	remaining: 5m 49s
# 332:	learn: 0.0844446	total: 2m 54s	remaining: 5m 48s
# 333:	learn: 0.0843486	total: 2m 54s	remaining: 5m 48s
# 334:	learn: 0.0841930	total: 2m 55s	remaining: 5m 48s
# 335:	learn: 0.0840154	total: 2m 55s	remaining: 5m 47s
# 336:	learn: 0.0838728	total: 2m 56s	remaining: 5m 46s
# 337:	learn: 0.0837465	total: 2m 56s	remaining: 5m 45s
# 338:	learn: 0.0836172	total: 2m 57s	remaining: 5m 45s
# 339:	learn: 0.0834772	total: 2m 57s	remaining: 5m 44s
# 340:	learn: 0.0832703	total: 2m 58s	remaining: 5m 44s
# 341:	learn: 0.0831594	total: 2m 58s	remaining: 5m 43s
# 342:	learn: 0.0830720	total: 2m 59s	remaining: 5m 43s
# 343:	learn: 0.0829643	total: 2m 59s	remaining: 5m 43s
# 344:	learn: 0.0828537	total: 3m	remaining: 5m 42s
# 345:	learn: 0.0827242	total: 3m	remaining: 5m 41s
# 346:	learn: 0.0825517	total: 3m 1s	remaining: 5m 41s
# 347:	learn: 0.0823957	total: 3m 1s	remaining: 5m 40s
# 348:	learn: 0.0822929	total: 3m 2s	remaining: 5m 40s
# 349:	learn: 0.0821190	total: 3m 2s	remaining: 5m 39s
# 350:	learn: 0.0820003	total: 3m 3s	remaining: 5m 38s
# 351:	learn: 0.0819159	total: 3m 3s	remaining: 5m 37s
# 352:	learn: 0.0817840	total: 3m 3s	remaining: 5m 37s
# 353:	learn: 0.0816922	total: 3m 4s	remaining: 5m 36s
# 354:	learn: 0.0814519	total: 3m 5s	remaining: 5m 36s
# 355:	learn: 0.0813619	total: 3m 5s	remaining: 5m 35s
# 356:	learn: 0.0812549	total: 3m 5s	remaining: 5m 34s
# 357:	learn: 0.0810604	total: 3m 6s	remaining: 5m 34s
# 358:	learn: 0.0808886	total: 3m 6s	remaining: 5m 33s
# 359:	learn: 0.0807223	total: 3m 7s	remaining: 5m 32s
# 360:	learn: 0.0805675	total: 3m 7s	remaining: 5m 32s
# 361:	learn: 0.0804547	total: 3m 8s	remaining: 5m 31s
# 362:	learn: 0.0803219	total: 3m 8s	remaining: 5m 31s
# 363:	learn: 0.0802203	total: 3m 9s	remaining: 5m 30s
# 364:	learn: 0.0800577	total: 3m 9s	remaining: 5m 30s
# 365:	learn: 0.0799686	total: 3m 10s	remaining: 5m 29s
# 366:	learn: 0.0797888	total: 3m 10s	remaining: 5m 28s
# 367:	learn: 0.0796069	total: 3m 10s	remaining: 5m 27s
# 368:	learn: 0.0794540	total: 3m 11s	remaining: 5m 27s
# 369:	learn: 0.0793016	total: 3m 11s	remaining: 5m 26s
# 370:	learn: 0.0791781	total: 3m 12s	remaining: 5m 26s
# 371:	learn: 0.0790640	total: 3m 13s	remaining: 5m 25s
# 372:	learn: 0.0789768	total: 3m 13s	remaining: 5m 25s
# 373:	learn: 0.0788401	total: 3m 14s	remaining: 5m 24s
# 374:	learn: 0.0787929	total: 3m 14s	remaining: 5m 24s
# 375:	learn: 0.0786330	total: 3m 15s	remaining: 5m 23s
# 376:	learn: 0.0785558	total: 3m 15s	remaining: 5m 23s
# 377:	learn: 0.0784535	total: 3m 15s	remaining: 5m 22s
# 378:	learn: 0.0783619	total: 3m 16s	remaining: 5m 21s
# 379:	learn: 0.0782043	total: 3m 16s	remaining: 5m 20s
# 380:	learn: 0.0780711	total: 3m 17s	remaining: 5m 20s
# 381:	learn: 0.0779645	total: 3m 17s	remaining: 5m 19s
# 382:	learn: 0.0778516	total: 3m 18s	remaining: 5m 19s
# 383:	learn: 0.0777794	total: 3m 18s	remaining: 5m 18s
# 384:	learn: 0.0776757	total: 3m 18s	remaining: 5m 17s
# 385:	learn: 0.0774869	total: 3m 19s	remaining: 5m 17s
# 386:	learn: 0.0772822	total: 3m 20s	remaining: 5m 17s
# 387:	learn: 0.0771221	total: 3m 20s	remaining: 5m 16s
# 388:	learn: 0.0770123	total: 3m 21s	remaining: 5m 15s
# 389:	learn: 0.0769688	total: 3m 21s	remaining: 5m 15s
# 390:	learn: 0.0768073	total: 3m 22s	remaining: 5m 14s
# 391:	learn: 0.0767614	total: 3m 22s	remaining: 5m 14s
# 392:	learn: 0.0766954	total: 3m 23s	remaining: 5m 13s
# 393:	learn: 0.0766069	total: 3m 23s	remaining: 5m 13s
# 394:	learn: 0.0764785	total: 3m 24s	remaining: 5m 12s
# 395:	learn: 0.0763838	total: 3m 24s	remaining: 5m 12s
# 396:	learn: 0.0763444	total: 3m 25s	remaining: 5m 11s
# 397:	learn: 0.0762004	total: 3m 25s	remaining: 5m 11s
# 398:	learn: 0.0760893	total: 3m 26s	remaining: 5m 10s
# 399:	learn: 0.0759373	total: 3m 26s	remaining: 5m 10s
# 400:	learn: 0.0758479	total: 3m 27s	remaining: 5m 9s
# 401:	learn: 0.0757748	total: 3m 27s	remaining: 5m 8s
# 402:	learn: 0.0756761	total: 3m 27s	remaining: 5m 7s
# 403:	learn: 0.0756041	total: 3m 28s	remaining: 5m 7s
# 404:	learn: 0.0754918	total: 3m 28s	remaining: 5m 6s
# 405:	learn: 0.0754150	total: 3m 29s	remaining: 5m 5s
# 406:	learn: 0.0752197	total: 3m 29s	remaining: 5m 5s
# 407:	learn: 0.0751043	total: 3m 30s	remaining: 5m 4s
# 408:	learn: 0.0749712	total: 3m 30s	remaining: 5m 4s
# 409:	learn: 0.0749564	total: 3m 30s	remaining: 5m 3s
# 410:	learn: 0.0748999	total: 3m 31s	remaining: 5m 2s
# 411:	learn: 0.0748314	total: 3m 31s	remaining: 5m 2s
# 412:	learn: 0.0746688	total: 3m 32s	remaining: 5m 1s
# 413:	learn: 0.0745107	total: 3m 32s	remaining: 5m 1s
# 414:	learn: 0.0743201	total: 3m 33s	remaining: 5m
# 415:	learn: 0.0742371	total: 3m 34s	remaining: 5m
# 416:	learn: 0.0741700	total: 3m 34s	remaining: 5m
# 417:	learn: 0.0739934	total: 3m 35s	remaining: 4m 59s
# 418:	learn: 0.0738980	total: 3m 35s	remaining: 4m 59s
# 419:	learn: 0.0737469	total: 3m 36s	remaining: 4m 58s
# 420:	learn: 0.0736738	total: 3m 36s	remaining: 4m 58s
# 421:	learn: 0.0735094	total: 3m 37s	remaining: 4m 57s
# 422:	learn: 0.0734303	total: 3m 37s	remaining: 4m 57s
# 423:	learn: 0.0734282	total: 3m 37s	remaining: 4m 55s
# 424:	learn: 0.0733738	total: 3m 38s	remaining: 4m 55s
# 425:	learn: 0.0733230	total: 3m 38s	remaining: 4m 54s
# 426:	learn: 0.0732072	total: 3m 39s	remaining: 4m 54s
# 427:	learn: 0.0730692	total: 3m 40s	remaining: 4m 54s
# 428:	learn: 0.0729962	total: 3m 40s	remaining: 4m 53s
# 429:	learn: 0.0729091	total: 3m 41s	remaining: 4m 53s
# 430:	learn: 0.0727917	total: 3m 41s	remaining: 4m 52s
# 431:	learn: 0.0727242	total: 3m 42s	remaining: 4m 52s
# 432:	learn: 0.0727093	total: 3m 42s	remaining: 4m 51s
# 433:	learn: 0.0726243	total: 3m 42s	remaining: 4m 50s
# 434:	learn: 0.0725542	total: 3m 43s	remaining: 4m 50s
# 435:	learn: 0.0724105	total: 3m 44s	remaining: 4m 49s
# 436:	learn: 0.0723092	total: 3m 44s	remaining: 4m 49s
# 437:	learn: 0.0721736	total: 3m 45s	remaining: 4m 48s
# 438:	learn: 0.0720073	total: 3m 45s	remaining: 4m 48s
# 439:	learn: 0.0719224	total: 3m 46s	remaining: 4m 47s
# 440:	learn: 0.0718585	total: 3m 46s	remaining: 4m 47s
# 441:	learn: 0.0717365	total: 3m 47s	remaining: 4m 46s
# 442:	learn: 0.0716441	total: 3m 47s	remaining: 4m 46s
# 443:	learn: 0.0715624	total: 3m 48s	remaining: 4m 45s
# 444:	learn: 0.0714240	total: 3m 48s	remaining: 4m 45s
# 445:	learn: 0.0712748	total: 3m 49s	remaining: 4m 44s
# 446:	learn: 0.0711199	total: 3m 49s	remaining: 4m 44s
# 447:	learn: 0.0710270	total: 3m 50s	remaining: 4m 43s
# 448:	learn: 0.0708703	total: 3m 50s	remaining: 4m 42s
# 449:	learn: 0.0707847	total: 3m 51s	remaining: 4m 42s
# 450:	learn: 0.0707078	total: 3m 51s	remaining: 4m 41s
# 451:	learn: 0.0706618	total: 3m 52s	remaining: 4m 41s
# 452:	learn: 0.0705433	total: 3m 52s	remaining: 4m 40s
# 453:	learn: 0.0704008	total: 3m 53s	remaining: 4m 40s
# 454:	learn: 0.0702661	total: 3m 53s	remaining: 4m 39s
# 455:	learn: 0.0702201	total: 3m 54s	remaining: 4m 39s
# 456:	learn: 0.0701190	total: 3m 54s	remaining: 4m 38s
# 457:	learn: 0.0699282	total: 3m 55s	remaining: 4m 38s
# 458:	learn: 0.0698783	total: 3m 55s	remaining: 4m 37s
# 459:	learn: 0.0698113	total: 3m 56s	remaining: 4m 37s
# 460:	learn: 0.0697267	total: 3m 56s	remaining: 4m 36s
# 461:	learn: 0.0695751	total: 3m 57s	remaining: 4m 36s
# 462:	learn: 0.0694797	total: 3m 57s	remaining: 4m 35s
# 463:	learn: 0.0694053	total: 3m 58s	remaining: 4m 34s
# 464:	learn: 0.0692596	total: 3m 58s	remaining: 4m 34s
# 465:	learn: 0.0691809	total: 3m 58s	remaining: 4m 33s
# 466:	learn: 0.0690844	total: 3m 59s	remaining: 4m 33s
# 467:	learn: 0.0689990	total: 4m	remaining: 4m 32s
# 468:	learn: 0.0689037	total: 4m	remaining: 4m 32s
# 469:	learn: 0.0687641	total: 4m 1s	remaining: 4m 31s
# 470:	learn: 0.0686501	total: 4m 1s	remaining: 4m 31s
# 471:	learn: 0.0685615	total: 4m 2s	remaining: 4m 30s
# 472:	learn: 0.0683705	total: 4m 2s	remaining: 4m 30s
# 473:	learn: 0.0683098	total: 4m 2s	remaining: 4m 29s
# 474:	learn: 0.0682614	total: 4m 3s	remaining: 4m 29s
# 475:	learn: 0.0681769	total: 4m 4s	remaining: 4m 28s
# 476:	learn: 0.0680516	total: 4m 4s	remaining: 4m 28s
# 477:	learn: 0.0679548	total: 4m 5s	remaining: 4m 27s
# 478:	learn: 0.0679249	total: 4m 5s	remaining: 4m 27s
# 479:	learn: 0.0678596	total: 4m 6s	remaining: 4m 26s
# 480:	learn: 0.0677503	total: 4m 6s	remaining: 4m 26s
# 481:	learn: 0.0676846	total: 4m 7s	remaining: 4m 25s
# 482:	learn: 0.0676263	total: 4m 7s	remaining: 4m 25s
# 483:	learn: 0.0675247	total: 4m 8s	remaining: 4m 24s
# 484:	learn: 0.0674643	total: 4m 8s	remaining: 4m 24s
# 485:	learn: 0.0673902	total: 4m 9s	remaining: 4m 23s
# 486:	learn: 0.0673154	total: 4m 9s	remaining: 4m 23s
# 487:	learn: 0.0672475	total: 4m 10s	remaining: 4m 22s
# 488:	learn: 0.0671515	total: 4m 10s	remaining: 4m 22s
# 489:	learn: 0.0670930	total: 4m 11s	remaining: 4m 21s
# 490:	learn: 0.0669847	total: 4m 11s	remaining: 4m 21s
# 491:	learn: 0.0668919	total: 4m 12s	remaining: 4m 20s
# 492:	learn: 0.0667962	total: 4m 13s	remaining: 4m 20s
# 493:	learn: 0.0667347	total: 4m 13s	remaining: 4m 19s
# 494:	learn: 0.0665676	total: 4m 14s	remaining: 4m 19s
# 495:	learn: 0.0664375	total: 4m 14s	remaining: 4m 18s
# 496:	learn: 0.0663225	total: 4m 15s	remaining: 4m 18s
# 497:	learn: 0.0662556	total: 4m 15s	remaining: 4m 17s
# 498:	learn: 0.0661425	total: 4m 16s	remaining: 4m 17s
# 499:	learn: 0.0660383	total: 4m 16s	remaining: 4m 16s
# 500:	learn: 0.0659731	total: 4m 16s	remaining: 4m 15s
# 501:	learn: 0.0658800	total: 4m 17s	remaining: 4m 15s
# 502:	learn: 0.0657838	total: 4m 18s	remaining: 4m 15s
# 503:	learn: 0.0656880	total: 4m 18s	remaining: 4m 14s
# 504:	learn: 0.0656512	total: 4m 19s	remaining: 4m 14s
# 505:	learn: 0.0655669	total: 4m 19s	remaining: 4m 13s
# 506:	learn: 0.0655097	total: 4m 20s	remaining: 4m 13s
# 507:	learn: 0.0654021	total: 4m 20s	remaining: 4m 12s
# 508:	learn: 0.0653492	total: 4m 21s	remaining: 4m 11s
# 509:	learn: 0.0652707	total: 4m 21s	remaining: 4m 11s
# 510:	learn: 0.0651588	total: 4m 21s	remaining: 4m 10s
# 511:	learn: 0.0651002	total: 4m 22s	remaining: 4m 10s
# 512:	learn: 0.0650276	total: 4m 22s	remaining: 4m 9s
# 513:	learn: 0.0649452	total: 4m 23s	remaining: 4m 9s
# 514:	learn: 0.0648175	total: 4m 24s	remaining: 4m 8s
# 515:	learn: 0.0646495	total: 4m 24s	remaining: 4m 8s
# 516:	learn: 0.0645780	total: 4m 25s	remaining: 4m 8s
# 517:	learn: 0.0644968	total: 4m 26s	remaining: 4m 7s
# 518:	learn: 0.0644565	total: 4m 27s	remaining: 4m 7s
# 519:	learn: 0.0644229	total: 4m 27s	remaining: 4m 7s
# 520:	learn: 0.0643664	total: 4m 28s	remaining: 4m 6s
# 521:	learn: 0.0642807	total: 4m 28s	remaining: 4m 6s
# 522:	learn: 0.0642130	total: 4m 29s	remaining: 4m 5s
# 523:	learn: 0.0641318	total: 4m 29s	remaining: 4m 5s
# 524:	learn: 0.0640790	total: 4m 30s	remaining: 4m 4s
# 525:	learn: 0.0639564	total: 4m 31s	remaining: 4m 4s
# 526:	learn: 0.0638960	total: 4m 31s	remaining: 4m 3s
# 527:	learn: 0.0637870	total: 4m 32s	remaining: 4m 3s
# 528:	learn: 0.0637335	total: 4m 33s	remaining: 4m 3s
# 529:	learn: 0.0636870	total: 4m 33s	remaining: 4m 2s
# 530:	learn: 0.0636137	total: 4m 34s	remaining: 4m 2s
# 531:	learn: 0.0634997	total: 4m 34s	remaining: 4m 1s
# 532:	learn: 0.0634197	total: 4m 35s	remaining: 4m 1s
# 533:	learn: 0.0633336	total: 4m 35s	remaining: 4m
# 534:	learn: 0.0632478	total: 4m 36s	remaining: 4m
# 535:	learn: 0.0630616	total: 4m 37s	remaining: 3m 59s
# 536:	learn: 0.0629807	total: 4m 37s	remaining: 3m 59s
# 537:	learn: 0.0628951	total: 4m 38s	remaining: 3m 58s
# 538:	learn: 0.0628318	total: 4m 38s	remaining: 3m 58s
# 539:	learn: 0.0627924	total: 4m 39s	remaining: 3m 58s
# 540:	learn: 0.0626939	total: 4m 40s	remaining: 3m 57s
# 541:	learn: 0.0626141	total: 4m 40s	remaining: 3m 57s
# 542:	learn: 0.0625654	total: 4m 41s	remaining: 3m 56s
# 543:	learn: 0.0624270	total: 4m 41s	remaining: 3m 56s
# 544:	learn: 0.0623957	total: 4m 42s	remaining: 3m 55s
# 545:	learn: 0.0623567	total: 4m 43s	remaining: 3m 55s
# 546:	learn: 0.0622949	total: 4m 43s	remaining: 3m 54s
# 547:	learn: 0.0621817	total: 4m 44s	remaining: 3m 54s
# 548:	learn: 0.0621160	total: 4m 44s	remaining: 3m 53s
# 549:	learn: 0.0620350	total: 4m 44s	remaining: 3m 53s
# 550:	learn: 0.0619357	total: 4m 45s	remaining: 3m 52s
# 551:	learn: 0.0618087	total: 4m 45s	remaining: 3m 52s
# 552:	learn: 0.0617413	total: 4m 46s	remaining: 3m 51s
# 553:	learn: 0.0616994	total: 4m 47s	remaining: 3m 51s
# 554:	learn: 0.0616463	total: 4m 47s	remaining: 3m 50s
# 555:	learn: 0.0615270	total: 4m 47s	remaining: 3m 49s
# 556:	learn: 0.0613894	total: 4m 48s	remaining: 3m 49s
# 557:	learn: 0.0613003	total: 4m 49s	remaining: 3m 49s
# 558:	learn: 0.0612089	total: 4m 49s	remaining: 3m 48s
# 559:	learn: 0.0611379	total: 4m 50s	remaining: 3m 48s
# 560:	learn: 0.0610837	total: 4m 50s	remaining: 3m 47s
# 561:	learn: 0.0609634	total: 4m 51s	remaining: 3m 47s
# 562:	learn: 0.0609098	total: 4m 51s	remaining: 3m 46s
# 563:	learn: 0.0607908	total: 4m 52s	remaining: 3m 45s
# 564:	learn: 0.0607285	total: 4m 52s	remaining: 3m 45s
# 565:	learn: 0.0606680	total: 4m 53s	remaining: 3m 44s
# 566:	learn: 0.0605710	total: 4m 53s	remaining: 3m 44s
# 567:	learn: 0.0604081	total: 4m 54s	remaining: 3m 43s
# 568:	learn: 0.0603693	total: 4m 54s	remaining: 3m 43s
# 569:	learn: 0.0602984	total: 4m 55s	remaining: 3m 42s
# 570:	learn: 0.0602605	total: 4m 55s	remaining: 3m 42s
# 571:	learn: 0.0600835	total: 4m 56s	remaining: 3m 41s
# 572:	learn: 0.0600351	total: 4m 56s	remaining: 3m 41s
# 573:	learn: 0.0600063	total: 4m 57s	remaining: 3m 40s
# 574:	learn: 0.0599476	total: 4m 57s	remaining: 3m 40s
# 575:	learn: 0.0598847	total: 4m 58s	remaining: 3m 39s
# 576:	learn: 0.0598028	total: 4m 58s	remaining: 3m 39s
# 577:	learn: 0.0597629	total: 4m 59s	remaining: 3m 38s
# 578:	learn: 0.0597039	total: 4m 59s	remaining: 3m 38s
# 579:	learn: 0.0596135	total: 5m	remaining: 3m 37s
# 580:	learn: 0.0595727	total: 5m 1s	remaining: 3m 37s
# 581:	learn: 0.0594890	total: 5m 1s	remaining: 3m 36s
# 582:	learn: 0.0593976	total: 5m 2s	remaining: 3m 36s
# 583:	learn: 0.0593523	total: 5m 3s	remaining: 3m 35s
# 584:	learn: 0.0593145	total: 5m 3s	remaining: 3m 35s
# 585:	learn: 0.0592270	total: 5m 4s	remaining: 3m 35s
# 586:	learn: 0.0591226	total: 5m 5s	remaining: 3m 34s
# 587:	learn: 0.0590555	total: 5m 5s	remaining: 3m 34s
# 588:	learn: 0.0589833	total: 5m 7s	remaining: 3m 34s
# 589:	learn: 0.0589458	total: 5m 7s	remaining: 3m 33s
# 590:	learn: 0.0588747	total: 5m 8s	remaining: 3m 33s
# 591:	learn: 0.0587589	total: 5m 8s	remaining: 3m 32s
# 592:	learn: 0.0586910	total: 5m 9s	remaining: 3m 32s
# 593:	learn: 0.0586173	total: 5m 9s	remaining: 3m 31s
# 594:	learn: 0.0585294	total: 5m 10s	remaining: 3m 31s
# 595:	learn: 0.0585018	total: 5m 10s	remaining: 3m 30s
# 596:	learn: 0.0584520	total: 5m 11s	remaining: 3m 30s
# 597:	learn: 0.0583981	total: 5m 12s	remaining: 3m 30s
# 598:	learn: 0.0583444	total: 5m 13s	remaining: 3m 29s
# 599:	learn: 0.0582647	total: 5m 14s	remaining: 3m 29s
# 600:	learn: 0.0581292	total: 5m 14s	remaining: 3m 29s
# 601:	learn: 0.0580463	total: 5m 15s	remaining: 3m 28s
# 602:	learn: 0.0580025	total: 5m 16s	remaining: 3m 28s
# 603:	learn: 0.0579630	total: 5m 16s	remaining: 3m 27s
# 604:	learn: 0.0579145	total: 5m 17s	remaining: 3m 27s
# 605:	learn: 0.0578085	total: 5m 17s	remaining: 3m 26s
# 606:	learn: 0.0577517	total: 5m 18s	remaining: 3m 26s
# 607:	learn: 0.0576994	total: 5m 19s	remaining: 3m 25s
# 608:	learn: 0.0576398	total: 5m 19s	remaining: 3m 25s
# 609:	learn: 0.0575889	total: 5m 20s	remaining: 3m 24s
# 610:	learn: 0.0575200	total: 5m 21s	remaining: 3m 24s
# 611:	learn: 0.0574523	total: 5m 21s	remaining: 3m 23s
# 612:	learn: 0.0573759	total: 5m 22s	remaining: 3m 23s
# 613:	learn: 0.0572747	total: 5m 23s	remaining: 3m 23s
# 614:	learn: 0.0571921	total: 5m 23s	remaining: 3m 22s
# 615:	learn: 0.0571134	total: 5m 24s	remaining: 3m 22s
# 616:	learn: 0.0570766	total: 5m 25s	remaining: 3m 22s
# 617:	learn: 0.0570164	total: 5m 26s	remaining: 3m 21s
# 618:	learn: 0.0569583	total: 5m 26s	remaining: 3m 21s
# 619:	learn: 0.0568978	total: 5m 27s	remaining: 3m 20s
# 620:	learn: 0.0568670	total: 5m 28s	remaining: 3m 20s
# 621:	learn: 0.0568275	total: 5m 29s	remaining: 3m 19s
# 622:	learn: 0.0567191	total: 5m 29s	remaining: 3m 19s
# 623:	learn: 0.0566788	total: 5m 30s	remaining: 3m 19s
# 624:	learn: 0.0566062	total: 5m 30s	remaining: 3m 18s
# 625:	learn: 0.0565170	total: 5m 31s	remaining: 3m 18s
# 626:	learn: 0.0564953	total: 5m 31s	remaining: 3m 17s
# 627:	learn: 0.0564587	total: 5m 32s	remaining: 3m 16s
# 628:	learn: 0.0563553	total: 5m 33s	remaining: 3m 16s
# 629:	learn: 0.0562925	total: 5m 34s	remaining: 3m 16s
# 630:	learn: 0.0562117	total: 5m 34s	remaining: 3m 15s
# 631:	learn: 0.0561514	total: 5m 35s	remaining: 3m 15s
# 632:	learn: 0.0560611	total: 5m 35s	remaining: 3m 14s
# 633:	learn: 0.0559975	total: 5m 36s	remaining: 3m 14s
# 634:	learn: 0.0559573	total: 5m 36s	remaining: 3m 13s
# 635:	learn: 0.0558414	total: 5m 37s	remaining: 3m 13s
# 636:	learn: 0.0557961	total: 5m 38s	remaining: 3m 12s
# 637:	learn: 0.0557478	total: 5m 38s	remaining: 3m 12s
# 638:	learn: 0.0556840	total: 5m 39s	remaining: 3m 11s
# 639:	learn: 0.0556166	total: 5m 39s	remaining: 3m 11s
# 640:	learn: 0.0555631	total: 5m 40s	remaining: 3m 10s
# 641:	learn: 0.0554782	total: 5m 41s	remaining: 3m 10s
# 642:	learn: 0.0554167	total: 5m 41s	remaining: 3m 9s
# 643:	learn: 0.0553731	total: 5m 42s	remaining: 3m 9s
# 644:	learn: 0.0553310	total: 5m 42s	remaining: 3m 8s
# 645:	learn: 0.0552748	total: 5m 43s	remaining: 3m 8s
# 646:	learn: 0.0552234	total: 5m 44s	remaining: 3m 7s
# 647:	learn: 0.0551645	total: 5m 44s	remaining: 3m 7s
# 648:	learn: 0.0550674	total: 5m 45s	remaining: 3m 6s
# 649:	learn: 0.0550076	total: 5m 45s	remaining: 3m 6s
# 650:	learn: 0.0548933	total: 5m 46s	remaining: 3m 5s
# 651:	learn: 0.0548425	total: 5m 47s	remaining: 3m 5s
# 652:	learn: 0.0547751	total: 5m 48s	remaining: 3m 4s
# 653:	learn: 0.0546596	total: 5m 48s	remaining: 3m 4s
# 654:	learn: 0.0545750	total: 5m 49s	remaining: 3m 4s
# 655:	learn: 0.0544945	total: 5m 50s	remaining: 3m 3s
# 656:	learn: 0.0544465	total: 5m 50s	remaining: 3m 3s
# 657:	learn: 0.0543938	total: 5m 51s	remaining: 3m 2s
# 658:	learn: 0.0543647	total: 5m 51s	remaining: 3m 2s
# 659:	learn: 0.0543050	total: 5m 52s	remaining: 3m 1s
# 660:	learn: 0.0542628	total: 5m 53s	remaining: 3m 1s
# 661:	learn: 0.0541929	total: 5m 54s	remaining: 3m
# 662:	learn: 0.0540835	total: 5m 54s	remaining: 3m
# 663:	learn: 0.0540243	total: 5m 55s	remaining: 2m 59s
# 664:	learn: 0.0539955	total: 5m 55s	remaining: 2m 59s
# 665:	learn: 0.0538873	total: 5m 56s	remaining: 2m 58s
# 666:	learn: 0.0538545	total: 5m 57s	remaining: 2m 58s
# 667:	learn: 0.0538133	total: 5m 57s	remaining: 2m 57s
# 668:	learn: 0.0537552	total: 5m 58s	remaining: 2m 57s
# 669:	learn: 0.0536941	total: 5m 59s	remaining: 2m 56s
# 670:	learn: 0.0536383	total: 5m 59s	remaining: 2m 56s
# 671:	learn: 0.0535963	total: 6m	remaining: 2m 55s
# 672:	learn: 0.0535499	total: 6m	remaining: 2m 55s
# 673:	learn: 0.0534456	total: 6m 1s	remaining: 2m 54s
# 674:	learn: 0.0533960	total: 6m 2s	remaining: 2m 54s
# 675:	learn: 0.0533191	total: 6m 2s	remaining: 2m 53s
# 676:	learn: 0.0532400	total: 6m 3s	remaining: 2m 53s
# 677:	learn: 0.0532062	total: 6m 4s	remaining: 2m 52s
# 678:	learn: 0.0531671	total: 6m 4s	remaining: 2m 52s
# 679:	learn: 0.0531401	total: 6m 4s	remaining: 2m 51s
# 680:	learn: 0.0530694	total: 6m 5s	remaining: 2m 51s
# 681:	learn: 0.0530067	total: 6m 6s	remaining: 2m 50s
# 682:	learn: 0.0529384	total: 6m 7s	remaining: 2m 50s
# 683:	learn: 0.0529041	total: 6m 7s	remaining: 2m 49s
# 684:	learn: 0.0528548	total: 6m 8s	remaining: 2m 49s
# 685:	learn: 0.0527889	total: 6m 8s	remaining: 2m 48s
# 686:	learn: 0.0527579	total: 6m 9s	remaining: 2m 48s
# 687:	learn: 0.0527261	total: 6m 10s	remaining: 2m 48s
# 688:	learn: 0.0526556	total: 6m 11s	remaining: 2m 47s
# 689:	learn: 0.0525943	total: 6m 12s	remaining: 2m 47s
# 690:	learn: 0.0525005	total: 6m 12s	remaining: 2m 46s
# 691:	learn: 0.0524500	total: 6m 13s	remaining: 2m 46s
# 692:	learn: 0.0524093	total: 6m 14s	remaining: 2m 45s
# 693:	learn: 0.0523763	total: 6m 14s	remaining: 2m 45s
# 694:	learn: 0.0523438	total: 6m 15s	remaining: 2m 44s
# 695:	learn: 0.0522237	total: 6m 16s	remaining: 2m 44s
# 696:	learn: 0.0521771	total: 6m 17s	remaining: 2m 43s
# 697:	learn: 0.0521275	total: 6m 17s	remaining: 2m 43s
# 698:	learn: 0.0520291	total: 6m 18s	remaining: 2m 42s
# 699:	learn: 0.0519777	total: 6m 18s	remaining: 2m 42s
# 700:	learn: 0.0519358	total: 6m 19s	remaining: 2m 41s
# 701:	learn: 0.0518915	total: 6m 19s	remaining: 2m 41s
# 702:	learn: 0.0518291	total: 6m 20s	remaining: 2m 40s
# 703:	learn: 0.0517810	total: 6m 21s	remaining: 2m 40s
# 704:	learn: 0.0516967	total: 6m 21s	remaining: 2m 39s
# 705:	learn: 0.0516547	total: 6m 22s	remaining: 2m 39s
# 706:	learn: 0.0516020	total: 6m 23s	remaining: 2m 38s
# 707:	learn: 0.0515596	total: 6m 23s	remaining: 2m 38s
# 708:	learn: 0.0515366	total: 6m 24s	remaining: 2m 37s
# 709:	learn: 0.0515141	total: 6m 25s	remaining: 2m 37s
# 710:	learn: 0.0514623	total: 6m 25s	remaining: 2m 36s
# 711:	learn: 0.0513907	total: 6m 26s	remaining: 2m 36s
# 712:	learn: 0.0513239	total: 6m 27s	remaining: 2m 35s
# 713:	learn: 0.0511834	total: 6m 27s	remaining: 2m 35s
# 714:	learn: 0.0510298	total: 6m 28s	remaining: 2m 34s
# 715:	learn: 0.0509553	total: 6m 29s	remaining: 2m 34s
# 716:	learn: 0.0509198	total: 6m 29s	remaining: 2m 33s
# 717:	learn: 0.0508757	total: 6m 30s	remaining: 2m 33s
# 718:	learn: 0.0507889	total: 6m 30s	remaining: 2m 32s
# 719:	learn: 0.0507003	total: 6m 31s	remaining: 2m 32s
# 720:	learn: 0.0506394	total: 6m 32s	remaining: 2m 31s
# 721:	learn: 0.0506046	total: 6m 32s	remaining: 2m 31s
# 722:	learn: 0.0504673	total: 6m 33s	remaining: 2m 30s
# 723:	learn: 0.0503997	total: 6m 33s	remaining: 2m 30s
# 724:	learn: 0.0503388	total: 6m 34s	remaining: 2m 29s
# 725:	learn: 0.0502842	total: 6m 35s	remaining: 2m 29s
# 726:	learn: 0.0502301	total: 6m 35s	remaining: 2m 28s
# 727:	learn: 0.0501763	total: 6m 36s	remaining: 2m 28s
# 728:	learn: 0.0500429	total: 6m 37s	remaining: 2m 27s
# 729:	learn: 0.0499825	total: 6m 37s	remaining: 2m 27s
# 730:	learn: 0.0499231	total: 6m 38s	remaining: 2m 26s
# 731:	learn: 0.0498579	total: 6m 38s	remaining: 2m 26s
# 732:	learn: 0.0498127	total: 6m 39s	remaining: 2m 25s
# 733:	learn: 0.0497752	total: 6m 39s	remaining: 2m 24s
# 734:	learn: 0.0496641	total: 6m 40s	remaining: 2m 24s
# 735:	learn: 0.0496213	total: 6m 41s	remaining: 2m 23s
# 736:	learn: 0.0495177	total: 6m 41s	remaining: 2m 23s
# 737:	learn: 0.0494919	total: 6m 42s	remaining: 2m 22s
# 738:	learn: 0.0494162	total: 6m 43s	remaining: 2m 22s
# 739:	learn: 0.0493663	total: 6m 43s	remaining: 2m 21s
# 740:	learn: 0.0493169	total: 6m 44s	remaining: 2m 21s
# 741:	learn: 0.0492245	total: 6m 45s	remaining: 2m 20s
# 742:	learn: 0.0491546	total: 6m 45s	remaining: 2m 20s
# 743:	learn: 0.0491219	total: 6m 46s	remaining: 2m 19s
# 744:	learn: 0.0490153	total: 6m 47s	remaining: 2m 19s
# 745:	learn: 0.0489759	total: 6m 47s	remaining: 2m 18s
# 746:	learn: 0.0489504	total: 6m 48s	remaining: 2m 18s
# 747:	learn: 0.0489172	total: 6m 48s	remaining: 2m 17s
# 748:	learn: 0.0488389	total: 6m 49s	remaining: 2m 17s
# 749:	learn: 0.0487785	total: 6m 50s	remaining: 2m 16s
# 750:	learn: 0.0487140	total: 6m 50s	remaining: 2m 16s
# 751:	learn: 0.0486567	total: 6m 51s	remaining: 2m 15s
# 752:	learn: 0.0486339	total: 6m 52s	remaining: 2m 15s
# 753:	learn: 0.0485655	total: 6m 52s	remaining: 2m 14s
# 754:	learn: 0.0485125	total: 6m 53s	remaining: 2m 14s
# 755:	learn: 0.0484732	total: 6m 54s	remaining: 2m 13s
# 756:	learn: 0.0484185	total: 6m 54s	remaining: 2m 13s
# 757:	learn: 0.0483843	total: 6m 55s	remaining: 2m 12s
# 758:	learn: 0.0483086	total: 6m 55s	remaining: 2m 12s
# 759:	learn: 0.0482772	total: 6m 56s	remaining: 2m 11s
# 760:	learn: 0.0482210	total: 6m 57s	remaining: 2m 11s
# 761:	learn: 0.0481837	total: 6m 57s	remaining: 2m 10s
# 762:	learn: 0.0480694	total: 6m 58s	remaining: 2m 9s
# 763:	learn: 0.0480661	total: 6m 58s	remaining: 2m 9s
# 764:	learn: 0.0480416	total: 6m 59s	remaining: 2m 8s
# 765:	learn: 0.0479937	total: 6m 59s	remaining: 2m 8s
# 766:	learn: 0.0479391	total: 7m	remaining: 2m 7s
# 767:	learn: 0.0478593	total: 7m 1s	remaining: 2m 7s
# 768:	learn: 0.0478024	total: 7m 1s	remaining: 2m 6s
# 769:	learn: 0.0477551	total: 7m 2s	remaining: 2m 6s
# 770:	learn: 0.0477074	total: 7m 2s	remaining: 2m 5s
# 771:	learn: 0.0476644	total: 7m 3s	remaining: 2m 5s
# 772:	learn: 0.0476155	total: 7m 4s	remaining: 2m 4s
# 773:	learn: 0.0475752	total: 7m 4s	remaining: 2m 4s
# 774:	learn: 0.0474646	total: 7m 5s	remaining: 2m 3s
# 775:	learn: 0.0474403	total: 7m 6s	remaining: 2m 3s
# 776:	learn: 0.0474031	total: 7m 6s	remaining: 2m 2s
# 777:	learn: 0.0473740	total: 7m 7s	remaining: 2m 1s
# 778:	learn: 0.0473228	total: 7m 7s	remaining: 2m 1s
# 779:	learn: 0.0472157	total: 7m 8s	remaining: 2m
# 780:	learn: 0.0471808	total: 7m 9s	remaining: 2m
# 781:	learn: 0.0471037	total: 7m 9s	remaining: 1m 59s
# 782:	learn: 0.0470708	total: 7m 10s	remaining: 1m 59s
# 783:	learn: 0.0470265	total: 7m 11s	remaining: 1m 58s
# 784:	learn: 0.0470048	total: 7m 11s	remaining: 1m 58s
# 785:	learn: 0.0469358	total: 7m 12s	remaining: 1m 57s
# 786:	learn: 0.0469212	total: 7m 12s	remaining: 1m 57s
# 787:	learn: 0.0468976	total: 7m 13s	remaining: 1m 56s
# 788:	learn: 0.0468261	total: 7m 14s	remaining: 1m 56s
# 789:	learn: 0.0467888	total: 7m 14s	remaining: 1m 55s
# 790:	learn: 0.0467421	total: 7m 15s	remaining: 1m 55s
# 791:	learn: 0.0466900	total: 7m 16s	remaining: 1m 54s
# 792:	learn: 0.0466160	total: 7m 16s	remaining: 1m 54s
# 793:	learn: 0.0465828	total: 7m 17s	remaining: 1m 53s
# 794:	learn: 0.0465313	total: 7m 18s	remaining: 1m 52s
# 795:	learn: 0.0464869	total: 7m 18s	remaining: 1m 52s
# 796:	learn: 0.0464011	total: 7m 19s	remaining: 1m 51s
# 797:	learn: 0.0463738	total: 7m 20s	remaining: 1m 51s
# 798:	learn: 0.0463298	total: 7m 20s	remaining: 1m 50s
# 799:	learn: 0.0463092	total: 7m 21s	remaining: 1m 50s
# 800:	learn: 0.0462865	total: 7m 22s	remaining: 1m 49s
# 801:	learn: 0.0462324	total: 7m 23s	remaining: 1m 49s
# 802:	learn: 0.0461876	total: 7m 23s	remaining: 1m 48s
# 803:	learn: 0.0461352	total: 7m 24s	remaining: 1m 48s
# 804:	learn: 0.0461039	total: 7m 25s	remaining: 1m 47s
# 805:	learn: 0.0460462	total: 7m 25s	remaining: 1m 47s
# 806:	learn: 0.0459823	total: 7m 26s	remaining: 1m 46s
# 807:	learn: 0.0459182	total: 7m 27s	remaining: 1m 46s
# 808:	learn: 0.0458622	total: 7m 28s	remaining: 1m 45s
# 809:	learn: 0.0458230	total: 7m 28s	remaining: 1m 45s
# 810:	learn: 0.0457865	total: 7m 29s	remaining: 1m 44s
# 811:	learn: 0.0457452	total: 7m 30s	remaining: 1m 44s
# 812:	learn: 0.0457037	total: 7m 30s	remaining: 1m 43s
# 813:	learn: 0.0456525	total: 7m 31s	remaining: 1m 43s
# 814:	learn: 0.0456145	total: 7m 32s	remaining: 1m 42s
# 815:	learn: 0.0455634	total: 7m 32s	remaining: 1m 42s
# 816:	learn: 0.0455140	total: 7m 33s	remaining: 1m 41s
# 817:	learn: 0.0454859	total: 7m 34s	remaining: 1m 41s
# 818:	learn: 0.0454355	total: 7m 34s	remaining: 1m 40s
# 819:	learn: 0.0454045	total: 7m 35s	remaining: 1m 39s
# 820:	learn: 0.0453727	total: 7m 35s	remaining: 1m 39s
# 821:	learn: 0.0453370	total: 7m 36s	remaining: 1m 38s
# 822:	learn: 0.0452923	total: 7m 36s	remaining: 1m 38s
# 823:	learn: 0.0452700	total: 7m 37s	remaining: 1m 37s
# 824:	learn: 0.0452337	total: 7m 38s	remaining: 1m 37s
# 825:	learn: 0.0452148	total: 7m 38s	remaining: 1m 36s
# 826:	learn: 0.0451229	total: 7m 39s	remaining: 1m 36s
# 827:	learn: 0.0450742	total: 7m 40s	remaining: 1m 35s
# 828:	learn: 0.0450157	total: 7m 41s	remaining: 1m 35s
# 829:	learn: 0.0449704	total: 7m 41s	remaining: 1m 34s
# 830:	learn: 0.0449342	total: 7m 42s	remaining: 1m 34s
# 831:	learn: 0.0448865	total: 7m 43s	remaining: 1m 33s
# 832:	learn: 0.0448676	total: 7m 43s	remaining: 1m 32s
# 833:	learn: 0.0448182	total: 7m 44s	remaining: 1m 32s
# 834:	learn: 0.0447605	total: 7m 44s	remaining: 1m 31s
# 835:	learn: 0.0446979	total: 7m 45s	remaining: 1m 31s
# 836:	learn: 0.0446453	total: 7m 46s	remaining: 1m 30s
# 837:	learn: 0.0445466	total: 7m 46s	remaining: 1m 30s
# 838:	learn: 0.0445017	total: 7m 47s	remaining: 1m 29s
# 839:	learn: 0.0444757	total: 7m 48s	remaining: 1m 29s
# 840:	learn: 0.0444287	total: 7m 48s	remaining: 1m 28s
# 841:	learn: 0.0443750	total: 7m 49s	remaining: 1m 28s
# 842:	learn: 0.0443383	total: 7m 50s	remaining: 1m 27s
# 843:	learn: 0.0443038	total: 7m 51s	remaining: 1m 27s
# 844:	learn: 0.0442648	total: 7m 51s	remaining: 1m 26s
# 845:	learn: 0.0442321	total: 7m 52s	remaining: 1m 25s
# 846:	learn: 0.0441785	total: 7m 52s	remaining: 1m 25s
# 847:	learn: 0.0441159	total: 7m 53s	remaining: 1m 24s
# 848:	learn: 0.0440774	total: 7m 54s	remaining: 1m 24s
# 849:	learn: 0.0440430	total: 7m 54s	remaining: 1m 23s
# 850:	learn: 0.0439976	total: 7m 55s	remaining: 1m 23s
# 851:	learn: 0.0439236	total: 7m 56s	remaining: 1m 22s
# 852:	learn: 0.0438792	total: 7m 56s	remaining: 1m 22s
# 853:	learn: 0.0438472	total: 7m 57s	remaining: 1m 21s
# 854:	learn: 0.0438048	total: 7m 58s	remaining: 1m 21s
# 855:	learn: 0.0437512	total: 7m 58s	remaining: 1m 20s
# 856:	learn: 0.0437277	total: 7m 59s	remaining: 1m 20s
# 857:	learn: 0.0436789	total: 8m	remaining: 1m 19s
# 858:	learn: 0.0436286	total: 8m	remaining: 1m 18s
# 859:	learn: 0.0435980	total: 8m 1s	remaining: 1m 18s
# 860:	learn: 0.0435562	total: 8m 2s	remaining: 1m 17s
# 861:	learn: 0.0435255	total: 8m 2s	remaining: 1m 17s
# 862:	learn: 0.0434835	total: 8m 3s	remaining: 1m 16s
# 863:	learn: 0.0434249	total: 8m 3s	remaining: 1m 16s
# 864:	learn: 0.0433870	total: 8m 4s	remaining: 1m 15s
# 865:	learn: 0.0433478	total: 8m 5s	remaining: 1m 15s
# 866:	learn: 0.0433065	total: 8m 6s	remaining: 1m 14s
# 867:	learn: 0.0432747	total: 8m 6s	remaining: 1m 14s
# 868:	learn: 0.0432085	total: 8m 7s	remaining: 1m 13s
# 869:	learn: 0.0431867	total: 8m 7s	remaining: 1m 12s
# 870:	learn: 0.0431378	total: 8m 8s	remaining: 1m 12s
# 871:	learn: 0.0431132	total: 8m 9s	remaining: 1m 11s
# 872:	learn: 0.0430808	total: 8m 10s	remaining: 1m 11s
# 873:	learn: 0.0429994	total: 8m 10s	remaining: 1m 10s
# 874:	learn: 0.0429454	total: 8m 11s	remaining: 1m 10s
# 875:	learn: 0.0428971	total: 8m 11s	remaining: 1m 9s
# 876:	learn: 0.0428844	total: 8m 12s	remaining: 1m 9s
# 877:	learn: 0.0428574	total: 8m 12s	remaining: 1m 8s
# 878:	learn: 0.0428278	total: 8m 13s	remaining: 1m 7s
# 879:	learn: 0.0427820	total: 8m 14s	remaining: 1m 7s
# 880:	learn: 0.0427500	total: 8m 14s	remaining: 1m 6s
# 881:	learn: 0.0427042	total: 8m 15s	remaining: 1m 6s
# 882:	learn: 0.0426771	total: 8m 15s	remaining: 1m 5s
# 883:	learn: 0.0426512	total: 8m 16s	remaining: 1m 5s
# 884:	learn: 0.0426247	total: 8m 17s	remaining: 1m 4s
# 885:	learn: 0.0425785	total: 8m 17s	remaining: 1m 4s
# 886:	learn: 0.0425233	total: 8m 18s	remaining: 1m 3s
# 887:	learn: 0.0424939	total: 8m 19s	remaining: 1m 2s
# 888:	learn: 0.0424463	total: 8m 19s	remaining: 1m 2s
# 889:	learn: 0.0423960	total: 8m 20s	remaining: 1m 1s
# 890:	learn: 0.0423434	total: 8m 20s	remaining: 1m 1s
# 891:	learn: 0.0423051	total: 8m 21s	remaining: 1m
# 892:	learn: 0.0422564	total: 8m 22s	remaining: 1m
# 893:	learn: 0.0422224	total: 8m 22s	remaining: 59.6s
# 894:	learn: 0.0421865	total: 8m 23s	remaining: 59.1s
# 895:	learn: 0.0421582	total: 8m 23s	remaining: 58.5s
# 896:	learn: 0.0421209	total: 8m 24s	remaining: 57.9s
# 897:	learn: 0.0420602	total: 8m 24s	remaining: 57.3s
# 898:	learn: 0.0420156	total: 8m 25s	remaining: 56.8s
# 899:	learn: 0.0419507	total: 8m 25s	remaining: 56.2s
# ...
# 700:	learn: 0.0504159	total: 6m 7s	remaining: 2m 36s
# 701:	learn: 0.0503636	total: 6m 8s	remaining: 2m 36s
# 702:	learn: 0.0502822	total: 6m 9s	remaining: 2m 35s
# 703:	learn: 0.0502430	total: 6m 9s	remaining: 2m 35s
# 704:	learn: 0.0501648	total: 6m 9s	remaining: 2m 34s
# 705:	learn: 0.0501019	total: 6m 10s	remaining: 2m 34s
# 706:	learn: 0.0500370	total: 6m 10s	remaining: 2m 33s
# 707:	learn: 0.0499596	total: 6m 11s	remaining: 2m 33s
# 708:	learn: 0.0498937	total: 6m 12s	remaining: 2m 32s
# 709:	learn: 0.0498064	total: 6m 12s	remaining: 2m 32s
# 710:	learn: 0.0497576	total: 6m 13s	remaining: 2m 31s
# 711:	learn: 0.0496955	total: 6m 13s	remaining: 2m 31s
# 712:	learn: 0.0496464	total: 6m 14s	remaining: 2m 30s
# 713:	learn: 0.0496104	total: 6m 14s	remaining: 2m 30s
# 714:	learn: 0.0495169	total: 6m 15s	remaining: 2m 29s
# 715:	learn: 0.0494318	total: 6m 15s	remaining: 2m 29s
# 716:	learn: 0.0493807	total: 6m 16s	remaining: 2m 28s
# 717:	learn: 0.0493504	total: 6m 17s	remaining: 2m 28s
# 718:	learn: 0.0493258	total: 6m 17s	remaining: 2m 27s
# 719:	learn: 0.0492582	total: 6m 18s	remaining: 2m 27s
# 720:	learn: 0.0492055	total: 6m 18s	remaining: 2m 26s
# 721:	learn: 0.0491449	total: 6m 19s	remaining: 2m 26s
# 722:	learn: 0.0490916	total: 6m 19s	remaining: 2m 25s
# 723:	learn: 0.0490450	total: 6m 20s	remaining: 2m 25s
# 724:	learn: 0.0489928	total: 6m 20s	remaining: 2m 24s
# 725:	learn: 0.0488911	total: 6m 21s	remaining: 2m 24s
# 726:	learn: 0.0487915	total: 6m 22s	remaining: 2m 23s
# 727:	learn: 0.0487424	total: 6m 22s	remaining: 2m 22s
# 728:	learn: 0.0487106	total: 6m 23s	remaining: 2m 22s
# 729:	learn: 0.0486491	total: 6m 23s	remaining: 2m 21s
# 730:	learn: 0.0486001	total: 6m 24s	remaining: 2m 21s
# 731:	learn: 0.0485429	total: 6m 24s	remaining: 2m 20s
# 732:	learn: 0.0485155	total: 6m 25s	remaining: 2m 20s
# 733:	learn: 0.0484673	total: 6m 25s	remaining: 2m 19s
# 734:	learn: 0.0483711	total: 6m 26s	remaining: 2m 19s
# 735:	learn: 0.0483120	total: 6m 26s	remaining: 2m 18s
# 736:	learn: 0.0482608	total: 6m 27s	remaining: 2m 18s
# 737:	learn: 0.0482400	total: 6m 27s	remaining: 2m 17s
# 738:	learn: 0.0481527	total: 6m 28s	remaining: 2m 17s
# 739:	learn: 0.0481094	total: 6m 28s	remaining: 2m 16s
# 740:	learn: 0.0480667	total: 6m 29s	remaining: 2m 16s
# 741:	learn: 0.0480237	total: 6m 29s	remaining: 2m 15s
# 742:	learn: 0.0479726	total: 6m 30s	remaining: 2m 15s
# 743:	learn: 0.0479330	total: 6m 30s	remaining: 2m 14s
# 744:	learn: 0.0479064	total: 6m 31s	remaining: 2m 13s
# 745:	learn: 0.0478655	total: 6m 32s	remaining: 2m 13s
# 746:	learn: 0.0477858	total: 6m 32s	remaining: 2m 12s
# 747:	learn: 0.0477050	total: 6m 33s	remaining: 2m 12s
# 748:	learn: 0.0476655	total: 6m 33s	remaining: 2m 11s
# 749:	learn: 0.0476257	total: 6m 34s	remaining: 2m 11s
# 750:	learn: 0.0475683	total: 6m 34s	remaining: 2m 10s
# 751:	learn: 0.0475063	total: 6m 35s	remaining: 2m 10s
# 752:	learn: 0.0474726	total: 6m 35s	remaining: 2m 9s
# 753:	learn: 0.0474237	total: 6m 36s	remaining: 2m 9s
# 754:	learn: 0.0473182	total: 6m 36s	remaining: 2m 8s
# 755:	learn: 0.0472901	total: 6m 37s	remaining: 2m 8s
# 756:	learn: 0.0472625	total: 6m 38s	remaining: 2m 7s
# 757:	learn: 0.0471697	total: 6m 38s	remaining: 2m 7s
# 758:	learn: 0.0471429	total: 6m 39s	remaining: 2m 6s
# 759:	learn: 0.0470739	total: 6m 39s	remaining: 2m 6s
# 760:	learn: 0.0470180	total: 6m 40s	remaining: 2m 5s
# 761:	learn: 0.0469845	total: 6m 40s	remaining: 2m 5s
# 762:	learn: 0.0469451	total: 6m 41s	remaining: 2m 4s
# 763:	learn: 0.0468944	total: 6m 41s	remaining: 2m 4s
# 764:	learn: 0.0468452	total: 6m 42s	remaining: 2m 3s
# 765:	learn: 0.0467838	total: 6m 43s	remaining: 2m 3s
# 766:	learn: 0.0467260	total: 6m 43s	remaining: 2m 2s
# 767:	learn: 0.0466894	total: 6m 44s	remaining: 2m 2s
# 768:	learn: 0.0466337	total: 6m 44s	remaining: 2m 1s
# 769:	learn: 0.0465930	total: 6m 45s	remaining: 2m 1s
# 770:	learn: 0.0465635	total: 6m 45s	remaining: 2m
# 771:	learn: 0.0465244	total: 6m 46s	remaining: 2m
# 772:	learn: 0.0464561	total: 6m 47s	remaining: 1m 59s
# 773:	learn: 0.0463929	total: 6m 47s	remaining: 1m 59s
# 774:	learn: 0.0463610	total: 6m 48s	remaining: 1m 58s
# 775:	learn: 0.0462968	total: 6m 48s	remaining: 1m 58s
# 776:	learn: 0.0462581	total: 6m 49s	remaining: 1m 57s
# 777:	learn: 0.0462101	total: 6m 50s	remaining: 1m 56s
# 778:	learn: 0.0461538	total: 6m 50s	remaining: 1m 56s
# 779:	learn: 0.0461093	total: 6m 51s	remaining: 1m 55s
# 780:	learn: 0.0460579	total: 6m 51s	remaining: 1m 55s
# 781:	learn: 0.0459984	total: 6m 52s	remaining: 1m 54s
# 782:	learn: 0.0459320	total: 6m 52s	remaining: 1m 54s
# 783:	learn: 0.0458783	total: 6m 53s	remaining: 1m 53s
# 784:	learn: 0.0458289	total: 6m 54s	remaining: 1m 53s
# 785:	learn: 0.0457772	total: 6m 54s	remaining: 1m 52s
# 786:	learn: 0.0457204	total: 6m 55s	remaining: 1m 52s
# 787:	learn: 0.0456471	total: 6m 55s	remaining: 1m 51s
# 788:	learn: 0.0455740	total: 6m 56s	remaining: 1m 51s
# 789:	learn: 0.0455283	total: 6m 56s	remaining: 1m 50s
# 790:	learn: 0.0454912	total: 6m 57s	remaining: 1m 50s
# 791:	learn: 0.0454083	total: 6m 57s	remaining: 1m 49s
# 792:	learn: 0.0453584	total: 6m 58s	remaining: 1m 49s
# 793:	learn: 0.0453291	total: 6m 59s	remaining: 1m 48s
# 794:	learn: 0.0452997	total: 6m 59s	remaining: 1m 48s
# 795:	learn: 0.0452625	total: 7m	remaining: 1m 47s
# 796:	learn: 0.0452292	total: 7m	remaining: 1m 47s
# 797:	learn: 0.0451740	total: 7m 1s	remaining: 1m 46s
# 798:	learn: 0.0451292	total: 7m 1s	remaining: 1m 46s
# 799:	learn: 0.0450614	total: 7m 2s	remaining: 1m 45s
# 800:	learn: 0.0450129	total: 7m 2s	remaining: 1m 44s
# 801:	learn: 0.0449719	total: 7m 3s	remaining: 1m 44s
# 802:	learn: 0.0448980	total: 7m 3s	remaining: 1m 43s
# 803:	learn: 0.0448819	total: 7m 4s	remaining: 1m 43s
# 804:	learn: 0.0448383	total: 7m 4s	remaining: 1m 42s
# 805:	learn: 0.0447767	total: 7m 5s	remaining: 1m 42s
# 806:	learn: 0.0447331	total: 7m 5s	remaining: 1m 41s
# 807:	learn: 0.0446998	total: 7m 6s	remaining: 1m 41s
# 808:	learn: 0.0446634	total: 7m 7s	remaining: 1m 40s
# 809:	learn: 0.0445931	total: 7m 7s	remaining: 1m 40s
# 810:	learn: 0.0445618	total: 7m 8s	remaining: 1m 39s
# 811:	learn: 0.0445391	total: 7m 8s	remaining: 1m 39s
# 812:	learn: 0.0444834	total: 7m 9s	remaining: 1m 38s
# 813:	learn: 0.0444460	total: 7m 9s	remaining: 1m 38s
# 814:	learn: 0.0443823	total: 7m 10s	remaining: 1m 37s
# 815:	learn: 0.0443353	total: 7m 10s	remaining: 1m 37s
# 816:	learn: 0.0443140	total: 7m 11s	remaining: 1m 36s
# 817:	learn: 0.0442777	total: 7m 11s	remaining: 1m 36s
# 818:	learn: 0.0442225	total: 7m 12s	remaining: 1m 35s
# 819:	learn: 0.0441941	total: 7m 12s	remaining: 1m 35s
# 820:	learn: 0.0441503	total: 7m 13s	remaining: 1m 34s
# 821:	learn: 0.0441001	total: 7m 13s	remaining: 1m 33s
# 822:	learn: 0.0440688	total: 7m 14s	remaining: 1m 33s
# 823:	learn: 0.0440407	total: 7m 14s	remaining: 1m 32s
# 824:	learn: 0.0440025	total: 7m 15s	remaining: 1m 32s
# 825:	learn: 0.0439314	total: 7m 16s	remaining: 1m 31s
# 826:	learn: 0.0438879	total: 7m 16s	remaining: 1m 31s
# 827:	learn: 0.0438556	total: 7m 17s	remaining: 1m 30s
# 828:	learn: 0.0438044	total: 7m 17s	remaining: 1m 30s
# 829:	learn: 0.0437779	total: 7m 17s	remaining: 1m 29s
# 830:	learn: 0.0437299	total: 7m 18s	remaining: 1m 29s
# 831:	learn: 0.0436947	total: 7m 19s	remaining: 1m 28s
# 832:	learn: 0.0436830	total: 7m 19s	remaining: 1m 28s
# 833:	learn: 0.0436281	total: 7m 20s	remaining: 1m 27s
# 834:	learn: 0.0435857	total: 7m 20s	remaining: 1m 27s
# 835:	learn: 0.0435267	total: 7m 21s	remaining: 1m 26s
# 836:	learn: 0.0434857	total: 7m 22s	remaining: 1m 26s
# 837:	learn: 0.0434441	total: 7m 22s	remaining: 1m 25s
# 838:	learn: 0.0434006	total: 7m 23s	remaining: 1m 25s
# 839:	learn: 0.0433479	total: 7m 24s	remaining: 1m 24s
# 840:	learn: 0.0433237	total: 7m 24s	remaining: 1m 24s
# 841:	learn: 0.0432988	total: 7m 25s	remaining: 1m 23s
# 842:	learn: 0.0432377	total: 7m 25s	remaining: 1m 23s
# 843:	learn: 0.0431944	total: 7m 26s	remaining: 1m 22s
# 844:	learn: 0.0431620	total: 7m 26s	remaining: 1m 21s
# 845:	learn: 0.0431166	total: 7m 27s	remaining: 1m 21s
# 846:	learn: 0.0430455	total: 7m 28s	remaining: 1m 20s
# 847:	learn: 0.0429961	total: 7m 28s	remaining: 1m 20s
# 848:	learn: 0.0429765	total: 7m 29s	remaining: 1m 19s
# 849:	learn: 0.0429380	total: 7m 29s	remaining: 1m 19s
# 850:	learn: 0.0428721	total: 7m 30s	remaining: 1m 18s
# 851:	learn: 0.0428260	total: 7m 30s	remaining: 1m 18s
# 852:	learn: 0.0427963	total: 7m 31s	remaining: 1m 17s
# 853:	learn: 0.0427479	total: 7m 32s	remaining: 1m 17s
# 854:	learn: 0.0426903	total: 7m 32s	remaining: 1m 16s
# 855:	learn: 0.0426492	total: 7m 32s	remaining: 1m 16s
# 856:	learn: 0.0426375	total: 7m 33s	remaining: 1m 15s
# 857:	learn: 0.0425787	total: 7m 33s	remaining: 1m 15s
# 858:	learn: 0.0425398	total: 7m 34s	remaining: 1m 14s
# 859:	learn: 0.0425138	total: 7m 34s	remaining: 1m 14s
# 860:	learn: 0.0424667	total: 7m 35s	remaining: 1m 13s
# 861:	learn: 0.0423898	total: 7m 36s	remaining: 1m 13s
# 862:	learn: 0.0423601	total: 7m 36s	remaining: 1m 12s
# 863:	learn: 0.0423143	total: 7m 37s	remaining: 1m 11s
# 864:	learn: 0.0422678	total: 7m 37s	remaining: 1m 11s
# 865:	learn: 0.0422226	total: 7m 38s	remaining: 1m 10s
# 866:	learn: 0.0422065	total: 7m 38s	remaining: 1m 10s
# 867:	learn: 0.0421793	total: 7m 39s	remaining: 1m 9s
# 868:	learn: 0.0421322	total: 7m 39s	remaining: 1m 9s
# 869:	learn: 0.0421189	total: 7m 40s	remaining: 1m 8s
# 870:	learn: 0.0420717	total: 7m 40s	remaining: 1m 8s
# 871:	learn: 0.0420261	total: 7m 41s	remaining: 1m 7s
# 872:	learn: 0.0419874	total: 7m 42s	remaining: 1m 7s
# 873:	learn: 0.0419674	total: 7m 42s	remaining: 1m 6s
# 874:	learn: 0.0419292	total: 7m 43s	remaining: 1m 6s
# 875:	learn: 0.0418909	total: 7m 43s	remaining: 1m 5s
# 876:	learn: 0.0418619	total: 7m 44s	remaining: 1m 5s
# 877:	learn: 0.0418282	total: 7m 44s	remaining: 1m 4s
# 878:	learn: 0.0417787	total: 7m 45s	remaining: 1m 4s
# 879:	learn: 0.0417509	total: 7m 45s	remaining: 1m 3s
# 880:	learn: 0.0416636	total: 7m 46s	remaining: 1m 3s
# 881:	learn: 0.0415839	total: 7m 47s	remaining: 1m 2s
# 882:	learn: 0.0415554	total: 7m 47s	remaining: 1m 1s
# 883:	learn: 0.0415366	total: 7m 48s	remaining: 1m 1s
# 884:	learn: 0.0414860	total: 7m 48s	remaining: 1m
# 885:	learn: 0.0414423	total: 7m 49s	remaining: 1m
# 886:	learn: 0.0413952	total: 7m 49s	remaining: 59.9s
# 887:	learn: 0.0413712	total: 7m 50s	remaining: 59.3s
# 888:	learn: 0.0413417	total: 7m 51s	remaining: 58.8s
# 889:	learn: 0.0413078	total: 7m 51s	remaining: 58.3s
# 890:	learn: 0.0412416	total: 7m 52s	remaining: 57.8s
# 891:	learn: 0.0412039	total: 7m 52s	remaining: 57.2s
# 892:	learn: 0.0411720	total: 7m 53s	remaining: 56.7s
# 893:	learn: 0.0411334	total: 7m 53s	remaining: 56.2s
# 894:	learn: 0.0410754	total: 7m 54s	remaining: 55.6s
# 895:	learn: 0.0410142	total: 7m 54s	remaining: 55.1s
# 896:	learn: 0.0409762	total: 7m 55s	remaining: 54.6s
# 897:	learn: 0.0409390	total: 7m 55s	remaining: 54s
# 898:	learn: 0.0409195	total: 7m 56s	remaining: 53.5s
# 899:	learn: 0.0408924	total: 7m 56s	remaining: 53s
# 900:	learn: 0.0408677	total: 7m 57s	remaining: 52.4s
# 901:	learn: 0.0408593	total: 7m 57s	remaining: 51.9s
# 902:	learn: 0.0408308	total: 7m 57s	remaining: 51.3s
# 903:	learn: 0.0407903	total: 7m 58s	remaining: 50.8s
# 904:	learn: 0.0407376	total: 7m 58s	remaining: 50.3s
# 905:	learn: 0.0407001	total: 7m 59s	remaining: 49.8s
# 906:	learn: 0.0406318	total: 8m	remaining: 49.2s
# 907:	learn: 0.0406012	total: 8m	remaining: 48.7s
# 908:	learn: 0.0405405	total: 8m 1s	remaining: 48.2s
# 909:	learn: 0.0404972	total: 8m 1s	remaining: 47.6s
# 910:	learn: 0.0404563	total: 8m 2s	remaining: 47.1s
# 911:	learn: 0.0404317	total: 8m 2s	remaining: 46.6s
# 912:	learn: 0.0404022	total: 8m 3s	remaining: 46s
# 913:	learn: 0.0403797	total: 8m 3s	remaining: 45.5s
# 914:	learn: 0.0403681	total: 8m 4s	remaining: 45s
# 915:	learn: 0.0403246	total: 8m 4s	remaining: 44.5s
# 916:	learn: 0.0402875	total: 8m 5s	remaining: 43.9s
# 917:	learn: 0.0402566	total: 8m 5s	remaining: 43.4s
# 918:	learn: 0.0402216	total: 8m 6s	remaining: 42.9s
# 919:	learn: 0.0402166	total: 8m 6s	remaining: 42.3s
# 920:	learn: 0.0401608	total: 8m 7s	remaining: 41.8s
# 921:	learn: 0.0401129	total: 8m 7s	remaining: 41.3s
# 922:	learn: 0.0400709	total: 8m 8s	remaining: 40.7s
# 923:	learn: 0.0400248	total: 8m 8s	remaining: 40.2s
# 924:	learn: 0.0399580	total: 8m 9s	remaining: 39.7s
# 925:	learn: 0.0399021	total: 8m 9s	remaining: 39.2s
# 926:	learn: 0.0398409	total: 8m 10s	remaining: 38.6s
# 927:	learn: 0.0398056	total: 8m 11s	remaining: 38.1s
# 928:	learn: 0.0397841	total: 8m 11s	remaining: 37.6s
# 929:	learn: 0.0397339	total: 8m 12s	remaining: 37.1s
# 930:	learn: 0.0397038	total: 8m 13s	remaining: 36.5s
# 931:	learn: 0.0396733	total: 8m 13s	remaining: 36s
# 932:	learn: 0.0396623	total: 8m 14s	remaining: 35.5s
# 933:	learn: 0.0396241	total: 8m 14s	remaining: 35s
# 934:	learn: 0.0396040	total: 8m 15s	remaining: 34.4s
# 935:	learn: 0.0395807	total: 8m 15s	remaining: 33.9s
# 936:	learn: 0.0395511	total: 8m 16s	remaining: 33.4s
# 937:	learn: 0.0395168	total: 8m 17s	remaining: 32.9s
# 938:	learn: 0.0394886	total: 8m 17s	remaining: 32.3s
# 939:	learn: 0.0394702	total: 8m 18s	remaining: 31.8s
# 940:	learn: 0.0394048	total: 8m 18s	remaining: 31.3s
# 941:	learn: 0.0393850	total: 8m 19s	remaining: 30.7s
# 942:	learn: 0.0393530	total: 8m 19s	remaining: 30.2s
# 943:	learn: 0.0393061	total: 8m 20s	remaining: 29.7s
# 944:	learn: 0.0392935	total: 8m 21s	remaining: 29.2s
# 945:	learn: 0.0392632	total: 8m 21s	remaining: 28.6s
# 946:	learn: 0.0392172	total: 8m 22s	remaining: 28.1s
# 947:	learn: 0.0391797	total: 8m 22s	remaining: 27.6s
# 948:	learn: 0.0391355	total: 8m 23s	remaining: 27.1s
# 949:	learn: 0.0391177	total: 8m 24s	remaining: 26.5s
# 950:	learn: 0.0390881	total: 8m 24s	remaining: 26s
# 951:	learn: 0.0390581	total: 8m 25s	remaining: 25.5s
# 952:	learn: 0.0390298	total: 8m 25s	remaining: 24.9s
# 953:	learn: 0.0390038	total: 8m 26s	remaining: 24.4s
# 954:	learn: 0.0389562	total: 8m 26s	remaining: 23.9s
# 955:	learn: 0.0388983	total: 8m 27s	remaining: 23.3s
# 956:	learn: 0.0388537	total: 8m 27s	remaining: 22.8s
# 957:	learn: 0.0388338	total: 8m 28s	remaining: 22.3s
# 958:	learn: 0.0388173	total: 8m 28s	remaining: 21.8s
# 959:	learn: 0.0387877	total: 8m 29s	remaining: 21.2s
# 960:	learn: 0.0387608	total: 8m 30s	remaining: 20.7s
# 961:	learn: 0.0387361	total: 8m 30s	remaining: 20.2s
# 962:	learn: 0.0387199	total: 8m 31s	remaining: 19.6s
# 963:	learn: 0.0386658	total: 8m 31s	remaining: 19.1s
# 964:	learn: 0.0386436	total: 8m 32s	remaining: 18.6s
# 965:	learn: 0.0385931	total: 8m 32s	remaining: 18s
# 966:	learn: 0.0385546	total: 8m 33s	remaining: 17.5s
# 967:	learn: 0.0385228	total: 8m 33s	remaining: 17s
# 968:	learn: 0.0384910	total: 8m 34s	remaining: 16.4s
# 969:	learn: 0.0384636	total: 8m 34s	remaining: 15.9s
# 970:	learn: 0.0384368	total: 8m 35s	remaining: 15.4s
# 971:	learn: 0.0384037	total: 8m 35s	remaining: 14.9s
# 972:	learn: 0.0383523	total: 8m 36s	remaining: 14.3s
# 973:	learn: 0.0383008	total: 8m 36s	remaining: 13.8s
# 974:	learn: 0.0382762	total: 8m 37s	remaining: 13.3s
# 975:	learn: 0.0382269	total: 8m 37s	remaining: 12.7s
# 976:	learn: 0.0381985	total: 8m 38s	remaining: 12.2s
# 977:	learn: 0.0381650	total: 8m 38s	remaining: 11.7s
# 978:	learn: 0.0381420	total: 8m 39s	remaining: 11.1s
# 979:	learn: 0.0381063	total: 8m 39s	remaining: 10.6s
# 980:	learn: 0.0380542	total: 8m 40s	remaining: 10.1s
# 981:	learn: 0.0380337	total: 8m 41s	remaining: 9.55s
# 982:	learn: 0.0380126	total: 8m 41s	remaining: 9.02s
# 983:	learn: 0.0379931	total: 8m 42s	remaining: 8.49s
# 984:	learn: 0.0379698	total: 8m 42s	remaining: 7.96s
# 985:	learn: 0.0379468	total: 8m 43s	remaining: 7.43s
# 986:	learn: 0.0378952	total: 8m 43s	remaining: 6.9s
# 987:	learn: 0.0378622	total: 8m 44s	remaining: 6.37s
# 988:	learn: 0.0378229	total: 8m 44s	remaining: 5.84s
# 989:	learn: 0.0377897	total: 8m 45s	remaining: 5.3s
# 990:	learn: 0.0377645	total: 8m 45s	remaining: 4.77s
# 991:	learn: 0.0377178	total: 8m 46s	remaining: 4.24s
# 992:	learn: 0.0376871	total: 8m 47s	remaining: 3.71s
# 993:	learn: 0.0376414	total: 8m 47s	remaining: 3.18s
# 994:	learn: 0.0376109	total: 8m 48s	remaining: 2.65s
# 995:	learn: 0.0375763	total: 8m 48s	remaining: 2.12s
# 996:	learn: 0.0375264	total: 8m 49s	remaining: 1.59s
# 997:	learn: 0.0374773	total: 8m 49s	remaining: 1.06s
# 998:	learn: 0.0374354	total: 8m 50s	remaining: 531ms
# 999:	learn: 0.0374108	total: 8m 50s	remaining: 0us

# %%
lgb_oof_train, lgb_oof_test = get_oof(model_lgb, train[lgb_features].values, y_train, test[lgb_features].values)
# Out:
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6697712968829559, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6697712968829559
# [LightGBM] [Warning] lambda_l1 is set=1.5680852745891572e-06, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.5680852745891572e-06
# [LightGBM] [Warning] bagging_fraction is set=0.7559447209589375, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7559447209589375
# [LightGBM] [Warning] lambda_l2 is set=5.5199200274889796e-05, reg_lambda=0.0 will be ignored. Current value: lambda_l2=5.5199200274889796e-05
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3

# %%
xgb_oof_train, xgb_oof_test = get_oof(model_xgb, train[xgb_features].values, y_train, test[xgb_features].values)
# Out:
# [17:08:15] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:10:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:13:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:16:46] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:19:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:22:43] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:25:39] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:28:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:31:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:35:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.0/src/learner.cc:576:
# Parameters: { "metric" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
rf_oof_train, rf_oof_test = get_oof(model_rf, train[rf_features].values, y_train, test[rf_features].values)

# %%
lgb_v2_oof_train, lgb_v2_oof_test = get_oof(model_lgb_v2, train[lgb_v2_features].values, y_train, test[lgb_v2_features].values)
# Out:
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\engine.py:177: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# [LightGBM] [Warning] boosting is set=gbdt, boosting_type=gbdt will be ignored. Current value: boosting=gbdt
# [LightGBM] [Warning] feature_fraction is set=0.6293142647827907, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6293142647827907
# [LightGBM] [Warning] lambda_l1 is set=2.4308837323197616e-05, reg_alpha=0.0 will be ignored. Current value: lambda_l1=2.4308837323197616e-05
# [LightGBM] [Warning] bagging_fraction is set=0.6244885179807813, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6244885179807813
# [LightGBM] [Warning] lambda_l2 is set=0.0005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0005
# [LightGBM] [Warning] bagging_freq is set=6, subsample_freq=0 will be ignored. Current value: bagging_freq=6

# %%
x_train = np.concatenate((
    lgb_oof_train,
    xgb_oof_train,
    cb_oof_train,
    rf_oof_train,
    lgb_v2_oof_train
), axis=1)

x_test = np.concatenate((
    lgb_oof_test,
    xgb_oof_test,
    cb_oof_test,
    rf_oof_test,
    lgb_v2_oof_test
), axis=1)

# %%
meta_model = lgb.LGBMRegressor( 
    num_leaves=5,
    max_depth=7, 
    random_state=42, 
    silent=True, 
    metric='rmsle',
    n_jobs=4, 
    n_estimators=4000,
    colsample_bytree=1,
    subsample=0.9,
    learning_rate=0.05
)

meta_model.fit(x_train, y_train)
meta_model_train_pred = np.exp(meta_model.predict(x_train))
meta_model_pred = np.exp(meta_model.predict(x_test))
# Out:
# C:\Users\Torkild\anaconda3\envs\tdt4173\lib\site-packages\lightgbm\sklearn.py:598: UserWarning: 'silent' argument is deprecated and will be removed in a future release of LightGBM. Pass 'verbose' parameter via keyword arguments instead.
#   _log_warning("'silent' argument is deprecated and will be removed in a future release of LightGBM. "

# %%
sub4 = pd.DataFrame()
sub4['id'] = test['id']
sub4['price_prediction'] =  meta_model_pred*0.5 + np.exp(xgb_pred)*0.2 + np.exp(cb_pred)*0.2 + np.exp(lgbm_preds)*0.1
sub4
# Out:
#          id  price_prediction
# 0     23285      2.997069e+07
# 1     23286      9.910036e+06
# 2     23287      6.151253e+06
# 3     23288      8.572743e+06
# 4     23289      5.297835e+06
# ...     ...               ...
# 9932  33217      2.878670e+07
# 9933  33218      2.073239e+07
# 9934  33219      9.484344e+06
# 9935  33220      9.516094e+06
# 9936  33221      5.611974e+06
#
# [9937 rows x 2 columns]

# %%
sub4.to_csv('submission.csv', index=False)
